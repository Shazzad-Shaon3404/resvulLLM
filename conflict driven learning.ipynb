# %%
import torch
import pandas as pd
import numpy as np
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, matthews_corrcoef, cohen_kappa_score,
    mean_squared_error, mean_absolute_error, roc_auc_score
)

# --- Load Model & Tokenizer ---
model_dir = "./cdl_codebert_model_final"
model = AutoModelForSequenceClassification.from_pretrained(model_dir)
tokenizer = AutoTokenizer.from_pretrained(model_dir)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

# --- Load Test Data ---
test_df = pd.read_csv("cdl_test.csv")
inputs = test_df['input'].astype(str).tolist()         # <--- Change here
true_labels = test_df['label'].astype(int).tolist()

# --- Batch Prediction ---
def batch_predict_probs(inputs, model, tokenizer, batch_size=16, max_length=256):
    all_preds = []
    all_probs = []
    for i in range(0, len(inputs), batch_size):
        batch = inputs[i:i+batch_size]
        encodings = tokenizer(batch, truncation=True, padding="max_length", max_length=max_length, return_tensors="pt")
        input_ids = encodings["input_ids"].to(device)
        attention_mask = encodings["attention_mask"].to(device)
        with torch.no_grad():
            logits = model(input_ids=input_ids, attention_mask=attention_mask).logits
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            preds = np.argmax(probs, axis=1)
            all_probs.extend(probs[:, 1])
            all_preds.extend(preds)
    return np.array(all_preds), np.array(all_probs)

preds, probs = batch_predict_probs(inputs, model, tokenizer)

# --- Add predictions to DataFrame ---
test_df["pred_label"] = preds
test_df["pred_prob"] = probs

# --- Evaluation Metrics ---
try:
    tn, fp, fn, tp = confusion_matrix(true_labels, preds).ravel()
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
except Exception:
    specificity, fpr = float('nan'), float('nan')

try:
    auc = roc_auc_score(true_labels, probs)
except Exception:
    auc = float('nan')

print("\n" + "="*28 + " Evaluation Metrics " + "="*28)
print(f"{'Accuracy':<15}: {accuracy_score(true_labels, preds):.4f}")
print(f"{'MCC':<15}: {matthews_corrcoef(true_labels, preds):.4f}")
print(f"{'Kappa':<15}: {cohen_kappa_score(true_labels, preds):.4f}")
print(f"{'Precision':<15}: {precision_score(true_labels, preds, zero_division=0):.4f}")
print(f"{'Recall':<15}: {recall_score(true_labels, preds, zero_division=0):.4f}")
print(f"{'F1 Score':<15}: {f1_score(true_labels, preds, zero_division=0):.4f}")
print(f"{'Specificity':<15}: {specificity:.4f}")
print(f"{'FPR':<15}: {fpr:.4f}")
print(f"{'AUC Score':<15}: {auc:.4f}")
print(f"{'MAE':<15}: {mean_absolute_error(true_labels, preds):.4f}")
print(f"{'MSE':<15}: {mean_squared_error(true_labels, preds):.4f}")
print("="*70)

# Save with predictions if desired
test_df.to_csv("cdl_test_with_preds.csv", index=False)
# Out:
# ============================ Evaluation Metrics ============================
# Accuracy       : 0.6658
# MCC            : 0.3018
# Kappa          : 0.2908
# Precision      : 0.6548
# Recall         : 0.4617
# F1 Score       : 0.5415
# Specificity    : 0.8183
# FPR            : 0.1817
# AUC Score      : 0.7188
# MAE            : 0.3342
# MSE            : 0.3342
# ======================================================================

# %%
def identify_conflicts(event_trace, predicted_label):
    """
    event_trace: list of strings describing the symbolic trace for a function
    predicted_label: 0 (not vulnerable) or 1 (vulnerable)
    Returns: (conflict: bool, reasons: list of strings)
    """
    reasons = []
    conflict = False

    # If model predicts not vulnerable (0), look for unsafe symbolic patterns
    if predicted_label == 0:
        # Rule 1: Assign to pointer without prior check
        for i, event in enumerate(event_trace):
            if event.startswith("assign: *"):
                # Check last 5 events for any if/condition/guard/check
                guarded = any('if:' in event_trace[j] or 'condition:' in event_trace[j] or 'check' in event_trace[j]
                              for j in range(max(0, i-5), i))
                if not guarded:
                    conflict = True
                    reasons.append(f"Unsafe pointer assignment `{event}` not preceded by a safety check, but predicted not vulnerable.")

        # Rule 2: Use of <unknown>
        for event in event_trace:
            if 'use <unknown>' in event:
                conflict = True
                reasons.append(f"Use of unknown/untrusted type in `{event}` but predicted not vulnerable.")

        # Rule 3: Direct field access (often signals privilege escalation or type confusion)
        for event in event_trace:
            if "field_access" in event:
                conflict = True
                reasons.append(f"Direct field access `{event}` could be unsafe, but predicted not vulnerable.")

        # Rule 4: Return after unsafe op (may be missing error check)
        for i, event in enumerate(event_trace):
            if event.startswith("return:"):
                unsafe_ops = any("assign: *" in e for e in event_trace[max(0, i-5):i])
                if unsafe_ops:
                    conflict = True
                    reasons.append(f"Returning after unsafe op before `{event}`, but predicted not vulnerable.")

        # Rule 5: Unsafe operation inside an else branch
        for i, event in enumerate(event_trace):
            if event == "else":
                possible_unsafe = any("assign: *" in e for e in event_trace[i:i+5])
                if possible_unsafe:
                    conflict = True
                    reasons.append("Possible unsafe write in else-branch, but predicted not vulnerable.")

    return conflict, reasons

# %%
import ast


test_df['event_trace_list'] = test_df['event_trace'].apply(ast.literal_eval)

# %%
conflict_results = test_df.apply(
    lambda row: identify_conflicts(row['event_trace_list'], row['pred_label']), axis=1
)
test_df['conflict'] = [c for c, _ in conflict_results]
test_df['conflict_reason'] = [r for _, r in conflict_results]

# %%
print(test_df[test_df['conflict'] == True][['input', 'event_trace', 'pred_label', 'conflict_reason']].head(5))
# Out:
#                                                input  \
# 0  static void s390x_cpu_get_id(Object *obj, Visi...
# 1  static int ast2500_rambits(AspeedSDMCState *s)...
# 2  static int vhdx_open(BlockDriverState *bs, QDi...
# 3  void hmp_nbd_server_start(Monitor *mon, const ...
# 4  int qemu_show_nic_models(const char *arg, cons...
#
#                                          event_trace  pred_label  \
# 0  ['declare S390CPU* cpu', 'assign: *cpu = S390_...           0
# 1  ['switch: switch (s->ram_size >> 20) {\ncase 1...           0
# 2  ['declare BDRVVHDXState* s', 'assign: *s = bs-...           0
# 3  ['declare char* uri', 'assign: *uri = qdict_ge...           0
# 4  ['declare int i', 'if: "!arg || strcmp(arg, \\...           0
#
#                                      conflict_reason
# 0  [Unsafe pointer assignment `assign: *cpu = S39...
# 1  [Use of unknown/untrusted type in `    use <un...
# 2  [Unsafe pointer assignment `assign: *s = bs->o...
# 3  [Unsafe pointer assignment `assign: *uri = qdi...
# 4  [Use of unknown/untrusted type in `use <unknow...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2807 entries, 0 to 2806
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   func              2807 non-null   object
#  1   func_cleaned      2807 non-null   object
#  2   project           2807 non-null   object
#  3   label             2807 non-null   bool
#  4   graph_path        2807 non-null   object
#  5   event_trace       2807 non-null   object
#  6   input             2807 non-null   object
#  7   pred_label        2807 non-null   int64
#  8   pred_prob         2807 non-null   float32
#  9   event_trace_list  2807 non-null   object
#  10  conflict          2807 non-null   bool
#  11  conflict_reason   2807 non-null   object
# dtypes: bool(2), float32(1), int64(1), object(8)
# memory usage: 213.9+ KB

# %%
test_df['conflict'].value_counts()
# Out:
# conflict
# True     1733
# False    1074
# Name: count, dtype: int64

# %%
test_df['label'].value_counts()
# Out:
# label
# False    1607
# True     1200
# Name: count, dtype: int64

# %%
mask = (test_df['conflict'] == True) & (test_df['label'] == 1)
num_true_conflicts = mask.sum()
print(f"Number of TRUE conflicts where model missed a real vulnerability: {num_true_conflicts}")
# Out:
# Number of TRUE conflicts where model missed a real vulnerability: 591

# %% [markdown]
# Another version

# %%
def identify_conflicts(event_trace, predicted_label):
    """
    Optimized: One-pass event_trace scan, all rules together, easier maintenance.
    """
    reasons = []
    conflict = False

    if predicted_label == 0:
        # Precompute guards for efficiency (track recent control/checks)
        recent_guards = [False] * len(event_trace)
        for i, event in enumerate(event_trace):
            if any(x in event for x in ['if:', 'condition:', 'check']):
                for j in range(max(0, i - 5), i):
                    recent_guards[j] = True  # Mark as guarded

        # For Rule 4: Keep a window of recent events for quick lookup
        recent_assign = [False] * len(event_trace)
        for i, event in enumerate(event_trace):
            if event.startswith("assign: *"):
                for j in range(i+1, min(len(event_trace), i+6)):
                    if event_trace[j].startswith("return:"):
                        recent_assign[j] = True  # Mark return after unsafe op

        # Track else blocks for Rule 5
        else_indices = [i for i, e in enumerate(event_trace) if e == "else"]

        # One-pass scan for all triggers
        for i, event in enumerate(event_trace):
            # Rule 1: Assign to pointer without prior check
            if event.startswith("assign: *") and not recent_guards[i]:
                conflict = True
                reasons.append(f"Unsafe pointer assignment `{event}` not preceded by a safety check, but predicted not vulnerable.")

            # Rule 2: Use of <unknown>
            if 'use <unknown>' in event:
                conflict = True
                reasons.append(f"Use of unknown/untrusted type in `{event}` but predicted not vulnerable.")

            # Rule 3: Direct field access
            if "field_access" in event:
                conflict = True
                reasons.append(f"Direct field access `{event}` could be unsafe, but predicted not vulnerable.")

            # Rule 4: Return after unsafe op
            if event.startswith("return:") and recent_assign[i]:
                conflict = True
                reasons.append(f"Returning after unsafe op before `{event}`, but predicted not vulnerable.")

        # Rule 5: Unsafe op in else branch
        for idx in else_indices:
            for j in range(idx, min(idx+5, len(event_trace))):
                if event_trace[j].startswith("assign: *"):
                    conflict = True
                    reasons.append("Possible unsafe write in else-branch, but predicted not vulnerable.")
                    break  # Only need to trigger once per else block

    return conflict, reasons

# %% [markdown]
# -------------------------------------

# %%
import pandas as pd
test_df = pd.read_csv('cdl_test_with_preds.csv')

# %%
def conflict_detection(event_trace, pred_label):
    """
    Refined version: Only flags real danger, minimizes field_access noise.
    """
    conflict = False
    reasons = []

    # Only proceed if model predicts not vulnerable (pred_label==0)
    if pred_label == 0:
        # Example: List of dangerous fields (customize as needed)
        dangerous_fields = {'password', 'user_ptr', 'kernel_addr'}
        assign_patterns = ['assign: *', 'assign: *(']  # pattern for pointer assignment

        for i, event in enumerate(event_trace):
            event_strip = event.strip()

            # Rule 1: Assign to pointer without guard
            if event_strip.startswith("assign: *"):
                guarded = any('if:' in event_trace[j] or 'condition:' in event_trace[j] or 'check' in event_trace[j]
                              for j in range(max(0, i-5), i))
                if not guarded:
                    conflict = True
                    reasons.append(f"Unsafe pointer assignment `{event}` not preceded by a safety check, but predicted not vulnerable.")

            # Rule 2: Use of <unknown>
            if 'use <unknown>' in event_strip:
                conflict = True
                reasons.append(f"Use of unknown/untrusted type in `{event}` but predicted not vulnerable.")

            # Rule 3: Context-aware field access (only for dangerous fields)
            if event_strip.startswith("field_access:"):
                # Extract the field name
                parts = event_strip.split(":")
                field_name = parts[-1].strip() if len(parts) > 1 else ""
                if field_name in dangerous_fields:
                    conflict = True
                    reasons.append(f"Direct access to sensitive field `{field_name}` without proper check.")
                # Optionally: look ahead for unsafe usage (pointer assignment)
                if i+1 < len(event_trace) and any(pat in event_trace[i+1] for pat in assign_patterns):
                    conflict = True
                    reasons.append(f"Field `{field_name}` is immediately used in unsafe pointer assignment.")

            # Rule 4: Return after unsafe op
            if event_strip.startswith("return:"):
                unsafe_ops = any("assign: *" in e for e in event_trace[max(0, i-5):i])
                if unsafe_ops:
                    conflict = True
                    reasons.append(f"Returning after unsafe op before `{event}`, but predicted not vulnerable.")

            # Rule 5: Unsafe operation inside an else branch (optional, often noisy)
            if event_strip == "else":
                possible_unsafe = any("assign: *" in e for e in event_trace[i:i+5])
                if possible_unsafe:
                    conflict = True
                    reasons.append("Possible unsafe write in else-branch, but predicted not vulnerable.")

    return conflict, reasons

# %%
import ast


test_df['event_trace_list'] = test_df['event_trace'].apply(ast.literal_eval)

# %%
conflict_results = test_df.apply(
    lambda row: conflict_detection(row['event_trace_list'], row['pred_label']), axis=1
)
test_df['conflict'] = [c for c, _ in conflict_results]
test_df['conflict_reason'] = [r for _, r in conflict_results]

# %%
test_df.info()
test_df['conflict'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2807 entries, 0 to 2806
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   func              2807 non-null   object
#  1   func_cleaned      2807 non-null   object
#  2   project           2807 non-null   object
#  3   label             2807 non-null   bool
#  4   graph_path        2807 non-null   object
#  5   event_trace       2807 non-null   object
#  6   input             2807 non-null   object
#  7   pred_label        2807 non-null   int64
#  8   pred_prob         2807 non-null   float64
#  9   event_trace_list  2807 non-null   object
#  10  conflict          2807 non-null   bool
#  11  conflict_reason   2807 non-null   object
# dtypes: bool(2), float64(1), int64(1), object(8)
# memory usage: 224.9+ KB
# conflict
# True     1613
# False    1194
# Name: count, dtype: int64

# %%
test_df['pred_label'].value_counts()
# Out:
# pred_label
# 0    1961
# 1     846
# Name: count, dtype: int64

# %%
test_df['label'].value_counts()
# Out:
# label
# False    1607
# True     1200
# Name: count, dtype: int64

# %%
mask = (test_df['conflict'] == False) & (test_df['label'] == True)
num_true_conflicts = mask.sum()
print(f"Number of TRUE conflicts where model not detected a real vulnerability: {num_true_conflicts}")
# Out:
# Number of TRUE conflicts where model not detected a real vulnerability: 646

# %%
import pandas as pd

# Let's say your results are stored in a DataFrame called df

# Select only false positives: conflict True but actual label is 0 (not vulnerable)
false_positives = test_df[(test_df['conflict'] == True) & (test_df['label'] == False)]

# Optional: Sort by reason or any column you like
false_positives = false_positives.sort_values(by='conflict_reason')

# Show or save the results
print(false_positives[['func', 'pred_label', 'label', 'conflict_reason', 'event_trace']])

# Save to CSV for manual analysis if needed
false_positives.to_csv('false_positive_conflicts.csv', index=False)
# Out:
#                                                    func  pred_label  label  \
# 971   int bdrv_is_allocated_above(BlockDriverState *...           0  False
# 2796  void qemu_bh_update_timeout(int *timeout)\n\n{...           0  False
# 325   static int vmdk_probe(const uint8_t *buf, int ...           0  False
# 2043  static PCIBus *pci_get_bus_devfn(int *devfnp, ...           0  False
# 297   tight_filter_gradient24(VncState *vs, uint8_t ...           0  False
# ...                                                 ...         ...    ...
# 1191  static int rate_get_samples (struct audio_pcm_...           0  False
# 1036  static int vnc_tls_initialize(void)\n\n{\n\n  ...           0  False
# 1670  static VirtIOSerialPort *find_port_by_name(cha...           0  False
# 459   static void test_submit(void)\n\n{\n\n    Work...           0  False
# 363   static void xen_config_cleanup_dir(char *dir)\...           0  False
#
#                                         conflict_reason  \
# 971   [Possible unsafe write in else-branch, but pre...
# 2796  [Possible unsafe write in else-branch, but pre...
# 325   [Possible unsafe write in else-branch, but pre...
# 2043  [Returning after unsafe op before `    return:...
# 297   [Unsafe pointer assignment `            assign...
# ...                                                 ...
# 1191  [Use of unknown/untrusted type in `use <unknow...
# 1036  [Use of unknown/untrusted type in `use <unknow...
# 1670  [Use of unknown/untrusted type in `use <unknow...
# 459   [Use of unknown/untrusted type in `use <unknow...
# 363   [Use of unknown/untrusted type in `use <unknow...
#
#                                             event_trace
# 971   ['declare BlockDriverState* intermediate', 'de...
# 2796  ['declare QEMUBH* bh', 'for: for (bh = async_c...
# 325   ['declare uint32_t magic', 'if: "buf_size < 4"...
# 2043  ['declare int dom', 'declare int bus', 'declar...
# 297   ['declare uint32_t* buf32', 'declare uint32_t ...
# ...                                                 ...
# 1191  ['declare int64_t now', 'declare int64_t ticks...
# 1036  ['declare int tlsinitialized', 'assign: tlsini...
# 1670  ['declare VirtIOSerial* vser', 'call: QLIST_FO...
# 459   ['declare WorkerTestData data', 'assign: data ...
# 363   ['declare xs_dirs* d', 'assign: d = qemu_mallo...
#
# [1059 rows x 5 columns]

# %%
import pandas as pd
data = pd.read_csv('false_positive_conflicts.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   func              1142 non-null   object
#  1   func_cleaned      1142 non-null   object
#  2   project           1142 non-null   object
#  3   label             1142 non-null   bool
#  4   graph_path        1142 non-null   object
#  5   event_trace       1142 non-null   object
#  6   input             1142 non-null   object
#  7   pred_label        1142 non-null   int64
#  8   pred_prob         1142 non-null   float64
#  9   event_trace_list  1142 non-null   object
#  10  conflict          1142 non-null   bool
#  11  conflict_reason   1142 non-null   object
# dtypes: bool(2), float64(1), int64(1), object(8)
# memory usage: 91.6+ KB

# %%
data['event_trace'].iloc[0]
# Out:
# '[\'declare int result\', \'assign: result = 0\', \'use result as int\', \'literal: 0\', \'if: "secn > 0"\', \'    declare uint8_t* sp\', \'    assign: *sp = (const uint8_t *)src\', \'    use sp as uint8_t*\', \'    operator: <operator>.cast ((const uint8_t *)src)\', \'    use src as void*\', \'    declare uint8_t* dp\', \'    declare uint8_t* dpp\', \'    assign: *dp = 0\', \'    use dp as uint8_t*\', \'    literal: 0\', \'    assign: *dpp = 0\', \'    use dpp as uint8_t*\', \'    literal: 0\', \'    if: "s->bdrv_cur"\', \'        assign: dp = g_malloc(512)\', \'        use dp as uint8_t*\', \'        call: g_malloc (g_malloc(512))\', \'        literal: 512\', \'        if: "!dp || bdrv_read(s->bdrv_cur, s->secs_cur + (sec >> 5), dp, 1) < 0"\', \'            assign: result = 1\', \'            use result as int\', \'            literal: 1\', \'        else\', \'            else\', \'                assign: dpp = dp + ((sec & 31) << 4)\', \'                use dpp as uint8_t*\', \'                operator: <operator>.addition (dp + ((sec & 31) << 4))\', \'                use dp as uint8_t*\', \'                operator: <operator>.shiftLeft ((sec & 31) << 4)\', \'                condition: sec & 31\', \'                use sec as int\', \'                literal: 31\', \'                literal: 4\', \'    else\', \'        else\', \'            if: "sec + secn > s->secs_cur"\', \'                assign: result = 1\', \'                use result as int\', \'                literal: 1\', \'            else\', \'                else\', \'                    assign: dpp = s->current + (s->secs_cur << 9) + (sec << 4)\', \'                    use dpp as uint8_t*\', \'                    operator: <operator>.addition (s->current + (s->secs_cur << 9) + (sec << 4))\', \'                    operator: <operator>.addition (s->current + (s->secs_cur << 9))\', \'                    field_access: s->current\', \'                    use s as OneNANDState*\', \'                    field: current\', \'                    operator: <operator>.shiftLeft (s->secs_cur << 9)\', \'                    field_access: s->secs_cur\', \'                    use s as OneNANDState*\', \'                    field: secs_cur\', \'                    literal: 9\', \'                    operator: <operator>.shiftLeft (sec << 4)\', \'                    use sec as int\', \'                    literal: 4\', \'    if: "!result"\', \'        declare uint32_t i\', \'        for: for (i = 0;i < (secn << 4);i++)\', \'            call: <operators>.assignmentAnd (dpp[i] &= sp[i])\', \'            operator: <operator>.indirectIndexAccess (dpp[i])\', \'            use dpp as uint8_t*\', \'            use i as uint32_t\', \'            operator: <operator>.indirectIndexAccess (sp[i])\', \'            use sp as uint8_t*\', \'            use i as uint32_t\', \'        if: "s->bdrv_cur"\', \'            assign: result = bdrv_write(s->bdrv_cur, s->secs_cur + (sec >> 5), dp, 1) < 0\', \'            use result as int\', \'            operator: <operator>.lessThan (bdrv_write(s->bdrv_cur, s->secs_cur + (sec >> 5), dp, 1) < 0)\', \'            call: bdrv_write (bdrv_write(s->bdrv_cur, s->secs_cur + (sec >> 5), dp, 1))\', \'            field_access: s->bdrv_cur\', \'            use s as OneNANDState*\', \'            field: bdrv_cur\', \'            operator: <operator>.addition (s->secs_cur + (sec >> 5))\', \'            field_access: s->secs_cur\', \'            use s as OneNANDState*\', \'            field: secs_cur\', \'            operator: <operator>.arithmeticShiftRight (sec >> 5)\', \'            use sec as int\', \'            literal: 5\', \'            use dp as uint8_t*\', \'            literal: 1\', \'            literal: 0\', \'    call: g_free (g_free(dp))\', \'    use dp as uint8_t*\', \'return: return result;\', \'use result as int\']'

# %%
data['conflict_reason'].iloc[0]
# Out:
# "['Direct field access `                    field_access: s->current` could be unsafe, but predicted not vulnerable.', 'Direct field access `                    field_access: s->secs_cur` could be unsafe, but predicted not vulnerable.', 'Direct field access `            field_access: s->bdrv_cur` could be unsafe, but predicted not vulnerable.', 'Direct field access `            field_access: s->secs_cur` could be unsafe, but predicted not vulnerable.']"

# %%
data['conflict'].iloc[0]
# Out:
# np.True_

# %%
# Find cases where:
# Model predicted 0 (not vulnerable), ground truth is 1 (vulnerable), conflict_refined is True
caught_model_misses = test_df[
    (test_df['pred_label'] == 0) &
    (test_df['label'] == 1) &
    (test_df['conflict'] == True)
]

# Count
num_caught = len(caught_model_misses)
print(f"Conflicts that caught model misses (False Negatives flagged): {num_caught}")

# Optionally, show a few examples
print(caught_model_misses[['func_cleaned', 'label', 'pred_label', 'conflict', 'conflict_reason']].head())
# Out:
# Conflicts that caught model misses (False Negatives flagged): 554
#                                          func_cleaned  label  pred_label  \
# 2   static int vhdx_open(BlockDriverState *bs, QDi...   True           0
# 4   int qemu_show_nic_models(const char *arg, cons...   True           0
# 5   static void openpic_set_irq(void *opaque, int ...   True           0
# 13  static CharDriverState *qemu_chr_open_fd(int f...   True           0
# 19  static void ehci_detach(USBPort *port) {\nEHCI...   True           0
#
#     conflict                                    conflict_reason
# 2       True  [Unsafe pointer assignment `assign: *s = bs->o...
# 4       True  [Use of unknown/untrusted type in `use <unknow...
# 5       True  [Unsafe pointer assignment `assign: *opp = opa...
# 13      True  [Use of unknown/untrusted type in `use <unknow...
# 19      True  [Unsafe pointer assignment `assign: *s = port-...

# %%
model_misses = test_df[(test_df['pred_label'] == 0) & (test_df['label'] == 1)]
total_misses = len(model_misses)


not_caught = total_misses - num_caught
print(f"Model misses not caught by conflict detection: {not_caught}")
# Out:
# Model misses not caught by conflict detection: 92

# %%
recall = num_caught / total_misses if total_misses > 0 else 0
print(f"Recall of conflict detection for model's false negatives: {recall:.2%}")
# Out:
# Recall of conflict detection for model's false negatives: 85.76%

# %%
# Suppose your DataFrame is called df, with columns: 'conflict', 'ground_truth'
false_positives = test_df[(test_df['conflict'] == True) & (test_df['label'] == False)].shape[0]
total_actual_negatives = test_df[test_df['label'] == False].shape[0]

conflict_fpr = false_positives / total_actual_negatives if total_actual_negatives > 0 else 0
print(f"Conflict detection false positive rate: {conflict_fpr:.2%}")
# Out:
# Conflict detection false positive rate: 65.90%

# %% [markdown]
# ----------------------------------------------------------------------------------

# %%
import re

#Define whitelists based on your analysis
SAFE_POINTER_ASSIGN_RHS = {'NULL', '&cpu->env', 'qemu_get_nic_opaque(nc)', 'arg', 'CPU(cpu)', 'to_qiv(v)', 'to_qov(v)', 'cfg_entry->reg'}
SAFE_UNKNOWN_VALUES = {'NULL', 'stderr', 'errno', 'false', 'true', 'cpu_env', 'env', 'TARGET_PAGE_MASK', 'PATH_MAX', 'EIO'}

def refined_conflict_detection(event_trace, pred_label):
    conflict = False
    reasons = []

    if pred_label == 0:
        for i, event in enumerate(event_trace):
            event_strip = event.strip()

            # Refined Unsafe Pointer Assignment Rule
            if event_strip.startswith("assign: *"):
                # Extract RHS value
                m = re.search(r"assign: \*.*= (.+)", event_strip)
                rhs = m.group(1).strip() if m else ""
                if rhs not in SAFE_POINTER_ASSIGN_RHS:
                    # Only flag if not whitelisted
                    guarded = any('if:' in event_trace[j] or 'check' in event_trace[j] for j in range(max(0, i-5), i))
                    if not guarded:
                        conflict = True
                        reasons.append(f"Unsafe pointer assignment `{event}` not preceded by a safety check, but predicted not vulnerable.")

            # Refined Use of Unknown/Untrusted Type Rule
            if 'use <unknown>' in event_strip:
                m = re.search(r"use <unknown> ([^ ]+)", event_strip)
                unknown_val = m.group(1).strip() if m else ""
                if unknown_val not in SAFE_UNKNOWN_VALUES:
                    conflict = True
                    reasons.append(f"Use of unknown/untrusted type in `{event}` but predicted not vulnerable.")

    return conflict, reasons

# %%
conflict_results = test_df.apply(
    lambda row: refined_conflict_detection(row['event_trace_list'], row['pred_label']), axis=1
)
test_df['conflict'] = [c for c, _ in conflict_results]
test_df['conflict_reason'] = [r for _, r in conflict_results]

# %%
test_df.info()
test_df['conflict'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2807 entries, 0 to 2806
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   func              2807 non-null   object
#  1   func_cleaned      2807 non-null   object
#  2   project           2807 non-null   object
#  3   label             2807 non-null   bool
#  4   graph_path        2807 non-null   object
#  5   event_trace       2807 non-null   object
#  6   input             2807 non-null   object
#  7   pred_label        2807 non-null   int64
#  8   pred_prob         2807 non-null   float64
#  9   event_trace_list  2807 non-null   object
#  10  conflict          2807 non-null   bool
#  11  conflict_reason   2807 non-null   object
# dtypes: bool(2), float64(1), int64(1), object(8)
# memory usage: 224.9+ KB
# conflict
# True     1508
# False    1299
# Name: count, dtype: int64

# %%
# Suppose your DataFrame is called df, with columns: 'conflict', 'ground_truth'
false_positives = test_df[(test_df['conflict'] == True) & (test_df['label'] == False)].shape[0]
total_actual_negatives = test_df[test_df['label'] == False].shape[0]

conflict_fpr = false_positives / total_actual_negatives if total_actual_negatives > 0 else 0
print(f"Conflict detection false positive rate: {conflict_fpr:.2%}")
# Out:
# Conflict detection false positive rate: 61.05%

# %%
# True Positives for conflict detection
tp_conflict = test_df[(test_df['label'] == True) & (test_df['conflict'] == True)].shape[0]

# Model false negatives rescued by conflict detection
fn_model_and_conflict = test_df[
    (test_df['label'] == True) &
    (test_df['pred_label'] == 0) &
    (test_df['conflict'] == True)
].shape[0]

print(f"True Positives (conflict): {tp_conflict}")
print(f"Model missed but conflict detected: {fn_model_and_conflict}")
# Out:
# True Positives (conflict): 527
# Model missed but conflict detected: 527

# %% [markdown]
# -------------------------------

# %%
import re

# Whitelist based on prior analysis
SAFE_POINTER_ASSIGN_RHS = {
    'NULL', '&cpu->env', 'qemu_get_nic_opaque(nc)', 'arg', 'CPU(cpu)',
    'to_qiv(v)', 'to_qov(v)', 'cfg_entry->reg'
}
SAFE_UNKNOWN_VALUES = {
    'NULL', 'stderr', 'errno', 'false', 'true', 'cpu_env', 'env', 'TARGET_PAGE_MASK', 'PATH_MAX', 'EIO'
}
DANGEROUS_FUNCS = {'strcpy', 'strcat', 'sprintf', 'vsprintf', 'memcpy', 'gets', 'system'}

def refined_conflict_detection(event_trace, pred_label):
    """
    Context-aware conflict detection tuned for your event_trace style.
    Only flags truly suspicious patterns and avoids common safe idioms.
    """
    conflict = False
    reasons = []

    # Convert string-list to Python list if needed
    if isinstance(event_trace, str):
        try:
            event_trace = eval(event_trace)
        except Exception:
            pass

    if pred_label == 0:
        for i, event in enumerate(event_trace):
            event_strip = event.strip()

            # Unsafe Pointer Assignment (with whitelist)
            if event_strip.startswith("assign: *"):
                m = re.search(r"assign: \*.*= (.+)", event_strip)
                rhs = m.group(1).strip() if m else ""
                # Only flag if not whitelisted
                if rhs not in SAFE_POINTER_ASSIGN_RHS:
                    guarded = any(
                        'if:' in event_trace[j] or 'check' in event_trace[j]
                        for j in range(max(0, i-5), i)
                    )
                    if not guarded:
                        conflict = True
                        reasons.append(f"Unsafe pointer assignment `{event}` not preceded by a safety check, but predicted not vulnerable.")

            # Use of <unknown> Value (with whitelist)
            if 'use <unknown>' in event_strip:
                m = re.search(r"use <unknown> ([^ ]+)", event_strip)
                unknown_val = m.group(1).strip() if m else ""
                if unknown_val not in SAFE_UNKNOWN_VALUES:
                    conflict = True
                    reasons.append(f"Use of unknown/untrusted type in `{event}` but predicted not vulnerable.")

            # Dangerous Buffer/Function Use (CWE-119, CWE-120, CWE-242, CWE-676)
            if event_strip.startswith("call:"):
                func_call = event_strip.split(":")[1].strip().split("(")[0]
                if func_call in DANGEROUS_FUNCS:
                    guarded = any(
                        'if:' in event_trace[j] and (
                            'size' in event_trace[j] or 'length' in event_trace[j] or 'bound' in event_trace[j]
                        )
                        for j in range(max(0, i-5), i)
                    )
                    if not guarded:
                        conflict = True
                        reasons.append(f"Dangerous call `{func_call}` without prior bounds/validation check.")

            # Null Pointer Dereference
            if event_strip.startswith("dereference:") or event_strip.startswith("assign: *"):
                # Null check for assigned pointer (basic)
                m = re.search(r"assign: \*([a-zA-Z0-9_]+)", event_strip)
                var = m.group(1) if m else ""
                if var and not any(
                    'if:' in event_trace[j] and (
                        f"{var} != NULL" in event_trace[j] or f"{var} == NULL" in event_trace[j]
                    )
                    for j in range(max(0, i-5), i)
                ):
                    conflict = True
                    reasons.append(f"Possible null pointer dereference of `{var}`.")

            # Out-of-bounds Array Access
            if "assign:" in event_strip and "[" in event_strip and "]" in event_strip:
                # crude index extraction: array[idx]
                m = re.search(r"\[([^\]]+)\]", event_strip)
                index_var = m.group(1) if m else ""
                if index_var and not any(
                    'if:' in event_trace[j] and (
                        f"{index_var} <" in event_trace[j] or f"{index_var} >=" in event_trace[j]
                    )
                    for j in range(max(0, i-5), i)
                ):
                    conflict = True
                    reasons.append(f"Possible out-of-bounds array access with index `{index_var}`.")

    return conflict, reasons

# %%
conflict_results = test_df.apply(
    lambda row: refined_conflict_detection(row['event_trace_list'], row['pred_label']), axis=1
)
test_df['conflict'] = [c for c, _ in conflict_results]
test_df['conflict_reason'] = [r for _, r in conflict_results]

# %%
test_df.info()
test_df['conflict'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2807 entries, 0 to 2806
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   func              2807 non-null   object
#  1   func_cleaned      2807 non-null   object
#  2   project           2807 non-null   object
#  3   label             2807 non-null   bool
#  4   graph_path        2807 non-null   object
#  5   event_trace       2807 non-null   object
#  6   input             2807 non-null   object
#  7   pred_label        2807 non-null   int64
#  8   pred_prob         2807 non-null   float64
#  9   event_trace_list  2807 non-null   object
#  10  conflict          2807 non-null   bool
#  11  conflict_reason   2807 non-null   object
# dtypes: bool(2), float64(1), int64(1), object(8)
# memory usage: 224.9+ KB
# conflict
# True     1566
# False    1241
# Name: count, dtype: int64

# %%
test_df['conflict'].value_counts()
# Suppose your DataFrame is called df, with columns: 'conflict', 'ground_truth'
false_positives = test_df[(test_df['conflict'] == True) & (test_df['label'] == False)].shape[0]
total_actual_negatives = test_df[test_df['label'] == False].shape[0]

conflict_fpr = false_positives / total_actual_negatives if total_actual_negatives > 0 else 0
print(f"Conflict detection false positive rate: {conflict_fpr:.2%}")
# Out:
# Conflict detection false positive rate: 63.53%

# %%
# True Positives for conflict detection
tp_conflict = test_df[(test_df['label'] == True) & (test_df['conflict'] == True)].shape[0]

# Model false negatives rescued by conflict detection
fn_model_and_conflict = test_df[
    (test_df['label'] == True) &
    (test_df['pred_label'] == 0) &
    (test_df['conflict'] == True)
].shape[0]

print(f"True Positives (conflict): {tp_conflict}")
print(f"Model missed but conflict detected: {fn_model_and_conflict}")
# Out:
# True Positives (conflict): 545
# Model missed but conflict detected: 545

# %% [markdown]
# ------------------------------

# %%
import re

SAFE_POINTER_ASSIGN_RHS = {
    'NULL', '&cpu->env', 'qemu_get_nic_opaque(nc)', 'arg', 'CPU(cpu)',
    'to_qiv(v)', 'to_qov(v)', 'cfg_entry->reg'
}
SAFE_UNKNOWN_VALUES = {
    'NULL', 'stderr', 'errno', 'false', 'true', 'cpu_env', 'env', 'TARGET_PAGE_MASK', 'PATH_MAX', 'EIO'
}
DANGEROUS_FUNCS = {'strcpy', 'strcat', 'sprintf', 'vsprintf', 'memcpy', 'gets', 'system'}

def profile_conflict_detection(event_trace, pred_label):
    conflict = False
    reasons = []
    rule_labels = []

    if isinstance(event_trace, str):
        try:
            event_trace = eval(event_trace)
        except Exception:
            pass

    if pred_label == 0:
        for i, event in enumerate(event_trace):
            event_strip = event.strip()

            # 1. Unsafe Pointer Assignment (with whitelist)
            if event_strip.startswith("assign: *"):
                m = re.search(r"assign: \*.*= (.+)", event_strip)
                rhs = m.group(1).strip() if m else ""
                if rhs not in SAFE_POINTER_ASSIGN_RHS:
                    guarded = any(
                        'if:' in event_trace[j] or 'check' in event_trace[j]
                        for j in range(max(0, i-5), i)
                    )
                    if not guarded:
                        conflict = True
                        reasons.append(f"Unsafe pointer assignment `{event}` not preceded by a safety check, but predicted not vulnerable.")
                        rule_labels.append("unsafe_pointer_assign")

            # 2. Use of <unknown> Value (with whitelist)
            if 'use <unknown>' in event_strip:
                m = re.search(r"use <unknown> ([^ ]+)", event_strip)
                unknown_val = m.group(1).strip() if m else ""
                if unknown_val not in SAFE_UNKNOWN_VALUES:
                    conflict = True
                    reasons.append(f"Use of unknown/untrusted type in `{event}` but predicted not vulnerable.")
                    rule_labels.append("use_unknown_value")

            # 3. Dangerous Buffer/Function Use
            if event_strip.startswith("call:"):
                func_call = event_strip.split(":")[1].strip().split("(")[0]
                if func_call in DANGEROUS_FUNCS:
                    guarded = any(
                        'if:' in event_trace[j] and (
                            'size' in event_trace[j] or 'length' in event_trace[j] or 'bound' in event_trace[j]
                        )
                        for j in range(max(0, i-5), i)
                    )
                    if not guarded:
                        conflict = True
                        reasons.append(f"Dangerous call `{func_call}` without prior bounds/validation check.")
                        rule_labels.append("dangerous_func_call")

            # 4. Null Pointer Dereference
            if event_strip.startswith("dereference:") or event_strip.startswith("assign: *"):
                m = re.search(r"assign: \*([a-zA-Z0-9_]+)", event_strip)
                var = m.group(1) if m else ""
                if var and not any(
                    'if:' in event_trace[j] and (
                        f"{var} != NULL" in event_trace[j] or f"{var} == NULL" in event_trace[j]
                    )
                    for j in range(max(0, i-5), i)
                ):
                    conflict = True
                    reasons.append(f"Possible null pointer dereference of `{var}`.")
                    rule_labels.append("null_pointer_deref")

            # 5. Out-of-bounds Array Access
            if "assign:" in event_strip and "[" in event_strip and "]" in event_strip:
                m = re.search(r"\[([^\]]+)\]", event_strip)
                index_var = m.group(1) if m else ""
                if index_var and not any(
                    'if:' in event_trace[j] and (
                        f"{index_var} <" in event_trace[j] or f"{index_var} >=" in event_trace[j]
                    )
                    for j in range(max(0, i-5), i)
                ):
                    conflict = True
                    reasons.append(f"Possible out-of-bounds array access with index `{index_var}`.")
                    rule_labels.append("oob_array_access")

    return conflict, reasons, list(set(rule_labels))  # dedupe rule labels

# %%
import pandas as pd
from collections import Counter

# Assume df is your DataFrame
rule_fp_counter = Counter()

for idx, row in test_df.iterrows():
    if not row['label']:  # Only look at false positives
        conflict, reasons, rule_labels = profile_conflict_detection(row['event_trace'], row['pred_label'])
        if conflict:
            for rule in rule_labels:
                rule_fp_counter[rule] += 1

print("False positives per rule:", rule_fp_counter)
# Out:
# False positives per rule: Counter({'use_unknown_value': 827, 'null_pointer_deref': 582, 'unsafe_pointer_assign': 514, 'oob_array_access': 283})

# %%
import pandas as pd

# Assume df is your DataFrame and you already have 'label', 'event_trace', 'conflict_reason' columns
# Let's add a 'rule_labels' column using your profiling function

def get_rule_labels(event_trace, pred_label):
    # Use your profile_conflict_detection function above
    _, _, rule_labels = profile_conflict_detection(event_trace, pred_label)
    return rule_labels

# Apply to get rule labels for each row
test_df['rule_labels'] = test_df.apply(lambda row: get_rule_labels(row['event_trace'], row['pred_label']), axis=1)

# Filter false positives where 'use_unknown_value' rule fired
mask = (test_df['label'] == False) & (test_df['conflict'] == True) & (test_df['rule_labels'].apply(lambda x: 'use_unknown_value' in x))

# Print a sample (e.g., 20)
sample_fp = test_df[mask].sample(20, random_state=42) if mask.sum() > 20 else test_df[mask]

for idx, row in sample_fp.iterrows():
    print(f"\nRow: {idx}")
    print(f"Event Trace: {row['event_trace']}")
    print(f"Conflict Reason: {row['conflict_reason']}")
    print('-' * 80)
# Out:
# Row: 614
# Event Trace: ['declare X86CPU* cpu', 'assign: *cpu = X86_CPU(obj)', 'use cpu as X86CPU*', 'call: X86_CPU (X86_CPU(obj))', 'use obj as Object*', 'declare CPUX86State* env', 'assign: *env = &cpu->env', 'use env as CPUX86State*', 'operator: <operator>.addressOf (&cpu->env)', 'field_access: cpu->env', 'use cpu as X86CPU*', 'field: env', 'declare KVMState* s', 'assign: *s = kvm_state', 'use s as KVMState*', 'use <unknown> kvm_state as ANY', 'assign: cpu->host_features = true', 'field_access: cpu->host_features', 'use cpu as X86CPU*', 'field: host_features', 'use <unknown> true as ANY', 'if: "kvm_enabled()"', '    assign: env->cpuid_level = kvm_arch_get_supported_cpuid(s, 0x0, 0, R_EAX)', '    field_access: env->cpuid_level', '    use env as CPUX86State*', '    field: cpuid_level', '    call: kvm_arch_get_supported_cpuid (kvm_arch_get_supported_cpuid(s, 0x0, 0, R_EAX))', '    use s as KVMState*', '    literal: 0x0', '    literal: 0', '    use <unknown> R_EAX as ANY', '    assign: env->cpuid_xlevel = kvm_arch_get_supported_cpuid(s, 0x80000000, 0, R_EAX)', '    field_access: env->cpuid_xlevel', '    use env as CPUX86State*', '    field: cpuid_xlevel', '    call: kvm_arch_get_supported_cpuid (kvm_arch_get_supported_cpuid(s, 0x80000000, 0, R_EAX))', '    use s as KVMState*', '    literal: 0x80000000', '    literal: 0', '    use <unknown> R_EAX as ANY', '    assign: env->cpuid_xlevel2 = kvm_arch_get_supported_cpuid(s, 0xC0000000, 0, R_EAX)', '    field_access: env->cpuid_xlevel2', '    use env as CPUX86State*', '    field: cpuid_xlevel2', '    call: kvm_arch_get_supported_cpuid (kvm_arch_get_supported_cpuid(s, 0xC0000000, 0, R_EAX))', '    use s as KVMState*', '    literal: 0xC0000000', '    literal: 0', '    use <unknown> R_EAX as ANY', 'call: object_property_set_bool (object_property_set_bool(OBJECT(cpu), true, \\"pmu\\", &error_abort))', 'call: OBJECT (OBJECT(cpu))', 'use cpu as X86CPU*', 'use <unknown> true as ANY', 'literal: \\"pmu\\', 'operator: <operator>.addressOf (&error_abort)', 'use <unknown> error_abort as ANY', 'declare ANY error_abort', 'declare ANY true', 'declare ANY R_EAX', 'declare ANY kvm_state']
# Conflict Reason: ['Unsafe pointer assignment `assign: *cpu = X86_CPU(obj)` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `cpu`.', 'Possible null pointer dereference of `env`.', 'Unsafe pointer assignment `assign: *s = kvm_state` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `s`.', 'Use of unknown/untrusted type in `use <unknown> kvm_state as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> R_EAX as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> R_EAX as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> R_EAX as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> error_abort as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 2576
# Event Trace: ['declare char* filename', 'declare pflash_t* fl', 'declare MemoryRegion* system_memory', 'assign: *system_memory = get_system_memory()', 'use system_memory as MemoryRegion*', 'call: get_system_memory (get_system_memory())', 'declare MemoryRegion* ram', 'assign: *ram = g_new(MemoryRegion, 1)', 'use ram as MemoryRegion*', 'call: g_new (g_new(MemoryRegion, 1))', 'use <unknown> MemoryRegion as ANY', 'literal: 1', 'declare MemoryRegion* bios', 'declare MemoryRegion* bios_alias', 'assign: *bios_alias = g_new(MemoryRegion, 1)', 'use bios_alias as MemoryRegion*', 'call: g_new (g_new(MemoryRegion, 1))', 'use <unknown> MemoryRegion as ANY', 'literal: 1', 'declare target_long bios_size', 'declare int64_t kernel_entry', 'declare PCIBus* pci_bus', 'declare ISABus* isa_bus', 'declare CPUState* env', 'declare qemu_irq* isa_irq', 'declare qemu_irq* cpu_exit_irq', 'declare int piix4_devfn', 'declare i2c_bus* smbus', 'declare int i', 'declare DriveInfo* dinfo', 'declare DriveInfo**[] hd', 'assign: *hd[MAX_IDE_BUS * MAX_IDE_DEVS]', 'use hd as DriveInfo**[]', 'operator: <operator>.alloc (*hd[MAX_IDE_BUS * MAX_IDE_DEVS])', 'use DriveInfo**[] as DriveInfo**[]', 'operator: <operator>.multiplication (MAX_IDE_BUS * MAX_IDE_DEVS)', 'use <unknown> MAX_IDE_BUS as ANY', 'use <unknown> MAX_IDE_DEVS as ANY', 'declare DriveInfo**[] fd', 'assign: *fd[MAX_FD]', 'use fd as DriveInfo**[]', 'operator: <operator>.alloc (*fd[MAX_FD])', 'use DriveInfo**[] as DriveInfo**[]', 'use <unknown> MAX_FD as ANY', 'declare int fl_idx', 'assign: fl_idx = 0', 'use fl_idx as int', 'literal: 0', 'declare int fl_sectors', 'assign: fl_sectors = 0', 'use fl_sectors as int', 'literal: 0', 'declare int be', 'declare DeviceState* dev', 'assign: *dev = qdev_create(NULL, \\"mips-malta\\")', 'use dev as DeviceState*', 'call: qdev_create (qdev_create(NULL, \\"mips-malta\\"))', 'use <unknown> NULL as ANY', 'literal: \\"mips-malta\\', 'declare MaltaState* s', 'assign: *s = DO_UPCAST(MaltaState, busdev.qdev, dev)', 'use s as MaltaState*', 'call: DO_UPCAST (DO_UPCAST(MaltaState, busdev.qdev, dev))', 'use <unknown> MaltaState as ANY', 'operator: <operator>.fieldAccess (busdev.qdev)', 'use <unknown> busdev as ANY', 'field: qdev', 'use dev as DeviceState*', 'call: qdev_init_nofail (qdev_init_nofail(dev))', 'use dev as DeviceState*', 'for: for (i = 0;i < 3;i++)', '    if: "!serial_hds[i]"', '        declare char[32] label', '        assign: label[32]', '        use label as char[32]', '        operator: <operator>.alloc (label[32])', '        use char[32] as char[32]', '        literal: 32', '        call: snprintf (snprintf(label, sizeof(label), \\"serial%d\\", i))', '        use label as char[32]', '        operator: <operator>.sizeOf (sizeof(label))', '        use label as char[32]', '        literal: \\"serial%d\\', '        use i as int', '        assign: serial_hds[i] = qemu_chr_new(label, \\"null\\", NULL)', '        operator: <operator>.indirectIndexAccess (serial_hds[i])', '        use <unknown> serial_hds as ANY', '        use i as int', '        call: qemu_chr_new (qemu_chr_new(label, \\"null\\", NULL))', '        use label as char[32]', '        literal: \\"null\\', '        use <unknown> NULL as ANY', 'declare ANY NULL', 'declare ANY serial_hds', 'declare ANY busdev', 'declare ANY MaltaState', 'declare ANY MAX_FD', 'declare ANY MAX_IDE_DEVS', 'declare ANY MAX_IDE_BUS', 'declare ANY MemoryRegion']
# Conflict Reason: ['Unsafe pointer assignment `assign: *system_memory = get_system_memory()` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `system_memory`.', 'Unsafe pointer assignment `assign: *ram = g_new(MemoryRegion, 1)` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `ram`.', 'Use of unknown/untrusted type in `use <unknown> MemoryRegion as ANY` but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *bios_alias = g_new(MemoryRegion, 1)` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `bios_alias`.', 'Use of unknown/untrusted type in `use <unknown> MemoryRegion as ANY` but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *hd[MAX_IDE_BUS * MAX_IDE_DEVS]` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `hd`.', 'Possible out-of-bounds array access with index `MAX_IDE_BUS * MAX_IDE_DEVS`.', 'Use of unknown/untrusted type in `use <unknown> MAX_IDE_BUS as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> MAX_IDE_DEVS as ANY` but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *fd[MAX_FD]` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `fd`.', 'Possible out-of-bounds array access with index `MAX_FD`.', 'Use of unknown/untrusted type in `use <unknown> MAX_FD as ANY` but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *dev = qdev_create(NULL, \\"mips-malta\\")` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `dev`.', 'Unsafe pointer assignment `assign: *s = DO_UPCAST(MaltaState, busdev.qdev, dev)` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `s`.', 'Use of unknown/untrusted type in `use <unknown> MaltaState as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> busdev as ANY` but predicted not vulnerable.', 'Possible out-of-bounds array access with index `32`.', 'Possible out-of-bounds array access with index `i`.', 'Use of unknown/untrusted type in `        use <unknown> serial_hds as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 851
# Event Trace: ['declare AcpiSdtTable* temp', 'declare GError* error', 'assign: *error = NULL', 'use error as GError*', 'use <unknown> NULL as ANY', 'declare GString* command_line', 'assign: *command_line = g_string_new(\\"\'iasl\' \\")', 'use command_line as GString*', 'call: g_string_new (g_string_new(\\"\'iasl\' \\"))', 'literal: \\"\'iasl\' \\', 'declare gint fd', 'declare gchar* out', 'declare gchar* out_err', 'declare gboolean ret', 'declare int i', 'assign: fd = g_file_open_tmp(\\"asl-XXXXXX.dsl\\", &sdt->asl_file, &error)', 'use fd as gint', 'call: g_file_open_tmp (g_file_open_tmp(\\"asl-XXXXXX.dsl\\", &sdt->asl_file, &error))', 'literal: \\"asl-XXXXXX.dsl\\', 'operator: <operator>.addressOf (&sdt->asl_file)', 'field_access: sdt->asl_file', 'use sdt as AcpiSdtTable*', 'field: asl_file', 'operator: <operator>.addressOf (&error)', 'use error as GError*', 'call: g_assert_no_error (g_assert_no_error(error))', 'use error as GError*', 'call: close (close(fd))', 'use fd as gint', 'call: g_string_append_printf (g_string_append_printf(command_line, \\"-p %s \\", sdt->asl_file))', 'use command_line as GString*', 'literal: \\"-p %s \\', 'field_access: sdt->asl_file', 'use sdt as AcpiSdtTable*', 'field: asl_file', 'for: for (i = 0;i < 2;++i)', '    assign: temp = &g_array_index(sdts, AcpiSdtTable, i)', '    use temp as AcpiSdtTable*', '    operator: <operator>.addressOf (&g_array_index(sdts, AcpiSdtTable, i))', '    call: g_array_index (g_array_index(sdts, AcpiSdtTable, i))', '    use sdts as GArray*', '    use <unknown> AcpiSdtTable as ANY', '    use i as int', '    call: g_string_append_printf (g_string_append_printf(command_line, \\"-e %s \\", temp->aml_file))', '    use command_line as GString*', '    literal: \\"-e %s \\', '    field_access: temp->aml_file', '    use temp as AcpiSdtTable*', '    field: aml_file', 'call: g_string_append_printf (g_string_append_printf(command_line, \\"-d %s\\", sdt->aml_file))', 'use command_line as GString*', 'literal: \\"-d %s\\', 'field_access: sdt->aml_file', 'use sdt as AcpiSdtTable*', 'field: aml_file', 'call: g_spawn_command_line_sync (g_spawn_command_line_sync(command_line->str, &out, &out_err, NULL, &error))', 'field_access: command_line->str', 'use command_line as GString*', 'field: str', 'operator: <operator>.addressOf (&out)', 'use out as gchar*', 'operator: <operator>.addressOf (&out_err)', 'use out_err as gchar*', 'use <unknown> NULL as ANY', 'operator: <operator>.addressOf (&error)', 'use error as GError*', 'call: g_assert_no_error (g_assert_no_error(error))', 'use error as GError*', 'assign: ret = g_file_get_contents(sdt->asl_file, (gchar **)&sdt->asl, &sdt->asl_len, &error)', 'use ret as gboolean', 'call: g_file_get_contents (g_file_get_contents(sdt->asl_file, (gchar **)&sdt->asl, &sdt->asl_len, &error))', 'field_access: sdt->asl_file', 'use sdt as AcpiSdtTable*', 'field: asl_file', 'operator: <operator>.cast ((gchar **)&sdt->asl)', 'operator: <operator>.addressOf (&sdt->asl)', 'field_access: sdt->asl', 'use sdt as AcpiSdtTable*', 'field: asl', 'operator: <operator>.addressOf (&sdt->asl_len)', 'field_access: sdt->asl_len', 'use sdt as AcpiSdtTable*', 'field: asl_len', 'operator: <operator>.addressOf (&error)', 'use error as GError*', 'call: g_assert (g_assert(ret))', 'use ret as gboolean', 'call: g_assert_no_error (g_assert_no_error(error))', 'use error as GError*', 'call: g_assert (g_assert(sdt->asl_len))', 'field_access: sdt->asl_len', 'use sdt as AcpiSdtTable*', 'field: asl_len', 'call: g_free (g_free(out))', 'use out as gchar*', 'call: g_free (g_free(out_err))', 'use out_err as gchar*', 'call: g_string_free (g_string_free(command_line, true))', 'use command_line as GString*', 'use <unknown> true as ANY', 'declare ANY true', 'declare ANY NULL', 'declare ANY AcpiSdtTable']
# Conflict Reason: ['Possible null pointer dereference of `error`.', 'Unsafe pointer assignment `assign: *command_line = g_string_new(\\"\'iasl\' \\")` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `command_line`.', 'Use of unknown/untrusted type in `    use <unknown> AcpiSdtTable as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 1108
# Event Trace: ['declare SCSIDiskReq* r', 'assign: *r = DO_UPCAST(SCSIDiskReq, req, req)', 'use r as SCSIDiskReq*', 'call: DO_UPCAST (DO_UPCAST(SCSIDiskReq, req, req))', 'use <unknown> SCSIDiskReq as ANY', 'use req as SCSIRequest*', 'use req as SCSIRequest*', 'if: "r->iov.iov_len"', '    declare int buflen', '    assign: buflen = r->iov.iov_len', '    use buflen as int', '    operator: <operator>.fieldAccess (r->iov.iov_len)', '    field_access: r->iov', '    use r as SCSIDiskReq*', '    field: iov', '    field: iov_len', '    call: DPRINTF (DPRINTF(\\"Write buf_len=%zd\\\\n\\", buflen))', '    literal: \\"Write buf_len=%zd\\\\n\\', '    use buflen as int', '    assign: r->iov.iov_len = 0', '    operator: <operator>.fieldAccess (r->iov.iov_len)', '    field_access: r->iov', '    use r as SCSIDiskReq*', '    field: iov', '    field: iov_len', '    literal: 0', '    call: scsi_req_data (scsi_req_data(&r->req, buflen))', '    operator: <operator>.addressOf (&r->req)', '    field_access: r->req', '    use r as SCSIDiskReq*', '    field: req', '    use buflen as int', '    return: return;', 'switch: switch (req->cmd.buf[0]) {\ncase MODE_SELECT: case MODE_SELECT_10: /* This also clears the sense buffer for REQUEST SENSE. */ scsi_req_complete(&r->req, GOOD); break; default: abort(); }', '    use <unknown> MODE_SELECT as ANY', '    use <unknown> MODE_SELECT_10 as ANY', '    call: scsi_req_complete (scsi_req_complete(&r->req, GOOD))', '    operator: <operator>.addressOf (&r->req)', '    field_access: r->req', '    use r as SCSIDiskReq*', '    field: req', '    use <unknown> GOOD as ANY', '    control: break;', '    call: abort (abort())', 'declare ANY GOOD', 'declare ANY MODE_SELECT_10', 'declare ANY MODE_SELECT', 'declare ANY SCSIDiskReq']
# Conflict Reason: ['Unsafe pointer assignment `assign: *r = DO_UPCAST(SCSIDiskReq, req, req)` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `r`.', 'Use of unknown/untrusted type in `use <unknown> SCSIDiskReq as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> MODE_SELECT as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> MODE_SELECT_10 as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> GOOD as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 539
# Event Trace: ['declare unsigned int hash', 'declare QDictEntry* entry', 'assign: hash = tdb_hash(key) % QDICT_HASH_SIZE', 'use hash as unsigned int', 'operator: <operator>.modulo (tdb_hash(key) % QDICT_HASH_SIZE)', 'call: tdb_hash (tdb_hash(key))', 'use key as char*', 'use <unknown> QDICT_HASH_SIZE as ANY', 'assign: entry = qdict_find(qdict, key, hash)', 'use entry as QDictEntry*', 'call: qdict_find (qdict_find(qdict, key, hash))', 'use qdict as QDict*', 'use key as char*', 'use hash as unsigned int', 'if: "entry"', '    call: qobject_decref (qobject_decref(entry->value))', '    field_access: entry->value', '    use entry as QDictEntry*', '    field: value', '    assign: entry->value = value', '    field_access: entry->value', '    use entry as QDictEntry*', '    field: value', '    use value as QObject*', 'else', '    else', '        assign: entry = alloc_entry(key, value)', '        use entry as QDictEntry*', '        call: alloc_entry (alloc_entry(key, value))', '        use key as char*', '        use value as QObject*', '        call: LIST_INSERT_HEAD (LIST_INSERT_HEAD(&qdict->table[hash], entry, next))', '        operator: <operator>.addressOf (&qdict->table[hash])', '        operator: <operator>.indirectIndexAccess (qdict->table[hash])', '        field_access: qdict->table', '        use qdict as QDict*', '        field: table', '        use hash as unsigned int', '        use entry as QDictEntry*', '        use <unknown> next as ANY', 'operator: <operator>.postIncrement (qdict->size++)', 'field_access: qdict->size', 'use qdict as QDict*', 'field: size', 'declare ANY next', 'declare ANY QDICT_HASH_SIZE']
# Conflict Reason: ['Use of unknown/untrusted type in `use <unknown> QDICT_HASH_SIZE as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> next as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 750
# Event Trace: ['declare CPUState* env', 'declare int kernel_size', 'declare uint64_t elf_entry', 'declare target_ulong entry', 'declare qemu_irq* pic', 'if: "!cpu_model"', '    assign: cpu_model = \\"m5208\\', '    use cpu_model as char*', '    literal: \\"m5208\\', 'assign: env = cpu_init(cpu_model)', 'use env as CPUState*', 'call: cpu_init (cpu_init(cpu_model))', 'use cpu_model as char*', 'if: "!env"', '    call: fprintf (fprintf(stderr, \\"Unable to find m68k CPU definition\\\\n\\"))', '    use <unknown> stderr as ANY', '    literal: \\"Unable to find m68k CPU definition\\\\n\\', '    call: exit (exit(1))', '    literal: 1', 'assign: env->vbr = 0', 'field_access: env->vbr', 'use env as CPUState*', 'field: vbr', 'literal: 0', 'call: cpu_register_physical_memory (cpu_register_physical_memory(0x40000000, ram_size, qemu_ram_alloc(ram_size) | IO_MEM_RAM))', 'literal: 0x40000000', 'use ram_size as ram_addr_t', 'condition: qemu_ram_alloc(ram_size) | IO_MEM_RAM', 'call: qemu_ram_alloc (qemu_ram_alloc(ram_size))', 'use ram_size as ram_addr_t', 'use <unknown> IO_MEM_RAM as ANY', 'call: cpu_register_physical_memory (cpu_register_physical_memory(0x80000000, 16384, qemu_ram_alloc(16384) | IO_MEM_RAM))', 'literal: 0x80000000', 'literal: 16384', 'condition: qemu_ram_alloc(16384) | IO_MEM_RAM', 'call: qemu_ram_alloc (qemu_ram_alloc(16384))', 'literal: 16384', 'use <unknown> IO_MEM_RAM as ANY', 'assign: pic = mcf_intc_init(0xfc048000, env)', 'use pic as qemu_irq*', 'call: mcf_intc_init (mcf_intc_init(0xfc048000, env))', 'literal: 0xfc048000', 'use env as CPUState*', 'call: mcf_uart_mm_init (mcf_uart_mm_init(0xfc060000, pic[26], serial_hds[0]))', 'literal: 0xfc060000', 'operator: <operator>.indirectIndexAccess (pic[26])', 'use pic as qemu_irq*', 'literal: 26', 'operator: <operator>.indirectIndexAccess (serial_hds[0])', 'use <unknown> serial_hds as ANY', 'literal: 0', 'call: mcf_uart_mm_init (mcf_uart_mm_init(0xfc064000, pic[27], serial_hds[1]))', 'literal: 0xfc064000', 'operator: <operator>.indirectIndexAccess (pic[27])', 'use pic as qemu_irq*', 'literal: 27', 'operator: <operator>.indirectIndexAccess (serial_hds[1])', 'use <unknown> serial_hds as ANY', 'literal: 1', 'call: mcf_uart_mm_init (mcf_uart_mm_init(0xfc068000, pic[28], serial_hds[2]))', 'literal: 0xfc068000', 'operator: <operator>.indirectIndexAccess (pic[28])', 'use pic as qemu_irq*', 'literal: 28', 'operator: <operator>.indirectIndexAccess (serial_hds[2])', 'use <unknown> serial_hds as ANY', 'literal: 2', 'call: mcf5208_sys_init (mcf5208_sys_init(pic))', 'use pic as qemu_irq*', 'if: "nb_nics > 1"', '    call: fprintf (fprintf(stderr, \\"Too many NICs\\\\n\\"))', '    use <unknown> stderr as ANY', '    literal: \\"Too many NICs\\\\n\\', '    call: exit (exit(1))', '    literal: 1', 'if: "nd_table[0].vlan"', '    if: "nd_table[0].model == NULL || strcmp(nd_table[0].model, \\"mcf_fec\\") == 0"', '        call: mcf_fec_init (mcf_fec_init(&nd_table[0], 0xfc030000, pic + 36))', '        operator: <operator>.addressOf (&nd_table[0])', '        operator: <operator>.indirectIndexAccess (nd_table[0])', '        use <unknown> nd_table as ANY', '        literal: 0', '        literal: 0xfc030000', '        operator: <operator>.addition (pic + 36)', '        use pic as qemu_irq*', '        literal: 36', '    else', '        else', '            if: "strcmp(nd_table[0].model, \\"?\\") == 0"', '                call: fprintf (fprintf(stderr, \\"qemu: Supported NICs: mcf_fec\\\\n\\"))', '                use <unknown> stderr as ANY', '                literal: \\"qemu: Supported NICs: mcf_fec\\\\n\\', '                call: exit (exit (1))', '                literal: 1', '            else', '                else', '                    call: fprintf (fprintf(stderr, \\"qemu: Unsupported NIC: %s\\\\n\\", nd_table[0].model))', '                    use <unknown> stderr as ANY', '                    literal: \\"qemu: Unsupported NIC: %s\\\\n\\', '                    operator: <operator>.fieldAccess (nd_tab ...
# Conflict Reason: ['Use of unknown/untrusted type in `use <unknown> IO_MEM_RAM as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> IO_MEM_RAM as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> serial_hds as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> serial_hds as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> serial_hds as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> nd_table as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                    use <unknown> nd_table as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> phys_ram_base as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 2758
# Event Trace: ['declare IOMMUState* s', 'assign: *s = opaque', 'use s as IOMMUState*', 'use opaque as void*', 'declare target_phys_addr_t saddr', 'declare uint32_t ret', 'assign: saddr = (addr - s->addr) >> 2', 'use saddr as target_phys_addr_t', 'operator: <operator>.arithmeticShiftRight ((addr - s->addr) >> 2)', 'operator: <operator>.subtraction (addr - s->addr)', 'use addr as target_phys_addr_t', 'field_access: s->addr', 'use s as IOMMUState*', 'field: addr', 'literal: 2', 'switch: switch (saddr) {\ndefault: ret = s->regs[saddr]; break; case IOMMU_AFAR: case IOMMU_AFSR: ret = s->regs[saddr]; qemu_irq_lower(s->irq); break; }', '    assign: ret = s->regs[saddr]', '    use ret as uint32_t', '    operator: <operator>.indirectIndexAccess (s->regs[saddr])', '    field_access: s->regs', '    use s as IOMMUState*', '    field: regs', '    use saddr as target_phys_addr_t', '    control: break;', '    use <unknown> IOMMU_AFAR as ANY', '    use <unknown> IOMMU_AFSR as ANY', '    assign: ret = s->regs[saddr]', '    use ret as uint32_t', '    operator: <operator>.indirectIndexAccess (s->regs[saddr])', '    field_access: s->regs', '    use s as IOMMUState*', '    field: regs', '    use saddr as target_phys_addr_t', '    call: qemu_irq_lower (qemu_irq_lower(s->irq))', '    field_access: s->irq', '    use s as IOMMUState*', '    field: irq', '    control: break;', 'call: DPRINTF (DPRINTF(\\"read reg[%d] = %x\\\\n\\", (int)saddr, ret))', 'literal: \\"read reg[%d] = %x\\\\n\\', 'operator: <operator>.cast ((int)saddr)', 'use saddr as target_phys_addr_t', 'use ret as uint32_t', 'return: return ret;', 'use ret as uint32_t', 'declare ANY IOMMU_AFSR', 'declare ANY IOMMU_AFAR']
# Conflict Reason: ['Unsafe pointer assignment `assign: *s = opaque` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `s`.', 'Possible out-of-bounds array access with index `saddr`.', 'Use of unknown/untrusted type in `    use <unknown> IOMMU_AFAR as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> IOMMU_AFSR as ANY` but predicted not vulnerable.', 'Possible out-of-bounds array access with index `saddr`.']
# --------------------------------------------------------------------------------
#
# Row: 265
# Event Trace: ['declare char* cpu_model', 'assign: *cpu_model = args->cpu_model', 'use cpu_model as char*', 'field_access: args->cpu_model', 'use args as QEMUMachineInitArgs*', 'field: cpu_model', 'declare char* kernel_filename', 'assign: *kernel_filename = args->kernel_filename', 'use kernel_filename as char*', 'field_access: args->kernel_filename', 'use args as QEMUMachineInitArgs*', 'field: kernel_filename', 'declare char* kernel_cmdline', 'assign: *kernel_cmdline = args->kernel_cmdline', 'use kernel_cmdline as char*', 'field_access: args->kernel_cmdline', 'use args as QEMUMachineInitArgs*', 'field: kernel_cmdline', 'declare char* initrd_filename', 'assign: *initrd_filename = args->initrd_filename', 'use initrd_filename as char*', 'field_access: args->initrd_filename', 'use args as QEMUMachineInitArgs*', 'field: initrd_filename', 'declare LM32CPU* cpu', 'declare CPULM32State* env', 'declare DriveInfo* dinfo', 'declare MemoryRegion* address_space_mem', 'assign: *address_space_mem = get_system_memory()', 'use address_space_mem as MemoryRegion*', 'call: get_system_memory (get_system_memory())', 'declare MemoryRegion* phys_ram', 'assign: *phys_ram = g_new(MemoryRegion, 1)', 'use phys_ram as MemoryRegion*', 'call: g_new (g_new(MemoryRegion, 1))', 'use <unknown> MemoryRegion as ANY', 'literal: 1', 'declare qemu_irq* cpu_irq', 'declare qemu_irq[32] irq', 'assign: irq[32]', 'use irq as qemu_irq[32]', 'operator: <operator>.alloc (irq[32])', 'use qemu_irq[32] as qemu_irq[32]', 'literal: 32', 'declare HWSetup* hw', 'declare ResetInfo* reset_info', 'declare int i', 'declare target_phys_addr_t flash_base', 'assign: flash_base = 0x04000000', 'use flash_base as target_phys_addr_t', 'literal: 0x04000000', 'declare size_t flash_sector_size', 'assign: flash_sector_size = 256 * 1024', 'use flash_sector_size as size_t', 'operator: <operator>.multiplication (256 * 1024)', 'literal: 256', 'literal: 1024', 'declare size_t flash_size', 'assign: flash_size = 32 * 1024 * 1024', 'use flash_size as size_t', 'operator: <operator>.multiplication (32 * 1024 * 1024)', 'operator: <operator>.multiplication (32 * 1024)', 'literal: 32', 'literal: 1024', 'literal: 1024', 'declare target_phys_addr_t ram_base', 'assign: ram_base = 0x08000000', 'use ram_base as target_phys_addr_t', 'literal: 0x08000000', 'declare size_t ram_size', 'assign: ram_size = 64 * 1024 * 1024', 'use ram_size as size_t', 'operator: <operator>.multiplication (64 * 1024 * 1024)', 'operator: <operator>.multiplication (64 * 1024)', 'literal: 64', 'literal: 1024', 'literal: 1024', 'declare target_phys_addr_t uart0_base', 'assign: uart0_base = 0x80000000', 'use uart0_base as target_phys_addr_t', 'literal: 0x80000000', 'declare target_phys_addr_t timer0_base', 'assign: timer0_base = 0x80002000', 'use timer0_base as target_phys_addr_t', 'literal: 0x80002000', 'declare target_phys_addr_t timer1_base', 'assign: timer1_base = 0x80010000', 'use timer1_base as target_phys_addr_t', 'literal: 0x80010000', 'declare target_phys_addr_t timer2_base', 'assign: timer2_base = 0x80012000', 'use timer2_base as target_phys_addr_t', 'literal: 0x80012000', 'declare int uart0_irq', 'assign: uart0_irq = 0', 'use uart0_irq as int', 'literal: 0', 'declare int timer0_irq', 'assign: timer0_irq = 1', 'use timer0_irq as int', 'literal: 1', 'declare int timer1_irq', 'assign: timer1_irq = 20', 'use timer1_irq as int', 'literal: 20', 'declare int timer2_irq', 'assign: timer2_irq = 21', 'use timer2_irq as int', 'literal: 21', 'declare target_phys_addr_t hwsetup_base', 'assign: hwsetup_base = 0x0bffe000', 'use hwsetup_base as target_phys_addr_t', 'literal: 0x0bffe000', 'declare target_phys_addr_t cmdline_base', 'assign: cmdline_base = 0x0bfff000', 'use cmdline_base as target_phys_addr_t', 'literal: 0x0bfff000', 'declare target_phys_addr_t initrd_base', 'assign: initrd_base = 0x08400000', 'use initrd_base as target_phys_addr_t', 'literal: 0x08400000', 'declare size_t initrd_max', 'assign: initrd_max = 0x01000000', 'use initrd_max  ...
# Conflict Reason: ['Unsafe pointer assignment `assign: *cpu_model = args->cpu_model` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `cpu_model`.', 'Unsafe pointer assignment `assign: *kernel_filename = args->kernel_filename` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `kernel_filename`.', 'Unsafe pointer assignment `assign: *kernel_cmdline = args->kernel_cmdline` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `kernel_cmdline`.', 'Unsafe pointer assignment `assign: *initrd_filename = args->initrd_filename` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `initrd_filename`.', 'Unsafe pointer assignment `assign: *address_space_mem = get_system_memory()` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `address_space_mem`.', 'Unsafe pointer assignment `assign: *phys_ram = g_new(MemoryRegion, 1)` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `phys_ram`.', 'Use of unknown/untrusted type in `use <unknown> MemoryRegion as ANY` but predicted not vulnerable.', 'Possible out-of-bounds array access with index `32`.', 'Use of unknown/untrusted type in `use <unknown> IF_PFLASH as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> cpu_irq_handler as ANY` but predicted not vulnerable.', 'Possible out-of-bounds array access with index `i`.', 'Use of unknown/untrusted type in `    use <unknown> ELF_MACHINE as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> TARGET_PAGE_SIZE as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> main_cpu_reset as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 831
# Event Trace: ['declare PowerPCCPU* cpu', 'assign: *cpu = opaque', 'use cpu as PowerPCCPU*', 'use opaque as void*', 'declare CPUPPCState* env', 'assign: *env = &cpu->env', 'use env as CPUPPCState*', 'operator: <operator>.addressOf (&cpu->env)', 'field_access: cpu->env', 'use cpu as PowerPCCPU*', 'field: env', 'call: <operators>.assignmentOr (env->spr[SPR_BOOKE_TSR] |= TSR_DIS)', 'operator: <operator>.indirectIndexAccess (env->spr[SPR_BOOKE_TSR])', 'field_access: env->spr', 'use env as CPUPPCState*', 'field: spr', 'use <unknown> SPR_BOOKE_TSR as ANY', 'use <unknown> TSR_DIS as ANY', 'call: booke_update_irq (booke_update_irq(cpu))', 'use cpu as PowerPCCPU*', 'if: "env->spr[SPR_BOOKE_TCR] & TCR_ARE"', '    call: cpu_ppc_store_decr (cpu_ppc_store_decr(env, env->spr[SPR_BOOKE_DECAR]))', '    use env as CPUPPCState*', '    operator: <operator>.indirectIndexAccess (env->spr[SPR_BOOKE_DECAR])', '    field_access: env->spr', '    use env as CPUPPCState*', '    field: spr', '    use <unknown> SPR_BOOKE_DECAR as ANY', 'declare ANY SPR_BOOKE_DECAR', 'declare ANY TCR_ARE', 'declare ANY SPR_BOOKE_TCR', 'declare ANY TSR_DIS', 'declare ANY SPR_BOOKE_TSR']
# Conflict Reason: ['Unsafe pointer assignment `assign: *cpu = opaque` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `cpu`.', 'Possible null pointer dereference of `env`.', 'Use of unknown/untrusted type in `use <unknown> SPR_BOOKE_TSR as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> TSR_DIS as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> SPR_BOOKE_DECAR as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 2578
# Event Trace: ['declare char ch', 'declare char* s', 'declare size_t len', 'call: __coverity_string_null_sink__ (__coverity_string_null_sink__(format))', 'use format as char*', 'call: __coverity_string_size_sink__ (__coverity_string_size_sink__(format))', 'use format as char*', 'assign: ch = *format', 'use ch as char', 'operator: <operator>.indirection (*format)', 'use format as char*', 'assign: s = __coverity_alloc_nosize__()', 'use s as char*', 'call: __coverity_alloc_nosize__ (__coverity_alloc_nosize__())', 'call: __coverity_writeall__ (__coverity_writeall__(s))', 'use s as char*', 'call: __coverity_mark_as_afm_allocated__ (__coverity_mark_as_afm_allocated__(s, AFM_free))', 'use s as char*', 'use <unknown> AFM_free as ANY', 'return: return s;', 'use s as char*', 'declare ANY AFM_free']
# Conflict Reason: ['Use of unknown/untrusted type in `use <unknown> AFM_free as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 716
# Event Trace: ['call: trace_usb_xhci_port_reset (trace_usb_xhci_port_reset(port->portnr))', 'field_access: port->portnr', 'use port as XHCIPort*', 'field: portnr', 'if: "!xhci_port_have_device(port)"', '    return: return;', 'call: usb_device_reset (usb_device_reset(port->uport->dev))', 'field_access: port->uport->dev', 'field_access: port->uport', 'use port as XHCIPort*', 'field: uport', 'field: dev', 'switch: switch (port->uport->dev->speed) {\ncase USB_SPEED_LOW: case USB_SPEED_FULL: case USB_SPEED_HIGH: set_field(&port->portsc, PLS_U0, PORTSC_PLS); trace_usb_xhci_port_link(port->portnr, PLS_U0); port->portsc |= PORTSC_PED; break; }', '    use <unknown> USB_SPEED_LOW as ANY', '    use <unknown> USB_SPEED_FULL as ANY', '    use <unknown> USB_SPEED_HIGH as ANY', '    call: set_field (set_field(&port->portsc, PLS_U0, PORTSC_PLS))', '    operator: <operator>.addressOf (&port->portsc)', '    field_access: port->portsc', '    use port as XHCIPort*', '    field: portsc', '    use <unknown> PLS_U0 as ANY', '    use <unknown> PORTSC_PLS as ANY', '    call: trace_usb_xhci_port_link (trace_usb_xhci_port_link(port->portnr, PLS_U0))', '    field_access: port->portnr', '    use port as XHCIPort*', '    field: portnr', '    use <unknown> PLS_U0 as ANY', '    call: <operators>.assignmentOr (port->portsc |= PORTSC_PED)', '    field_access: port->portsc', '    use port as XHCIPort*', '    field: portsc', '    use <unknown> PORTSC_PED as ANY', '    control: break;', 'call: <operators>.assignmentAnd (port->portsc &= ~PORTSC_PR)', 'field_access: port->portsc', 'use port as XHCIPort*', 'field: portsc', 'operator: <operator>.not (~PORTSC_PR)', 'use <unknown> PORTSC_PR as ANY', 'call: xhci_port_notify (xhci_port_notify(port, PORTSC_PRC))', 'use port as XHCIPort*', 'use <unknown> PORTSC_PRC as ANY', 'declare ANY PORTSC_PRC', 'declare ANY PORTSC_PR', 'declare ANY PORTSC_PED', 'declare ANY PLS_U0', 'declare ANY PORTSC_PLS', 'declare ANY USB_SPEED_HIGH', 'declare ANY USB_SPEED_FULL', 'declare ANY USB_SPEED_LOW']
# Conflict Reason: ['Use of unknown/untrusted type in `    use <unknown> USB_SPEED_LOW as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> USB_SPEED_FULL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> USB_SPEED_HIGH as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> PLS_U0 as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> PORTSC_PLS as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> PLS_U0 as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> PORTSC_PED as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> PORTSC_PR as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> PORTSC_PRC as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 434
# Event Trace: ['declare TCGv addr', 'if: "ra == 31"', '    return: return NO_EXIT;', '    use <unknown> NO_EXIT as ANY', 'declare ANY NO_EXIT']
# Conflict Reason: ['Use of unknown/untrusted type in `    use <unknown> NO_EXIT as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 2609
# Event Trace: ['declare char* home', 'declare char* knh_file', 'assign: *knh_file = NULL', 'use knh_file as char*', 'use <unknown> NULL as ANY', 'declare LIBSSH2_KNOWNHOSTS* knh', 'assign: *knh = NULL', 'use knh as LIBSSH2_KNOWNHOSTS*', 'use <unknown> NULL as ANY', 'declare libssh2_knownhost* found', 'declare int ret', 'declare int r', 'declare char* hostkey', 'declare size_t len', 'declare int type', 'assign: hostkey = libssh2_session_hostkey(s->session, &len, &type)', 'use hostkey as char*', 'call: libssh2_session_hostkey (libssh2_session_hostkey(s->session, &len, &type))', 'field_access: s->session', 'use s as BDRVSSHState*', 'field: session', 'operator: <operator>.addressOf (&len)', 'use len as size_t', 'operator: <operator>.addressOf (&type)', 'use type as int', 'if: "!hostkey"', '    assign: ret = -EINVAL', '    use ret as int', '    operator: <operator>.minus (-EINVAL)', '    use <unknown> EINVAL as ANY', '    call: session_error_report (session_error_report(s, \\"failed to read remote host key\\"))', '    use s as BDRVSSHState*', '    literal: \\"failed to read remote host key\\', '    control: goto out;', 'assign: knh = libssh2_knownhost_init(s->session)', 'use knh as LIBSSH2_KNOWNHOSTS*', 'call: libssh2_knownhost_init (libssh2_knownhost_init(s->session))', 'field_access: s->session', 'use s as BDRVSSHState*', 'field: session', 'if: "!knh"', '    assign: ret = -EINVAL', '    use ret as int', '    operator: <operator>.minus (-EINVAL)', '    use <unknown> EINVAL as ANY', '    call: session_error_report (session_error_report(s, \\"failed to initialize known hosts support\\"))', '    use s as BDRVSSHState*', '    literal: \\"failed to initialize known hosts support\\', '    control: goto out;', 'assign: home = getenv(\\"HOME\\")', 'use home as char*', 'call: getenv (getenv(\\"HOME\\"))', 'literal: \\"HOME\\', 'if: "home"', '    assign: knh_file = g_strdup_printf(\\"%s/.ssh/known_hosts\\", home)', '    use knh_file as char*', '    call: g_strdup_printf (g_strdup_printf(\\"%s/.ssh/known_hosts\\", home))', '    literal: \\"%s/.ssh/known_hosts\\', '    use home as char*', 'else', '    else', '        assign: knh_file = g_strdup_printf(\\"/root/.ssh/known_hosts\\")', '        use knh_file as char*', '        call: g_strdup_printf (g_strdup_printf(\\"/root/.ssh/known_hosts\\"))', '        literal: \\"/root/.ssh/known_hosts\\', 'call: libssh2_knownhost_readfile (libssh2_knownhost_readfile(knh, knh_file, LIBSSH2_KNOWNHOST_FILE_OPENSSH))', 'use knh as LIBSSH2_KNOWNHOSTS*', 'use knh_file as char*', 'use <unknown> LIBSSH2_KNOWNHOST_FILE_OPENSSH as ANY', 'assign: r = libssh2_knownhost_checkp(knh, host, port, hostkey, len, LIBSSH2_KNOWNHOST_TYPE_PLAIN| LIBSSH2_KNOWNHOST_KEYENC_RAW, &found)', 'use r as int', 'call: libssh2_knownhost_checkp (libssh2_knownhost_checkp(knh, host, port, hostkey, len, LIBSSH2_KNOWNHOST_TYPE_PLAIN| LIBSSH2_KNOWNHOST_KEYENC_RAW, &found))', 'use knh as LIBSSH2_KNOWNHOSTS*', 'use host as char*', 'use port as int', 'use hostkey as char*', 'use len as size_t', 'condition: LIBSSH2_KNOWNHOST_TYPE_PLAIN| LIBSSH2_KNOWNHOST_KEYENC_RAW', 'use <unknown> LIBSSH2_KNOWNHOST_TYPE_PLAIN as ANY', 'use <unknown> LIBSSH2_KNOWNHOST_KEYENC_RAW as ANY', 'operator: <operator>.addressOf (&found)', 'use found as libssh2_knownhost*', 'switch: switch (r) {\ncase LIBSSH2_KNOWNHOST_CHECK_MATCH: /* OK */ DPRINTF(\\"host key OK: %s\\", found->key); break; case LIBSSH2_KNOWNHOST_CHECK_MISMATCH: ret = -EINVAL; session_error_report(s, \\"host key does not match the one in known_hosts (found key %s)\\", found->key); goto out; case LIBSSH2_KNOWNHOST_CHECK_NOTFOUND: ret = -EINVAL; session_error_report(s, \\"no host key was found in known_hosts\\"); goto out; case LIBSSH2_KNOWNHOST_CHECK_FAILURE: ret = -EINVAL; session_error_report(s, \\"failure matching the host key with known_hosts\\"); goto out; default: ret = -EINVAL; session_error_report(s, \\"unknown error matching the host key with known_hosts (%d)\\", r); goto out; }', '    use <unknown> LI ...
# Conflict Reason: ['Possible null pointer dereference of `knh_file`.', 'Possible null pointer dereference of `knh`.', 'Use of unknown/untrusted type in `    use <unknown> EINVAL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> EINVAL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> LIBSSH2_KNOWNHOST_FILE_OPENSSH as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> LIBSSH2_KNOWNHOST_TYPE_PLAIN as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> LIBSSH2_KNOWNHOST_KEYENC_RAW as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> LIBSSH2_KNOWNHOST_CHECK_MATCH as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> LIBSSH2_KNOWNHOST_CHECK_MISMATCH as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> EINVAL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> LIBSSH2_KNOWNHOST_CHECK_NOTFOUND as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> EINVAL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> LIBSSH2_KNOWNHOST_CHECK_FAILURE as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> EINVAL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> EINVAL as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 1019
# Event Trace: ['declare int index', 'assign: index = 0', 'use index as int', 'literal: 0', 'declare char[32] label', 'assign: label[32]', 'use label as char[32]', 'operator: <operator>.alloc (label[32])', 'use char[32] as char[32]', 'literal: 32', 'if: "strcmp(devname, \\"none\\") == 0"', '    return: return 0;', '    literal: 0', 'if: "index == MAX_MONITOR_DEVICES"', '    call: fprintf (fprintf(stderr, \\"qemu: too many monitor devices\\\\n\\"))', '    use <unknown> stderr as ANY', '    literal: \\"qemu: too many monitor devices\\\\n\\', '    call: exit (exit(1))', '    literal: 1', 'if: "index == 0"', '    call: snprintf (snprintf(label, sizeof(label), \\"monitor\\"))', '    use label as char[32]', '    operator: <operator>.sizeOf (sizeof(label))', '    use label as char[32]', '    literal: \\"monitor\\', 'else', '    else', '        call: snprintf (snprintf(label, sizeof(label), \\"monitor%d\\", index))', '        use label as char[32]', '        operator: <operator>.sizeOf (sizeof(label))', '        use label as char[32]', '        literal: \\"monitor%d\\', '        use index as int', 'assign: monitor_hds[index] = qemu_chr_open(label, devname, NULL)', 'operator: <operator>.indirectIndexAccess (monitor_hds[index])', 'use <unknown> monitor_hds as ANY', 'use index as int', 'call: qemu_chr_open (qemu_chr_open(label, devname, NULL))', 'use label as char[32]', 'use devname as char*', 'use <unknown> NULL as ANY', 'if: "!monitor_hds[index]"', '    call: fprintf (fprintf(stderr, \\"qemu: could not open monitor device \'%s\'\\\\n\\", devname))', '    use <unknown> stderr as ANY', '    literal: \\"qemu: could not open monitor device \'%s\'\\\\n\\', '    use devname as char*', '    return: return -1;', '    operator: <operator>.minus (-1)', '    literal: 1', 'operator: <operator>.postIncrement (index++)', 'use index as int', 'return: return 0;', 'literal: 0', 'declare ANY stderr', 'declare ANY monitor_hds', 'declare ANY NULL', 'declare ANY MAX_MONITOR_DEVICES']
# Conflict Reason: ['Possible out-of-bounds array access with index `32`.', 'Possible out-of-bounds array access with index `index`.', 'Use of unknown/untrusted type in `use <unknown> monitor_hds as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 85
# Event Trace: ['call: gen_update_cc_op (gen_update_cc_op(s))', 'use s as DisasContext*', 'call: gen_jmp_im (gen_jmp_im(cur_eip))', 'use cur_eip as target_ulong', 'call: gen_helper_raise_exception (gen_helper_raise_exception(cpu_env, tcg_const_i32(trapno)))', 'use <unknown> cpu_env as ANY', 'call: tcg_const_i32 (tcg_const_i32(trapno))', 'use trapno as int', 'assign: s->is_jmp = DISAS_TB_JUMP', 'field_access: s->is_jmp', 'use s as DisasContext*', 'field: is_jmp', 'use <unknown> DISAS_TB_JUMP as ANY', 'declare ANY DISAS_TB_JUMP', 'declare ANY cpu_env']
# Conflict Reason: ['Use of unknown/untrusted type in `use <unknown> DISAS_TB_JUMP as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 1575
# Event Trace: ['call: test_native_list_integer_helper (test_native_list_integer_helper(data, unused, USER_DEF_NATIVE_LIST_UNION_KIND_U64))', 'use data as TestInputVisitorData*', 'use unused as void*', 'use <unknown> USER_DEF_NATIVE_LIST_UNION_KIND_U64 as ANY', 'declare ANY USER_DEF_NATIVE_LIST_UNION_KIND_U64']
# Conflict Reason: ['Use of unknown/untrusted type in `use <unknown> USER_DEF_NATIVE_LIST_UNION_KIND_U64 as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 1066
# Event Trace: ['declare struct msr_data', 'call: kvm_msr_entry_set (kvm_msr_entry_set(&msr_data.entry, MSR_IA32_FEATURE_CONTROL, cpu->env.msr_ia32_feature_control))', 'operator: <operator>.addressOf (&msr_data.entry)', 'operator: <operator>.fieldAccess (msr_data.entry)', 'use msr_data as struct', 'field: entry', 'use <unknown> MSR_IA32_FEATURE_CONTROL as ANY', 'operator: <operator>.fieldAccess (cpu->env.msr_ia32_feature_control)', 'field_access: cpu->env', 'use cpu as X86CPU*', 'field: env', 'field: msr_ia32_feature_control', 'assign: msr_data.info.nmsrs = 1', 'operator: <operator>.fieldAccess (msr_data.info.nmsrs)', 'operator: <operator>.fieldAccess (msr_data.info)', 'use msr_data as struct', 'field: info', 'field: nmsrs', 'literal: 1', 'return: return kvm_vcpu_ioctl(CPU(cpu), KVM_SET_MSRS, &msr_data);', 'call: kvm_vcpu_ioctl (kvm_vcpu_ioctl(CPU(cpu), KVM_SET_MSRS, &msr_data))', 'call: CPU (CPU(cpu))', 'use cpu as X86CPU*', 'use <unknown> KVM_SET_MSRS as ANY', 'operator: <operator>.addressOf (&msr_data)', 'use msr_data as struct', 'declare ANY KVM_SET_MSRS', 'declare ANY MSR_IA32_FEATURE_CONTROL']
# Conflict Reason: ['Use of unknown/untrusted type in `use <unknown> MSR_IA32_FEATURE_CONTROL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> KVM_SET_MSRS as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 2160
# Event Trace: ['declare VirtIONet* n', 'assign: *n = VIRTIO_NET(vdev)', 'use n as VirtIONet*', 'call: VIRTIO_NET (VIRTIO_NET(vdev))', 'use vdev as VirtIODevice*', 'declare int i', 'declare int link_down', 'call: qemu_get_buffer (qemu_get_buffer(f, n->mac, ETH_ALEN))', 'use f as QEMUFile*', 'field_access: n->mac', 'use n as VirtIONet*', 'field: mac', 'use <unknown> ETH_ALEN as ANY', 'assign: n->vqs[0].tx_waiting = qemu_get_be32(f)', 'operator: <operator>.fieldAccess (n->vqs[0].tx_waiting)', 'operator: <operator>.indirectIndexAccess (n->vqs[0])', 'field_access: n->vqs', 'use n as VirtIONet*', 'field: vqs', 'literal: 0', 'field: tx_waiting', 'call: qemu_get_be32 (qemu_get_be32(f))', 'use f as QEMUFile*', 'call: virtio_net_set_mrg_rx_bufs (virtio_net_set_mrg_rx_bufs(n, qemu_get_be32(f), virtio_has_feature(vdev, VIRTIO_F_VERSION_1)))', 'use n as VirtIONet*', 'call: qemu_get_be32 (qemu_get_be32(f))', 'use f as QEMUFile*', 'call: virtio_has_feature (virtio_has_feature(vdev, VIRTIO_F_VERSION_1))', 'use vdev as VirtIODevice*', 'use <unknown> VIRTIO_F_VERSION_1 as ANY', 'if: "version_id >= 3"', '    assign: n->status = qemu_get_be16(f)', '    field_access: n->status', '    use n as VirtIONet*', '    field: status', '    call: qemu_get_be16 (qemu_get_be16(f))', '    use f as QEMUFile*', 'if: "version_id >= 4"', '    if: "version_id < 8"', '        assign: n->promisc = qemu_get_be32(f)', '        field_access: n->promisc', '        use n as VirtIONet*', '        field: promisc', '        call: qemu_get_be32 (qemu_get_be32(f))', '        use f as QEMUFile*', '        assign: n->allmulti = qemu_get_be32(f)', '        field_access: n->allmulti', '        use n as VirtIONet*', '        field: allmulti', '        call: qemu_get_be32 (qemu_get_be32(f))', '        use f as QEMUFile*', '    else', '        else', '            assign: n->promisc = qemu_get_byte(f)', '            field_access: n->promisc', '            use n as VirtIONet*', '            field: promisc', '            call: qemu_get_byte (qemu_get_byte(f))', '            use f as QEMUFile*', '            assign: n->allmulti = qemu_get_byte(f)', '            field_access: n->allmulti', '            use n as VirtIONet*', '            field: allmulti', '            call: qemu_get_byte (qemu_get_byte(f))', '            use f as QEMUFile*', 'if: "version_id >= 5"', '    assign: n->mac_table.in_use = qemu_get_be32(f)', '    operator: <operator>.fieldAccess (n->mac_table.in_use)', '    field_access: n->mac_table', '    use n as VirtIONet*', '    field: mac_table', '    field: in_use', '    call: qemu_get_be32 (qemu_get_be32(f))', '    use f as QEMUFile*', '    if: "n->mac_table.in_use <= MAC_TABLE_ENTRIES"', '        call: qemu_get_buffer (qemu_get_buffer(f, n->mac_table.macs, n->mac_table.in_use * ETH_ALEN))', '        use f as QEMUFile*', '        operator: <operator>.fieldAccess (n->mac_table.macs)', '        field_access: n->mac_table', '        use n as VirtIONet*', '        field: mac_table', '        field: macs', '        operator: <operator>.multiplication (n->mac_table.in_use * ETH_ALEN)', '        operator: <operator>.fieldAccess (n->mac_table.in_use)', '        field_access: n->mac_table', '        use n as VirtIONet*', '        field: mac_table', '        field: in_use', '        use <unknown> ETH_ALEN as ANY', '    else', '        else', '            declare int64_t i', '            for: for (i = 0;i < (int64_t)n->mac_table.in_use * ETH_ALEN;++i)', '                call: qemu_get_byte (qemu_get_byte(f))', '                use f as QEMUFile*', '            assign: n->mac_table.multi_overflow = n->mac_table.uni_overflow = 1', '            operator: <operator>.fieldAccess (n->mac_table.multi_overflow)', '            field_access: n->mac_table', '            use n as VirtIONet*', '            field: mac_table', '            field: multi_overflow', '            assign: n->mac_table.uni_overflow = 1', '            operator: <operator>.fieldAccess (n->mac_table.uni_overflow)', '       ...
# Conflict Reason: ['Unsafe pointer assignment `assign: *n = VIRTIO_NET(vdev)` not preceded by a safety check, but predicted not vulnerable.', 'Possible null pointer dereference of `n`.', 'Use of unknown/untrusted type in `use <unknown> ETH_ALEN as ANY` but predicted not vulnerable.', 'Possible out-of-bounds array access with index `0`.', 'Use of unknown/untrusted type in `use <unknown> VIRTIO_F_VERSION_1 as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> ETH_ALEN as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> MAX_VLAN as ANY` but predicted not vulnerable.', 'Possible out-of-bounds array access with index `i`.', 'Use of unknown/untrusted type in `use <unknown> VIRTIO_NET_S_LINK_UP as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> SELF_ANNOUNCE_ROUNDS as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> QEMU_CLOCK_VIRTUAL as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 633
# Event Trace: ['declare uint32_t irqflags', 'assign: irqflags = GIC_FDT_IRQ_FLAGS_EDGE_LO_HI', 'use irqflags as uint32_t', 'use <unknown> GIC_FDT_IRQ_FLAGS_EDGE_LO_HI as ANY', 'assign: irqflags = deposit32(irqflags, GIC_FDT_IRQ_PPI_CPU_START, GIC_FDT_IRQ_PPI_CPU_WIDTH, (1 << vbi->smp_cpus) - 1)', 'use irqflags as uint32_t', 'call: deposit32 (deposit32(irqflags, GIC_FDT_IRQ_PPI_CPU_START, GIC_FDT_IRQ_PPI_CPU_WIDTH, (1 << vbi->smp_cpus) - 1))', 'use irqflags as uint32_t', 'use <unknown> GIC_FDT_IRQ_PPI_CPU_START as ANY', 'use <unknown> GIC_FDT_IRQ_PPI_CPU_WIDTH as ANY', 'operator: <operator>.subtraction ((1 << vbi->smp_cpus) - 1)', 'operator: <operator>.shiftLeft (1 << vbi->smp_cpus)', 'literal: 1', 'field_access: vbi->smp_cpus', 'use vbi as VirtBoardInfo*', 'field: smp_cpus', 'literal: 1', 'call: qemu_fdt_add_subnode (qemu_fdt_add_subnode(vbi->fdt, \\"/timer\\"))', 'field_access: vbi->fdt', 'use vbi as VirtBoardInfo*', 'field: fdt', 'literal: \\"/timer\\', 'call: qemu_fdt_setprop_string (qemu_fdt_setprop_string(vbi->fdt, \\"/timer\\", \\"compatible\\", \\"arm,armv7-timer\\"))', 'field_access: vbi->fdt', 'use vbi as VirtBoardInfo*', 'field: fdt', 'literal: \\"/timer\\', 'literal: \\"compatible\\', 'literal: \\"arm,armv7-timer\\', 'call: qemu_fdt_setprop_cells (qemu_fdt_setprop_cells(vbi->fdt, \\"/timer\\", \\"interrupts\\", GIC_FDT_IRQ_TYPE_PPI, 13, irqflags, GIC_FDT_IRQ_TYPE_PPI, 14, irqflags, GIC_FDT_IRQ_TYPE_PPI, 11, irqflags, GIC_FDT_IRQ_TYPE_PPI, 10, irqflags))', 'field_access: vbi->fdt', 'use vbi as VirtBoardInfo*', 'field: fdt', 'literal: \\"/timer\\', 'literal: \\"interrupts\\', 'use <unknown> GIC_FDT_IRQ_TYPE_PPI as ANY', 'literal: 13', 'use irqflags as uint32_t', 'use <unknown> GIC_FDT_IRQ_TYPE_PPI as ANY', 'literal: 14', 'use irqflags as uint32_t', 'use <unknown> GIC_FDT_IRQ_TYPE_PPI as ANY', 'literal: 11', 'use irqflags as uint32_t', 'use <unknown> GIC_FDT_IRQ_TYPE_PPI as ANY', 'literal: 10', 'use irqflags as uint32_t', 'declare ANY GIC_FDT_IRQ_TYPE_PPI', 'declare ANY GIC_FDT_IRQ_PPI_CPU_WIDTH', 'declare ANY GIC_FDT_IRQ_PPI_CPU_START', 'declare ANY GIC_FDT_IRQ_FLAGS_EDGE_LO_HI']
# Conflict Reason: ['Use of unknown/untrusted type in `use <unknown> GIC_FDT_IRQ_FLAGS_EDGE_LO_HI as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> GIC_FDT_IRQ_PPI_CPU_START as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> GIC_FDT_IRQ_PPI_CPU_WIDTH as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> GIC_FDT_IRQ_TYPE_PPI as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> GIC_FDT_IRQ_TYPE_PPI as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> GIC_FDT_IRQ_TYPE_PPI as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> GIC_FDT_IRQ_TYPE_PPI as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------
#
# Row: 1785
# Event Trace: ['declare CURLState* state', 'assign: *state = NULL', 'use state as CURLState*', 'use <unknown> NULL as ANY', 'declare int i', 'declare int j', 'control: do {\nfor (i=0; i<CURL_NUM_STATES; i++) {\nfor (j=0; j<CURL_NUM_ACB; j++) if (s->states[i].acb[j]) continue; if (s->states[i].in_use) continue; state = &s->states[i]; state->in_use = 1; break; } if (!state) {\nqemu_aio_wait(); } } while(!state);', 'if: "!state->curl"', '    assign: state->curl = curl_easy_init()', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    call: curl_easy_init (curl_easy_init())', '    if: "!state->curl"', '        return: return NULL;', '        use <unknown> NULL as ANY', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_URL, s->url))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_URL as ANY', '    field_access: s->url', '    use s as BDRVCURLState*', '    field: url', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_SSL_VERIFYPEER, (long) s->sslverify))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_SSL_VERIFYPEER as ANY', '    operator: <operator>.cast ((long) s->sslverify)', '    field_access: s->sslverify', '    use s as BDRVCURLState*', '    field: sslverify', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_TIMEOUT, 5))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_TIMEOUT as ANY', '    literal: 5', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_WRITEFUNCTION, (void *)curl_read_cb))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_WRITEFUNCTION as ANY', '    operator: <operator>.cast ((void *)curl_read_cb)', '    use <unknown> curl_read_cb as ANY', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_WRITEDATA, (void *)state))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_WRITEDATA as ANY', '    operator: <operator>.cast ((void *)state)', '    use state as CURLState*', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_PRIVATE, (void *)state))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_PRIVATE as ANY', '    operator: <operator>.cast ((void *)state)', '    use state as CURLState*', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_AUTOREFERER, 1))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_AUTOREFERER as ANY', '    literal: 1', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_FOLLOWLOCATION, 1))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_FOLLOWLOCATION as ANY', '    literal: 1', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_NOSIGNAL, 1))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_NOSIGNAL as ANY', '    literal: 1', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_ERRORBUFFER, state->errmsg))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_ERRORBUFFER as ANY', '    field_access: state->errmsg', '    use state as CURLState*', '    field: errmsg', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_FAILONERROR, 1))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown> CURLOPT_FAILONERROR as ANY', '    literal: 1', '    call: curl_easy_setopt (curl_easy_setopt(state->curl, CURLOPT_REDIR_PROTOCOLS, PROTOCOLS))', '    field_access: state->curl', '    use state as CURLState*', '    field: curl', '    use <unknown ...
# Conflict Reason: ['Possible null pointer dereference of `state`.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_URL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_SSL_VERIFYPEER as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_TIMEOUT as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_WRITEFUNCTION as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> curl_read_cb as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_WRITEDATA as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_PRIVATE as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_AUTOREFERER as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_FOLLOWLOCATION as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_NOSIGNAL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_ERRORBUFFER as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_FAILONERROR as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> CURLOPT_REDIR_PROTOCOLS as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> PROTOCOLS as ANY` but predicted not vulnerable.']
# --------------------------------------------------------------------------------

# %%
BENIGN_SYMBOLS = {
    # Extend as you analyze more
    "IO_MEM_RAM", "KVM_SET_MSRS", "ELF_MACHINE", "stderr", "PROTOCOLS",
    "AFM_free", "EINVAL", "NULL", "DISAS_TB_JUMP", "GOOD", "VIRTIO_F_VERSION_1",
    "SELF_ANNOUNCE_ROUNDS", "USB_SPEED_LOW", "USB_SPEED_FULL", "USB_SPEED_HIGH",
    "PORTSC_PED", "PLS_U0", "PORTSC_PLS", "PORTSC_PR", "PORTSC_PRC", "MAX_IDE_BUS",
    "MAX_IDE_DEVS", "MAX_FD", "main_cpu_reset", "TARGET_PAGE_SIZE", "cpu_irq_handler",
    "IF_PFLASH", "curl_read_cb", "VIRTIO_NET_S_LINK_UP", "MAC_TABLE_ENTRIES",
    "MAX_VLAN", "GIC_FDT_IRQ_FLAGS_EDGE_LO_HI", "GIC_FDT_IRQ_PPI_CPU_START",
    "GIC_FDT_IRQ_PPI_CPU_WIDTH", "GIC_FDT_IRQ_TYPE_PPI", "CURL_NUM_ACB",
    "CURL_NUM_STATES", "SPR_BOOKE_TSR", "TSR_DIS", "SPR_BOOKE_DECAR",
    "TCR_ARE", "SPR_BOOKE_TCR"
    # ... and others as you see them
}

def is_benign_unknown(event):
    # Event like 'use <unknown> SYMBOL as ANY'
    for sym in BENIGN_SYMBOLS:
        if f"<unknown> {sym}" in event:
            return True
    return False

def ref_conflict_detection(event_trace, pred_label):
    conflict = False
    reasons = []

    if pred_label == 0:
        for i, event in enumerate(event_trace):
            event_strip = event.strip()

            # 1. Only trigger on 'unknown' if not benign
            if 'use <unknown>' in event_strip and not is_benign_unknown(event_strip):
                conflict = True
                reasons.append(f"Use of untrusted or dynamic unknown type in `{event_strip}` but predicted not vulnerable.")

            # 2. Pointer assignment without prior check, but skip for whitelisted allocation/init functions
            if event_strip.startswith("assign: *"):
                # If assignment is from an alloc/init function, relax the rule
                safe_sources = ["g_new", "g_malloc", "g_malloc0", "DO_UPCAST", "cpu_init", "qdev_create", "qemu_allocate_irqs"]
                is_safe = any(src in event_trace[i] for src in safe_sources)
                guarded = any('if:' in event_trace[j] or 'condition:' in event_trace[j] or 'check' in event_trace[j]
                              for j in range(max(0, i-5), i))
                if not is_safe and not guarded:
                    conflict = True
                    reasons.append(f"Unsafe pointer assignment `{event_strip}` not preceded by a safety check.")

            # 3. OOB: Only flag for non-literals or user-controlled indices
            if 'Possible out-of-bounds array access' in event_strip:
                # You may parse the index and check if it's a literal, else fire
                pass  # implement only for dynamic/user indices

            # 4. Null deref: Only if dereferenced with no prior check
            if 'Possible null pointer dereference' in event_strip:
                # Only flag if field_access/use occurs and no guard
                pass  # keep this, but be sure to check for guarding

    return conflict, reasons

# %%
conflict_results_up = test_df.apply(
    lambda row: ref_conflict_detection(row['event_trace_list'], row['pred_label']), axis=1
)
test_df['conflict_up'] = [c for c, _ in conflict_results_up]
test_df['conflict_reason_up'] = [r for _, r in conflict_results_up]

# %%
test_df['conflict_up'].value_counts()
# Out:
# conflict_up
# True     1561
# False    1246
# Name: count, dtype: int64

# %%
test_df['conflict'].value_counts()
# Suppose your DataFrame is called df, with columns: 'conflict', 'ground_truth'
false_positives = test_df[(test_df['conflict'] == True) & (test_df['label'] == False)].shape[0]
total_actual_negatives = test_df[test_df['label'] == False].shape[0]

conflict_fpr = false_positives / total_actual_negatives if total_actual_negatives > 0 else 0
print(f"Conflict detection false positive rate: {conflict_fpr:.2%}")
# Out:
# Conflict detection false positive rate: 63.85%

# %%
import pandas as pd
import random

# Load your false positive CSV
fp_df = pd.read_csv('false_positive_conflicts.csv')

# If you have a specific column for the conflict rule, use that. If not, extract rule names from the 'conflict_reason'
def extract_rule_names(conflict_reason):
    # This is a rough heuristic, adapt if your formatting is different
    if isinstance(conflict_reason, str):
        # Try to extract the first phrase (rule type)
        if "pointer assignment" in conflict_reason:
            return "unsafe_pointer_assign"
        elif "null pointer dereference" in conflict_reason:
            return "null_pointer_deref"
        elif "out-of-bounds array access" in conflict_reason:
            return "oob_array_access"
        elif "unknown/untrusted type" in conflict_reason:
            return "use_unknown_value"
        else:
            return "other"
    return "none"

# If you want to sample 20 FPs
sampled_fp = fp_df.sample(n=20, random_state=42) if len(fp_df) > 20 else fp_df

for idx, row in sampled_fp.iterrows():
    print(f"Row: {idx}")
    print(f"Rule Type(s): {[extract_rule_names(cr) for cr in eval(row['conflict_reason'])] if isinstance(row['conflict_reason'], str) and row['conflict_reason'].startswith('[') else extract_rule_names(row['conflict_reason'])}")
    print(f"Conflict Reason:\n{row['conflict_reason']}")
    print(f"Event Trace:\n{row['event_trace']}")
    print("-" * 80)
# Out:
# Row: 576
# Rule Type(s): ['use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Use of unknown/untrusted type in `        use <unknown> true as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> false as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare uint64_t i', 'declare int sectors_per_bit', 'assign: sectors_per_bit = 1 << hbitmap_granularity(bitmap->meta)', 'use sectors_per_bit as int', 'operator: <operator>.shiftLeft (1 << hbitmap_granularity(bitmap->meta))', 'literal: 1', 'call: hbitmap_granularity (hbitmap_granularity(bitmap->meta))', 'field_access: bitmap->meta', 'use bitmap as BdrvDirtyBitmap*', 'field: meta', 'for: for (i = sector;i < sector + nb_sectors;i += sectors_per_bit)', '    if: "hbitmap_get(bitmap->meta, i)"', '        return: return true;', '        use <unknown> true as ANY', 'return: return false;', 'use <unknown> false as ANY', 'declare ANY false', 'declare ANY true']
# --------------------------------------------------------------------------------
# Row: 312
# Rule Type(s): ['unsafe_pointer_assign', 'unsafe_pointer_assign']
# Conflict Reason:
# ['Unsafe pointer assignment `assign: *reg = cfg_entry->reg` not preceded by a safety check, but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *val = XEN_PT_MERGE_VALUE(*val, dev_value, throughable_mask)` not preceded by a safety check, but predicted not vulnerable.']
# Event Trace:
# ['declare XenPTRegInfo* reg', 'assign: *reg = cfg_entry->reg', 'use reg as XenPTRegInfo*', 'field_access: cfg_entry->reg', 'use cfg_entry as XenPTReg*', 'field: reg', 'declare uint16_t writable_mask', 'assign: writable_mask = 0', 'use writable_mask as uint16_t', 'literal: 0', 'declare uint16_t throughable_mask', 'assign: throughable_mask = get_throughable_mask(s, reg, valid_mask)', 'use throughable_mask as uint16_t', 'call: get_throughable_mask (get_throughable_mask(s, reg, valid_mask))', 'use s as XenPCIPassthroughState*', 'use reg as XenPTRegInfo*', 'use valid_mask as uint16_t', 'assign: writable_mask = reg->emu_mask & ~reg->ro_mask & valid_mask', 'use writable_mask as uint16_t', 'condition: reg->emu_mask & ~reg->ro_mask & valid_mask', 'condition: reg->emu_mask & ~reg->ro_mask', 'field_access: reg->emu_mask', 'use reg as XenPTRegInfo*', 'field: emu_mask', 'operator: <operator>.not (~reg->ro_mask)', 'field_access: reg->ro_mask', 'use reg as XenPTRegInfo*', 'field: ro_mask', 'use valid_mask as uint16_t', 'assign: cfg_entry->data = XEN_PT_MERGE_VALUE(*val, cfg_entry->data, writable_mask)', 'field_access: cfg_entry->data', 'use cfg_entry as XenPTReg*', 'field: data', 'call: XEN_PT_MERGE_VALUE (XEN_PT_MERGE_VALUE(*val, cfg_entry->data, writable_mask))', 'operator: <operator>.indirection (*val)', 'use val as uint16_t*', 'field_access: cfg_entry->data', 'use cfg_entry as XenPTReg*', 'field: data', 'use writable_mask as uint16_t', 'assign: *val = XEN_PT_MERGE_VALUE(*val, dev_value, throughable_mask)', 'operator: <operator>.indirection (*val)', 'use val as uint16_t*', 'call: XEN_PT_MERGE_VALUE (XEN_PT_MERGE_VALUE(*val, dev_value, throughable_mask))', 'operator: <operator>.indirection (*val)', 'use val as uint16_t*', 'use dev_value as uint16_t', 'use throughable_mask as uint16_t', 'return: return 0;', 'literal: 0']
# --------------------------------------------------------------------------------
# Row: 70
# Rule Type(s): ['unsafe_pointer_assign', 'unsafe_pointer_assign', 'unsafe_pointer_assign', 'unsafe_pointer_assign', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Unsafe pointer assignment `assign: *cpu_model = args->cpu_model` not preceded by a safety check, but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *kernel_filename = args->kernel_filename` not preceded by a safety check, but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *address_space_mem = get_system_memory()` not preceded by a safety check, but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *ram = g_new(MemoryRegion, 1)` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> MemoryRegion as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> stderr as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> NULL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> NULL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> NULL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> NULL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> ELF_MACHINE as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> NULL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> NULL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> KERNEL_LOAD_ADDR as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> KERNEL_LOAD_ADDR as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> KERNEL_LOAD_ADDR as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> stderr as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare ram_addr_t ram_size', 'assign: ram_size = args->ram_size', 'use ram_size as ram_addr_t', 'field_access: args->ram_size', 'use args as QEMUMachineInitArgs*', 'field: ram_size', 'declare char* cpu_model', 'assign: *cpu_model = args->cpu_model', 'use cpu_model as char*', 'field_access: args->cpu_model', 'use args as QEMUMachineInitArgs*', 'field: cpu_model', 'declare char* kernel_filename', 'assign: *kernel_filename = args->kernel_filename', 'use kernel_filename as char*', 'field_access: args->kernel_filename', 'use args as QEMUMachineInitArgs*', 'field: kernel_filename', 'declare CPUM68KState* env', 'declare MemoryRegion* address_space_mem', 'assign: *address_space_mem = get_system_memory()', 'use address_space_mem as MemoryRegion*', 'call: get_system_memory (get_system_memory())', 'declare MemoryRegion* ram', 'assign: *ram = g_new(MemoryRegion, 1)', 'use ram as MemoryRegion*', 'call: g_new (g_new(MemoryRegion, 1))', 'use <unknown> MemoryRegion as ANY', 'literal: 1', 'declare int kernel_size', 'declare uint64_t elf_entry', 'declare target_phys_addr_t entry', 'if: "!cpu_model"', '    assign: cpu_model = \\"cfv4e\\', '    use cpu_model as char*', '    literal: \\"cfv4e\\', 'assign: env = cpu_init(cpu_model)', 'use env as CPUM68KState*', 'call: cpu_init (cpu_init(cpu_model))', 'use cpu_model as char*', 'if: "!env"', '    call: fprintf (fprintf(stderr, \\"Unable to find m68k CPU definition\\\\n\\"))', '    use <unknown> stderr as ANY', '    literal: \\"Unable to find m68k CPU definition\\\\n\\', '    call: exit (exit(1))', '    literal: 1', 'assign: env->vbr = 0', 'field_access: env->vbr', 'use env as CPUM68KState*', 'field: vbr', 'literal: 0', 'call: memory_region_init_ram (memory_region_init_ram(ram, \\"dummy_m68k.ram\\", ram_size))', 'use ram as MemoryRegion*', 'literal: \\"dummy_m68k.ram\\', 'use ram_size as ram_addr_t', 'call: vmstate_register_ram_global (vmstate_register_ram_global(ram))', 'use ram as MemoryRegion*', 'call: memory_region_add_subregion (memory_region_add_subregion(address_space_mem, 0, ram))', 'use address_space_mem as MemoryRegion*', 'literal: 0', 'use ram as MemoryRegion*', 'if: "kernel_filename"', '    assign: kernel_size = load_elf(kernel_filename, NULL, NULL, &elf_entry, NULL, NULL, 1, ELF_MACHINE, 0)', '    use kernel_size as int', '    call: load_elf (load_elf(kernel_filename, NULL, NULL, &elf_entry, NULL, NULL, 1, ELF_MACHINE, 0))', '    use kernel_filename as char*', '    use <unknown> NULL as ANY', '    use <unknown> NULL as ANY', '    operator: <operator>.addressOf (&elf_entry)', '    use elf_entry as uint64_t', '    use <unknown> NULL as ANY', '    use <unknown> NULL as ANY', '    literal: 1', '    use <unknown> ELF_MACHINE as ANY', '    literal: 0', '    assign: entry = elf_entry', '    use entry as target_phys_addr_t', '    use elf_entry as uint64_t', '    if: "kernel_size < 0"', '        assign: kernel_size = load_uimage(kernel_filename, &entry, NULL, NULL)', '        use kernel_size as int', '        call: load_uimage (load_uimage(kernel_filename, &entry, NULL, NULL))', '        use kernel_filename as char*', '        operator: <operator>.addressOf (&entry)', '        use entry as target_phys_addr_t', '        use <unknown> NULL as ANY', '        use <unknown> NULL as ANY', '    if: "kernel_size < 0"', '        assign: kernel_size = load_image_targphys(kernel_filename, KERNEL_LOAD_ADDR, ram_size - KERNEL_LOAD_ADDR)', '        use kernel_size as int', '        call: load_image_targphys (load_image_targphys(kernel_filename, KERNEL_LOAD_ADDR, ram_size - KERNEL_LOAD_ADDR))', '        use kernel_filename as char*', '        use <unknown> KERNEL_LOAD_ADDR as ANY', '        operator: <operator>.subtraction (ram_size - KERNEL_LOAD_ADDR)', '        use ram_size as ram_addr_t', '        use <unknown> KERNEL_LOAD_ADDR as ANY', '        assign: entry = KERNEL_LOAD_ADDR', '        use entry as target_phys_addr_t', '        use <unknown> KERNEL_LOAD_ADDR as ANY', '    if: "kernel_size < 0"', '       ...
# --------------------------------------------------------------------------------
# Row: 682
# Rule Type(s): ['use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Use of unknown/untrusted type in `    use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `            use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `            use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `            use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                    use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                    use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                    use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                        use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                    use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                    use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                    use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                        use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                        use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                            use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                            use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                            use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                            use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                        use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                        use <unknown> eeprom as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `                        use <unknown> eeprom ...
# Event Trace:
# ['if: "eeprom.scl && scl && (eeprom.sda != sda)"', '    call: logout (logout(\\"%u: scl = %u->%u, sda = %u->%u i2c %s\\\\n\\", eeprom.tick, eeprom.scl, scl, eeprom.sda, sda, sda ? \\"stop\\" : \\"start\\"))', '    literal: \\"%u: scl = %u->%u, sda = %u->%u i2c %s\\\\n\\', '    operator: <operator>.fieldAccess (eeprom.tick)', '    use <unknown> eeprom as ANY', '    field: tick', '    operator: <operator>.fieldAccess (eeprom.scl)', '    use <unknown> eeprom as ANY', '    field: scl', '    use scl as int', '    operator: <operator>.fieldAccess (eeprom.sda)', '    use <unknown> eeprom as ANY', '    field: sda', '    use sda as int', '    condition: sda ? \\"stop\\" : \\"start\\', '    use sda as int', '    literal: \\"stop\\', '    literal: \\"start\\', '    if: "!sda"', '        assign: eeprom.tick = 1', '        operator: <operator>.fieldAccess (eeprom.tick)', '        use <unknown> eeprom as ANY', '        field: tick', '        literal: 1', '        assign: eeprom.command = 0', '        operator: <operator>.fieldAccess (eeprom.command)', '        use <unknown> eeprom as ANY', '        field: command', '        literal: 0', 'else', '    else', '        if: "eeprom.tick == 0 && !eeprom.ack"', '            call: logout (logout(\\"%u: scl = %u->%u, sda = %u->%u wait for i2c start\\\\n\\", eeprom.tick, eeprom.scl, scl, eeprom.sda, sda))', '            literal: \\"%u: scl = %u->%u, sda = %u->%u wait for i2c start\\\\n\\', '            operator: <operator>.fieldAccess (eeprom.tick)', '            use <unknown> eeprom as ANY', '            field: tick', '            operator: <operator>.fieldAccess (eeprom.scl)', '            use <unknown> eeprom as ANY', '            field: scl', '            use scl as int', '            operator: <operator>.fieldAccess (eeprom.sda)', '            use <unknown> eeprom as ANY', '            field: sda', '            use sda as int', '        else', '            else', '                if: "!eeprom.scl && scl"', '                    call: logout (logout(\\"%u: scl = %u->%u, sda = %u->%u trigger bit\\\\n\\", eeprom.tick, eeprom.scl, scl, eeprom.sda, sda))', '                    literal: \\"%u: scl = %u->%u, sda = %u->%u trigger bit\\\\n\\', '                    operator: <operator>.fieldAccess (eeprom.tick)', '                    use <unknown> eeprom as ANY', '                    field: tick', '                    operator: <operator>.fieldAccess (eeprom.scl)', '                    use <unknown> eeprom as ANY', '                    field: scl', '                    use scl as int', '                    operator: <operator>.fieldAccess (eeprom.sda)', '                    use <unknown> eeprom as ANY', '                    field: sda', '                    use sda as int', '                    if: "eeprom.ack"', '                        call: logout (logout(\\"\\\\ti2c ack bit = 0\\\\n\\"))', '                        literal: \\"\\\\ti2c ack bit = 0\\\\n\\', '                        assign: sda = 0', '                        use sda as int', '                        literal: 0', '                        assign: eeprom.ack = 0', '                        operator: <operator>.fieldAccess (eeprom.ack)', '                        use <unknown> eeprom as ANY', '                        field: ack', '                        literal: 0', '                    else', '                        else', '                            if: "eeprom.sda == sda"', '                                declare uint8_t bit', '                                assign: bit = (sda != 0)', '                                use bit as uint8_t', '                                condition: sda != 0', '                                use sda as int', '                                literal: 0', '                                call: logout (logout(\\"\\\\ti2c bit = %d\\\\n\\", bit))', '                                literal: \\"\\\\ti2c bit = %d\\\\n\\', '                                use bit as uint8_t', '                                if:  ...
# --------------------------------------------------------------------------------
# Row: 896
# Rule Type(s): ['use_unknown_value', 'use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Use of unknown/untrusted type in `use <unknown> VIRTIO_F_NOTIFY_ON_EMPTY as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> VIRTIO_RING_F_INDIRECT_DESC as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> VIRTIO_F_BAD_FEATURE as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare unsigned ret', 'assign: ret = 0', 'use ret as unsigned', 'literal: 0', 'call: <operators>.assignmentOr (ret |= (1 << VIRTIO_F_NOTIFY_ON_EMPTY))', 'use ret as unsigned', 'operator: <operator>.shiftLeft (1 << VIRTIO_F_NOTIFY_ON_EMPTY)', 'literal: 1', 'use <unknown> VIRTIO_F_NOTIFY_ON_EMPTY as ANY', 'call: <operators>.assignmentOr (ret |= (1 << VIRTIO_RING_F_INDIRECT_DESC))', 'use ret as unsigned', 'operator: <operator>.shiftLeft (1 << VIRTIO_RING_F_INDIRECT_DESC)', 'literal: 1', 'use <unknown> VIRTIO_RING_F_INDIRECT_DESC as ANY', 'call: <operators>.assignmentOr (ret |= (1 << VIRTIO_F_BAD_FEATURE))', 'use ret as unsigned', 'operator: <operator>.shiftLeft (1 << VIRTIO_F_BAD_FEATURE)', 'literal: 1', 'use <unknown> VIRTIO_F_BAD_FEATURE as ANY', 'return: return ret;', 'use ret as unsigned', 'declare ANY VIRTIO_F_BAD_FEATURE', 'declare ANY VIRTIO_RING_F_INDIRECT_DESC', 'declare ANY VIRTIO_F_NOTIFY_ON_EMPTY']
# --------------------------------------------------------------------------------
# Row: 912
# Rule Type(s): ['use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Use of unknown/untrusted type in `use <unknown> alloc_list as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> alloc_list as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare Aml* var', 'call: assert (assert(!alloc_list))', 'condition: !alloc_list', 'use <unknown> alloc_list as ANY', 'assign: alloc_list = g_ptr_array_new()', 'use <unknown> alloc_list as ANY', 'call: g_ptr_array_new (g_ptr_array_new())', 'assign: var = aml_alloc()', 'use var as Aml*', 'call: aml_alloc (aml_alloc())', 'return: return var;', 'use var as Aml*', 'declare ANY alloc_list']
# --------------------------------------------------------------------------------
# Row: 308
# Rule Type(s): ['unsafe_pointer_assign', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Unsafe pointer assignment `assign: *red = (ReadEventData *) sccb` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> SCLP_RC_INSUFFICIENT_SCCB_LENGTH as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> SCLP_UNCONDITIONAL_READ as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> SCLP_SELECTIVE_READ as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> SCLP_RC_INVALID_SELECTION_MASK as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> SCLP_RC_INVALID_FUNCTION as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare unsigned int sclp_active_selection_mask', 'declare unsigned int sclp_cp_receive_mask', 'declare ReadEventData* red', 'assign: *red = (ReadEventData *) sccb', 'use red as ReadEventData*', 'operator: <operator>.cast ((ReadEventData *) sccb)', 'use sccb as SCCB*', 'if: "be16_to_cpu(sccb->h.length) != SCCB_SIZE"', '    assign: sccb->h.response_code = cpu_to_be16(SCLP_RC_INSUFFICIENT_SCCB_LENGTH)', '    operator: <operator>.fieldAccess (sccb->h.response_code)', '    field_access: sccb->h', '    use sccb as SCCB*', '    field: h', '    field: response_code', '    call: cpu_to_be16 (cpu_to_be16(SCLP_RC_INSUFFICIENT_SCCB_LENGTH))', '    use <unknown> SCLP_RC_INSUFFICIENT_SCCB_LENGTH as ANY', '    control: goto out;', 'assign: sclp_cp_receive_mask = ef->receive_mask', 'use sclp_cp_receive_mask as unsigned int', 'field_access: ef->receive_mask', 'use ef as SCLPEventFacility*', 'field: receive_mask', 'switch: switch (sccb->h.function_code) {\ncase SCLP_UNCONDITIONAL_READ: sclp_active_selection_mask = sclp_cp_receive_mask; break; case SCLP_SELECTIVE_READ: if (!(sclp_cp_receive_mask & be32_to_cpu(red->mask))) {\nsccb->h.response_code = cpu_to_be16(SCLP_RC_INVALID_SELECTION_MASK); goto out; } sclp_active_selection_mask = be32_to_cpu(red->mask); break; default: sccb->h.response_code = cpu_to_be16(SCLP_RC_INVALID_FUNCTION); goto out; }', '    use <unknown> SCLP_UNCONDITIONAL_READ as ANY', '    assign: sclp_active_selection_mask = sclp_cp_receive_mask', '    use sclp_active_selection_mask as unsigned int', '    use sclp_cp_receive_mask as unsigned int', '    control: break;', '    use <unknown> SCLP_SELECTIVE_READ as ANY', '    if: "!(sclp_cp_receive_mask & be32_to_cpu(red->mask))"', '        assign: sccb->h.response_code = cpu_to_be16(SCLP_RC_INVALID_SELECTION_MASK)', '        operator: <operator>.fieldAccess (sccb->h.response_code)', '        field_access: sccb->h', '        use sccb as SCCB*', '        field: h', '        field: response_code', '        call: cpu_to_be16 (cpu_to_be16(SCLP_RC_INVALID_SELECTION_MASK))', '        use <unknown> SCLP_RC_INVALID_SELECTION_MASK as ANY', '        control: goto out;', '    assign: sclp_active_selection_mask = be32_to_cpu(red->mask)', '    use sclp_active_selection_mask as unsigned int', '    call: be32_to_cpu (be32_to_cpu(red->mask))', '    field_access: red->mask', '    use red as ReadEventData*', '    field: mask', '    control: break;', '    assign: sccb->h.response_code = cpu_to_be16(SCLP_RC_INVALID_FUNCTION)', '    operator: <operator>.fieldAccess (sccb->h.response_code)', '    field_access: sccb->h', '    use sccb as SCCB*', '    field: h', '    field: response_code', '    call: cpu_to_be16 (cpu_to_be16(SCLP_RC_INVALID_FUNCTION))', '    use <unknown> SCLP_RC_INVALID_FUNCTION as ANY', '    control: goto out;', 'assign: sccb->h.response_code = cpu_to_be16( handle_sccb_read_events(ef, sccb, sclp_active_selection_mask))', 'operator: <operator>.fieldAccess (sccb->h.response_code)', 'field_access: sccb->h', 'use sccb as SCCB*', 'field: h', 'field: response_code', 'call: cpu_to_be16 (cpu_to_be16( handle_sccb_read_events(ef, sccb, sclp_active_selection_mask)))', 'call: handle_sccb_read_events (handle_sccb_read_events(ef, sccb, sclp_active_selection_mask))', 'use ef as SCLPEventFacility*', 'use sccb as SCCB*', 'use sclp_active_selection_mask as unsigned int', 'return: return;', 'declare ANY SCLP_RC_INVALID_FUNCTION', 'declare ANY SCLP_RC_INVALID_SELECTION_MASK', 'declare ANY SCLP_SELECTIVE_READ', 'declare ANY SCLP_UNCONDITIONAL_READ', 'declare ANY SCLP_RC_INSUFFICIENT_SCCB_LENGTH', 'declare ANY SCCB_SIZE']
# --------------------------------------------------------------------------------
# Row: 660
# Rule Type(s): ['use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Use of unknown/untrusted type in `    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_INET as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_UNIX as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_FD as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_VSOCK as ANY` but predicted not vulnerable.']
# Event Trace:
# ['switch: switch (addr->type) {\ncase SOCKET_ADDRESS_LEGACY_KIND_INET: return g_strdup_printf(\\"%s%s:%s:%s%s\\", prefix, is_telnet ? \\"telnet\\" : \\"tcp\\", addr->u.inet.data->host, addr->u.inet.data->port, is_listen ? \\",server\\" : \\"\\"); break; case SOCKET_ADDRESS_LEGACY_KIND_UNIX: return g_strdup_printf(\\"%sunix:%s%s\\", prefix, addr->u.q_unix.data->path, is_listen ? \\",server\\" : \\"\\"); break; case SOCKET_ADDRESS_LEGACY_KIND_FD: return g_strdup_printf(\\"%sfd:%s%s\\", prefix, addr->u.fd.data->str, is_listen ? \\",server\\" : \\"\\"); break; case SOCKET_ADDRESS_LEGACY_KIND_VSOCK: return g_strdup_printf(\\"%svsock:%s:%s\\", prefix, addr->u.vsock.data->cid, addr->u.vsock.data->port); default: abort(); }', '    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_INET as ANY', '    return: return g_strdup_printf(\\"%s%s:%s:%s%s\\", prefix, is_telnet ? \\"telnet\\" : \\"tcp\\", addr->u.inet.data->host, addr->u.inet.data->port, is_listen ? \\",server\\" : \\"\\");', '    call: g_strdup_printf (g_strdup_printf(\\"%s%s:%s:%s%s\\", prefix, is_telnet ? \\"telnet\\" : \\"tcp\\", addr->u.inet.data->host, addr->u.inet.data->port, is_listen ? \\",server\\" : \\"\\"))', '    literal: \\"%s%s:%s:%s%s\\', '    use prefix as char*', '    condition: is_telnet ? \\"telnet\\" : \\"tcp\\', '    use is_telnet as bool', '    literal: \\"telnet\\', '    literal: \\"tcp\\', '    field_access: addr->u.inet.data->host', '    operator: <operator>.fieldAccess (addr->u.inet.data)', '    operator: <operator>.fieldAccess (addr->u.inet)', '    field_access: addr->u', '    use addr as SocketAddressLegacy*', '    field: u', '    field: inet', '    field: data', '    field: host', '    field_access: addr->u.inet.data->port', '    operator: <operator>.fieldAccess (addr->u.inet.data)', '    operator: <operator>.fieldAccess (addr->u.inet)', '    field_access: addr->u', '    use addr as SocketAddressLegacy*', '    field: u', '    field: inet', '    field: data', '    field: port', '    condition: is_listen ? \\",server\\" : \\"\\', '    use is_listen as bool', '    literal: \\",server\\', '    literal: \\"\\', '    control: break;', '    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_UNIX as ANY', '    return: return g_strdup_printf(\\"%sunix:%s%s\\", prefix, addr->u.q_unix.data->path, is_listen ? \\",server\\" : \\"\\");', '    call: g_strdup_printf (g_strdup_printf(\\"%sunix:%s%s\\", prefix, addr->u.q_unix.data->path, is_listen ? \\",server\\" : \\"\\"))', '    literal: \\"%sunix:%s%s\\', '    use prefix as char*', '    field_access: addr->u.q_unix.data->path', '    operator: <operator>.fieldAccess (addr->u.q_unix.data)', '    operator: <operator>.fieldAccess (addr->u.q_unix)', '    field_access: addr->u', '    use addr as SocketAddressLegacy*', '    field: u', '    field: q_unix', '    field: data', '    field: path', '    condition: is_listen ? \\",server\\" : \\"\\', '    use is_listen as bool', '    literal: \\",server\\', '    literal: \\"\\', '    control: break;', '    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_FD as ANY', '    return: return g_strdup_printf(\\"%sfd:%s%s\\", prefix, addr->u.fd.data->str, is_listen ? \\",server\\" : \\"\\");', '    call: g_strdup_printf (g_strdup_printf(\\"%sfd:%s%s\\", prefix, addr->u.fd.data->str, is_listen ? \\",server\\" : \\"\\"))', '    literal: \\"%sfd:%s%s\\', '    use prefix as char*', '    field_access: addr->u.fd.data->str', '    operator: <operator>.fieldAccess (addr->u.fd.data)', '    operator: <operator>.fieldAccess (addr->u.fd)', '    field_access: addr->u', '    use addr as SocketAddressLegacy*', '    field: u', '    field: fd', '    field: data', '    field: str', '    condition: is_listen ? \\",server\\" : \\"\\', '    use is_listen as bool', '    literal: \\",server\\', '    literal: \\"\\', '    control: break;', '    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_VSOCK as ANY', '    return: return g_strdup_printf(\\"%svsock:%s:%s\\", prefix, addr->u.vsock.data->cid, addr->u.vsock.data->port);', '    call: g_strdup_ ...
# --------------------------------------------------------------------------------
# Row: 174
# Rule Type(s): ['unsafe_pointer_assign', 'use_unknown_value']
# Conflict Reason:
# ['Unsafe pointer assignment `assign: *filename = qdict_get_str(qdict, \\"device\\")` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> QERR_DEVICE_NOT_FOUND as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare BlockDriverState* bs', 'declare int force', 'assign: force = qdict_get_int(qdict, \\"force\\")', 'use force as int', 'call: qdict_get_int (qdict_get_int(qdict, \\"force\\"))', 'use qdict as QDict*', 'literal: \\"force\\', 'declare char* filename', 'assign: *filename = qdict_get_str(qdict, \\"device\\")', 'use filename as char*', 'call: qdict_get_str (qdict_get_str(qdict, \\"device\\"))', 'use qdict as QDict*', 'literal: \\"device\\', 'assign: bs = bdrv_find(filename)', 'use bs as BlockDriverState*', 'call: bdrv_find (bdrv_find(filename))', 'use filename as char*', 'if: "!bs"', '    call: qerror_report (qerror_report(QERR_DEVICE_NOT_FOUND, filename))', '    use <unknown> QERR_DEVICE_NOT_FOUND as ANY', '    use filename as char*', '    return: return -1;', '    operator: <operator>.minus (-1)', '    literal: 1', 'return: return eject_device(mon, bs, force);', 'call: eject_device (eject_device(mon, bs, force))', 'use mon as Monitor*', 'use bs as BlockDriverState*', 'use force as int', 'declare ANY QERR_DEVICE_NOT_FOUND']
# --------------------------------------------------------------------------------
# Row: 192
# Rule Type(s): ['unsafe_pointer_assign', 'use_unknown_value', 'unsafe_pointer_assign', 'unsafe_pointer_assign', 'use_unknown_value']
# Conflict Reason:
# ['Unsafe pointer assignment `assign: *info_list = NULL` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> NULL as ANY` but predicted not vulnerable.', 'Unsafe pointer assignment `assign: **prev = &info_list` not preceded by a safety check, but predicted not vulnerable.', 'Unsafe pointer assignment `    assign: *value = info->value` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `            use <unknown> MEMORY_DEVICE_INFO_KIND_DIMM as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare MemoryDeviceInfoList* info_list', 'assign: *info_list = NULL', 'use info_list as MemoryDeviceInfoList*', 'use <unknown> NULL as ANY', 'declare MemoryDeviceInfoList** prev', 'assign: **prev = &info_list', 'use prev as MemoryDeviceInfoList**', 'operator: <operator>.addressOf (&info_list)', 'use info_list as MemoryDeviceInfoList*', 'declare MemoryDeviceInfoList* info', 'call: qmp_pc_dimm_device_list (qmp_pc_dimm_device_list(qdev_get_machine(), &prev))', 'call: qdev_get_machine (qdev_get_machine())', 'operator: <operator>.addressOf (&prev)', 'use prev as MemoryDeviceInfoList**', 'for: for (info = info_list;info;info = info->next)', '    declare MemoryDeviceInfo* value', '    assign: *value = info->value', '    use value as MemoryDeviceInfo*', '    field_access: info->value', '    use info as MemoryDeviceInfoList*', '    field: value', '    if: "value"', '        switch: switch (value->type) {\ncase MEMORY_DEVICE_INFO_KIND_DIMM: node_mem[value->u.dimm->node] += value->u.dimm->size; break; default: break; }', '            use <unknown> MEMORY_DEVICE_INFO_KIND_DIMM as ANY', '            operator: <operator>.assignmentPlus (node_mem[value->u.dimm->node] += value->u.dimm->size)', '            operator: <operator>.indirectIndexAccess (node_mem[value->u.dimm->node])', '            use node_mem as uint64_t[]', '            field_access: value->u.dimm->node', '            operator: <operator>.fieldAccess (value->u.dimm)', '            field_access: value->u', '            use value as MemoryDeviceInfo*', '            field: u', '            field: dimm', '            field: node', '            field_access: value->u.dimm->size', '            operator: <operator>.fieldAccess (value->u.dimm)', '            field_access: value->u', '            use value as MemoryDeviceInfo*', '            field: u', '            field: dimm', '            field: size', '            control: break;', '            control: break;', 'call: qapi_free_MemoryDeviceInfoList (qapi_free_MemoryDeviceInfoList(info_list))', 'use info_list as MemoryDeviceInfoList*', 'declare ANY MEMORY_DEVICE_INFO_KIND_DIMM', 'declare ANY NULL']
# --------------------------------------------------------------------------------
# Row: 352
# Rule Type(s): ['unsafe_pointer_assign', 'use_unknown_value']
# Conflict Reason:
# ['Unsafe pointer assignment `assign: *s = (struct omap_32khz_timer_s *) opaque` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> OMAP_MPUI_REG_MASK as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare omap_32khz_timer_s* s', 'assign: *s = (struct omap_32khz_timer_s *) opaque', 'use s as omap_32khz_timer_s*', 'operator: <operator>.cast ((struct omap_32khz_timer_s *) opaque)', 'use opaque as void*', 'declare int offset', 'assign: offset = addr & OMAP_MPUI_REG_MASK', 'use offset as int', 'condition: addr & OMAP_MPUI_REG_MASK', 'use addr as target_phys_addr_t', 'use <unknown> OMAP_MPUI_REG_MASK as ANY', 'if: "size != 4"', '    return: return omap_badwidth_write32(opaque, addr, value);', '    call: omap_badwidth_write32 (omap_badwidth_write32(opaque, addr, value))', '    use opaque as void*', '    use addr as target_phys_addr_t', '    use value as uint64_t', 'switch: switch (offset) {\ncase 0x00: /* TVR */ s->timer.reset_val = value & 0x00ffffff; break; case 0x04: /* TCR */ OMAP_RO_REG(addr); break; case 0x08: /* CR */ s->timer.ar = (value >> 3) & 1; s->timer.it_ena = (value >> 2) & 1; if (s->timer.st != (value & 1) || (value & 2)) {\nomap_timer_sync(&s->timer); s->timer.enable = value & 1; s->timer.st = value & 1; omap_timer_update(&s->timer); } break; default: OMAP_BAD_REG(addr); }', '    literal: 0x00', '    assign: s->timer.reset_val = value & 0x00ffffff', '    operator: <operator>.fieldAccess (s->timer.reset_val)', '    field_access: s->timer', '    use s as omap_32khz_timer_s*', '    field: timer', '    field: reset_val', '    condition: value & 0x00ffffff', '    use value as uint64_t', '    literal: 0x00ffffff', '    control: break;', '    literal: 0x04', '    call: OMAP_RO_REG (OMAP_RO_REG(addr))', '    use addr as target_phys_addr_t', '    control: break;', '    literal: 0x08', '    assign: s->timer.ar = (value >> 3) & 1', '    operator: <operator>.fieldAccess (s->timer.ar)', '    field_access: s->timer', '    use s as omap_32khz_timer_s*', '    field: timer', '    field: ar', '    condition: (value >> 3) & 1', '    operator: <operator>.arithmeticShiftRight (value >> 3)', '    use value as uint64_t', '    literal: 3', '    literal: 1', '    assign: s->timer.it_ena = (value >> 2) & 1', '    operator: <operator>.fieldAccess (s->timer.it_ena)', '    field_access: s->timer', '    use s as omap_32khz_timer_s*', '    field: timer', '    field: it_ena', '    condition: (value >> 2) & 1', '    operator: <operator>.arithmeticShiftRight (value >> 2)', '    use value as uint64_t', '    literal: 2', '    literal: 1', '    if: "s->timer.st != (value & 1) || (value & 2)"', '        call: omap_timer_sync (omap_timer_sync(&s->timer))', '        operator: <operator>.addressOf (&s->timer)', '        field_access: s->timer', '        use s as omap_32khz_timer_s*', '        field: timer', '        assign: s->timer.enable = value & 1', '        operator: <operator>.fieldAccess (s->timer.enable)', '        field_access: s->timer', '        use s as omap_32khz_timer_s*', '        field: timer', '        field: enable', '        condition: value & 1', '        use value as uint64_t', '        literal: 1', '        assign: s->timer.st = value & 1', '        operator: <operator>.fieldAccess (s->timer.st)', '        field_access: s->timer', '        use s as omap_32khz_timer_s*', '        field: timer', '        field: st', '        condition: value & 1', '        use value as uint64_t', '        literal: 1', '        call: omap_timer_update (omap_timer_update(&s->timer))', '        operator: <operator>.addressOf (&s->timer)', '        field_access: s->timer', '        use s as omap_32khz_timer_s*', '        field: timer', '    control: break;', '    call: OMAP_BAD_REG (OMAP_BAD_REG(addr))', '    use addr as target_phys_addr_t', 'declare ANY OMAP_MPUI_REG_MASK']
# --------------------------------------------------------------------------------
# Row: 1010
# Rule Type(s): ['use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Use of unknown/untrusted type in `use <unknown> piix4_gpe_ops as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> GPE_LEN as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> GPE_BASE as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> true as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> piix4_get_cpu_hotplug_legacy as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> piix4_set_cpu_hotplug_legacy as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> NULL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> PIIX4_CPU_HOTPLUG_IO_BASE as ANY` but predicted not vulnerable.']
# Event Trace:
# ['call: memory_region_init_io (memory_region_init_io(&s->io_gpe, OBJECT(s), &piix4_gpe_ops, s, \\"acpi-gpe0\\", GPE_LEN))', 'operator: <operator>.addressOf (&s->io_gpe)', 'field_access: s->io_gpe', 'use s as PIIX4PMState*', 'field: io_gpe', 'call: OBJECT (OBJECT(s))', 'use s as PIIX4PMState*', 'operator: <operator>.addressOf (&piix4_gpe_ops)', 'use <unknown> piix4_gpe_ops as ANY', 'use s as PIIX4PMState*', 'literal: \\"acpi-gpe0\\', 'use <unknown> GPE_LEN as ANY', 'call: memory_region_add_subregion (memory_region_add_subregion(parent, GPE_BASE, &s->io_gpe))', 'use parent as MemoryRegion*', 'use <unknown> GPE_BASE as ANY', 'operator: <operator>.addressOf (&s->io_gpe)', 'field_access: s->io_gpe', 'use s as PIIX4PMState*', 'field: io_gpe', 'call: acpi_pcihp_init (acpi_pcihp_init(OBJECT(s), &s->acpi_pci_hotplug, bus, parent, s->use_acpi_pci_hotplug))', 'call: OBJECT (OBJECT(s))', 'use s as PIIX4PMState*', 'operator: <operator>.addressOf (&s->acpi_pci_hotplug)', 'field_access: s->acpi_pci_hotplug', 'use s as PIIX4PMState*', 'field: acpi_pci_hotplug', 'use bus as PCIBus*', 'use parent as MemoryRegion*', 'field_access: s->use_acpi_pci_hotplug', 'use s as PIIX4PMState*', 'field: use_acpi_pci_hotplug', 'assign: s->cpu_hotplug_legacy = true', 'field_access: s->cpu_hotplug_legacy', 'use s as PIIX4PMState*', 'field: cpu_hotplug_legacy', 'use <unknown> true as ANY', 'call: object_property_add_bool (object_property_add_bool(OBJECT(s), \\"cpu-hotplug-legacy\\", piix4_get_cpu_hotplug_legacy, piix4_set_cpu_hotplug_legacy, NULL))', 'call: OBJECT (OBJECT(s))', 'use s as PIIX4PMState*', 'literal: \\"cpu-hotplug-legacy\\', 'use <unknown> piix4_get_cpu_hotplug_legacy as ANY', 'use <unknown> piix4_set_cpu_hotplug_legacy as ANY', 'use <unknown> NULL as ANY', 'call: legacy_acpi_cpu_hotplug_init (legacy_acpi_cpu_hotplug_init(parent, OBJECT(s), &s->gpe_cpu, PIIX4_CPU_HOTPLUG_IO_BASE))', 'use parent as MemoryRegion*', 'call: OBJECT (OBJECT(s))', 'use s as PIIX4PMState*', 'operator: <operator>.addressOf (&s->gpe_cpu)', 'field_access: s->gpe_cpu', 'use s as PIIX4PMState*', 'field: gpe_cpu', 'use <unknown> PIIX4_CPU_HOTPLUG_IO_BASE as ANY', 'if: "s->acpi_memory_hotplug.is_enabled"', '    call: acpi_memory_hotplug_init (acpi_memory_hotplug_init(parent, OBJECT(s), &s->acpi_memory_hotplug))', '    use parent as MemoryRegion*', '    call: OBJECT (OBJECT(s))', '    use s as PIIX4PMState*', '    operator: <operator>.addressOf (&s->acpi_memory_hotplug)', '    field_access: s->acpi_memory_hotplug', '    use s as PIIX4PMState*', '    field: acpi_memory_hotplug', 'declare ANY PIIX4_CPU_HOTPLUG_IO_BASE', 'declare ANY NULL', 'declare ANY piix4_set_cpu_hotplug_legacy', 'declare ANY piix4_get_cpu_hotplug_legacy', 'declare ANY true', 'declare ANY GPE_BASE', 'declare ANY GPE_LEN', 'declare ANY piix4_gpe_ops']
# --------------------------------------------------------------------------------
# Row: 109
# Rule Type(s): ['unsafe_pointer_assign', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'unsafe_pointer_assign', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Unsafe pointer assignment `assign: *dc = &dc1` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> gen_opc_buf as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> OPC_MAX_SIZE as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> gen_opparam_ptr as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> gen_opparam_buf as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> ACCESS_CODE as ANY` but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *gen_opc_ptr = INDEX_op_end` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> gen_opc_ptr as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> INDEX_op_end as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> gen_opc_ptr as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> gen_opc_buf as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `        use <unknown> gen_opc_instr_start as ANY` but predicted not vulnerable.']
# Event Trace:
# ...
# Conflict Reason:
# ['Unsafe pointer assignment `assign: *qbus = BUS(qdev_get_parent_bus(DEVICE(s->vdev)))` not preceded by a safety check, but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *k = VIRTIO_BUS_GET_CLASS(qbus)` not preceded by a safety check, but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *vblk = VIRTIO_BLK(s->vdev)` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> true as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> true as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> stderr as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> true as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> stderr as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> complete_request_vring as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> false as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> true as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> true as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> handle_notify as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> false as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> true as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> false as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare BusState* qbus', 'assign: *qbus = BUS(qdev_get_parent_bus(DEVICE(s->vdev)))', 'use qbus as BusState*', 'call: BUS (BUS(qdev_get_parent_bus(DEVICE(s->vdev))))', 'call: qdev_get_parent_bus (qdev_get_parent_bus(DEVICE(s->vdev)))', 'call: DEVICE (DEVICE(s->vdev))', 'field_access: s->vdev', 'use s as VirtIOBlockDataPlane*', 'field: vdev', 'declare VirtioBusClass* k', 'assign: *k = VIRTIO_BUS_GET_CLASS(qbus)', 'use k as VirtioBusClass*', 'call: VIRTIO_BUS_GET_CLASS (VIRTIO_BUS_GET_CLASS(qbus))', 'use qbus as BusState*', 'declare VirtIOBlock* vblk', 'assign: *vblk = VIRTIO_BLK(s->vdev)', 'use vblk as VirtIOBlock*', 'call: VIRTIO_BLK (VIRTIO_BLK(s->vdev))', 'field_access: s->vdev', 'use s as VirtIOBlockDataPlane*', 'field: vdev', 'declare VirtQueue* vq', 'declare int r', 'if: "s->started || s->disabled"', '    return: return;', 'if: "s->starting"', '    return: return;', 'assign: s->starting = true', 'field_access: s->starting', 'use s as VirtIOBlockDataPlane*', 'field: starting', 'use <unknown> true as ANY', 'assign: vq = virtio_get_queue(s->vdev, 0)', 'use vq as VirtQueue*', 'call: virtio_get_queue (virtio_get_queue(s->vdev, 0))', 'field_access: s->vdev', 'use s as VirtIOBlockDataPlane*', 'field: vdev', 'literal: 0', 'if: "!vring_setup(&s->vring, s->vdev, 0)"', '    control: goto fail_vring;', 'assign: r = k->set_guest_notifiers(qbus->parent, 1, true)', 'use r as int', 'operator: <operator>.pointerCall (k->set_guest_notifiers(qbus->parent, 1, true))', 'field_access: qbus->parent', 'use qbus as BusState*', 'field: parent', 'literal: 1', 'use <unknown> true as ANY', 'field_access: k->set_guest_notifiers', 'use k as VirtioBusClass*', 'field: set_guest_notifiers', 'if: "r != 0"', '    call: fprintf (fprintf(stderr, \\"virtio-blk failed to set guest notifier (%d), \\" \\"ensure -enable-kvm is set\\\\n\\", r))', '    use <unknown> stderr as ANY', '    literal: \\"virtio-blk failed to set guest notifier (%d), \\" \\"ensure -enable-kvm is set\\\\n\\', '    use r as int', '    control: goto fail_guest_notifiers;', 'assign: s->guest_notifier = virtio_queue_get_guest_notifier(vq)', 'field_access: s->guest_notifier', 'use s as VirtIOBlockDataPlane*', 'field: guest_notifier', 'call: virtio_queue_get_guest_notifier (virtio_queue_get_guest_notifier(vq))', 'use vq as VirtQueue*', 'assign: r = k->set_host_notifier(qbus->parent, 0, true)', 'use r as int', 'operator: <operator>.pointerCall (k->set_host_notifier(qbus->parent, 0, true))', 'field_access: qbus->parent', 'use qbus as BusState*', 'field: parent', 'literal: 0', 'use <unknown> true as ANY', 'field_access: k->set_host_notifier', 'use k as VirtioBusClass*', 'field: set_host_notifier', 'if: "r != 0"', '    call: fprintf (fprintf(stderr, \\"virtio-blk failed to set host notifier (%d)\\\\n\\", r))', '    use <unknown> stderr as ANY', '    literal: \\"virtio-blk failed to set host notifier (%d)\\\\n\\', '    use r as int', '    control: goto fail_host_notifier;', 'assign: s->host_notifier = *virtio_queue_get_host_notifier(vq)', 'field_access: s->host_notifier', 'use s as VirtIOBlockDataPlane*', 'field: host_notifier', 'operator: <operator>.indirection (*virtio_queue_get_host_notifier(vq))', 'call: virtio_queue_get_host_notifier (virtio_queue_get_host_notifier(vq))', 'use vq as VirtQueue*', 'assign: s->saved_complete_request = vblk->complete_request', 'field_access: s->saved_complete_request', 'use s as VirtIOBlockDataPlane*', 'field: saved_complete_request', 'field_access: vblk->complete_request', 'use vblk as VirtIOBlock*', 'field: complete_request', 'assign: vblk->complete_request = complete_request_vring', 'field_access: vblk->complete_request', 'use vblk as VirtIOBlock*', 'field: complete_request', 'use <unknown> complete_request_vring as ANY', 'assign: s->starting = false', 'field_access: s->starting', 'use s as VirtIOBlockDataPlane*', 'field: starting', 'use <unknown> false as ANY', 'assign: s->started = true', 'field_access: s->started', 'use s as VirtIOBlockDataPlane*', 'field: st ...
# --------------------------------------------------------------------------------
# Row: 96
# Rule Type(s): ['unsafe_pointer_assign', 'use_unknown_value', 'unsafe_pointer_assign', 'use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Unsafe pointer assignment `assign: *d = DO_UPCAST(ISACirrusVGAState, dev, dev)` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> ISACirrusVGAState as ANY` but predicted not vulnerable.', 'Unsafe pointer assignment `assign: *s = &d->cirrus_vga.vga` not preceded by a safety check, but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> CIRRUS_ID_CLGD5430 as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> VGABIOS_CIRRUS_FILENAME as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare ISACirrusVGAState* d', 'assign: *d = DO_UPCAST(ISACirrusVGAState, dev, dev)', 'use d as ISACirrusVGAState*', 'call: DO_UPCAST (DO_UPCAST(ISACirrusVGAState, dev, dev))', 'use <unknown> ISACirrusVGAState as ANY', 'use dev as ISADevice*', 'use dev as ISADevice*', 'declare VGACommonState* s', 'assign: *s = &d->cirrus_vga.vga', 'use s as VGACommonState*', 'operator: <operator>.addressOf (&d->cirrus_vga.vga)', 'operator: <operator>.fieldAccess (d->cirrus_vga.vga)', 'field_access: d->cirrus_vga', 'use d as ISACirrusVGAState*', 'field: cirrus_vga', 'field: vga', 'call: vga_common_init (vga_common_init(s))', 'use s as VGACommonState*', 'call: cirrus_init_common (cirrus_init_common(&d->cirrus_vga, CIRRUS_ID_CLGD5430, 0, isa_address_space(dev), isa_address_space_io(dev)))', 'operator: <operator>.addressOf (&d->cirrus_vga)', 'field_access: d->cirrus_vga', 'use d as ISACirrusVGAState*', 'field: cirrus_vga', 'use <unknown> CIRRUS_ID_CLGD5430 as ANY', 'literal: 0', 'call: isa_address_space (isa_address_space(dev))', 'use dev as ISADevice*', 'call: isa_address_space_io (isa_address_space_io(dev))', 'use dev as ISADevice*', 'assign: s->con = graphic_console_init(s->update, s->invalidate, s->screen_dump, s->text_update, s)', 'field_access: s->con', 'use s as VGACommonState*', 'field: con', 'call: graphic_console_init (graphic_console_init(s->update, s->invalidate, s->screen_dump, s->text_update, s))', 'field_access: s->update', 'use s as VGACommonState*', 'field: update', 'field_access: s->invalidate', 'use s as VGACommonState*', 'field: invalidate', 'field_access: s->screen_dump', 'use s as VGACommonState*', 'field: screen_dump', 'field_access: s->text_update', 'use s as VGACommonState*', 'field: text_update', 'use s as VGACommonState*', 'call: rom_add_vga (rom_add_vga(VGABIOS_CIRRUS_FILENAME))', 'use <unknown> VGABIOS_CIRRUS_FILENAME as ANY', 'return: return 0;', 'literal: 0', 'declare ANY VGABIOS_CIRRUS_FILENAME', 'declare ANY CIRRUS_ID_CLGD5430', 'declare ANY ISACirrusVGAState']
# --------------------------------------------------------------------------------
# Row: 643
# Rule Type(s): ['use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Use of unknown/untrusted type in `    use <unknown> NULL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> child_root as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare BlockBackend* blk', 'declare BlockDriverState* bs', 'assign: blk = blk_new(errp)', 'use blk as BlockBackend*', 'call: blk_new (blk_new(errp))', 'use errp as Error**', 'if: "!blk"', '    return: return NULL;', '    use <unknown> NULL as ANY', 'assign: bs = bdrv_new_root()', 'use bs as BlockDriverState*', 'call: bdrv_new_root (bdrv_new_root())', 'assign: blk->root = bdrv_root_attach_child(bs, \\"root\\", &child_root)', 'field_access: blk->root', 'use blk as BlockBackend*', 'field: root', 'call: bdrv_root_attach_child (bdrv_root_attach_child(bs, \\"root\\", &child_root))', 'use bs as BlockDriverState*', 'literal: \\"root\\', 'operator: <operator>.addressOf (&child_root)', 'use <unknown> child_root as ANY', 'assign: blk->root->opaque = blk', 'field_access: blk->root->opaque', 'field_access: blk->root', 'use blk as BlockBackend*', 'field: root', 'field: opaque', 'use blk as BlockBackend*', 'assign: bs->blk = blk', 'field_access: bs->blk', 'use bs as BlockDriverState*', 'field: blk', 'use blk as BlockBackend*', 'return: return blk;', 'use blk as BlockBackend*', 'declare ANY child_root', 'declare ANY NULL']
# --------------------------------------------------------------------------------
# Row: 949
# Rule Type(s): ['use_unknown_value']
# Conflict Reason:
# ['Use of unknown/untrusted type in `use <unknown> env as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare CPU_DoubleU u', 'assign: u.ll = val', 'operator: <operator>.fieldAccess (u.ll)', 'use u as CPU_DoubleU', 'field: ll', 'use val as uint64_t', 'if: "unlikely(float64_is_nan(u.d))"', '    return: return 0;', '    literal: 0', 'return: return float64_to_uint32_round_to_zero(u.d, &env->vec_status);', 'call: float64_to_uint32_round_to_zero (float64_to_uint32_round_to_zero(u.d, &env->vec_status))', 'operator: <operator>.fieldAccess (u.d)', 'use u as CPU_DoubleU', 'field: d', 'operator: <operator>.addressOf (&env->vec_status)', 'field_access: env->vec_status', 'use <unknown> env as ANY', 'field: vec_status', 'declare ANY env']
# --------------------------------------------------------------------------------
# Row: 178
# Rule Type(s): ['unsafe_pointer_assign']
# Conflict Reason:
# ['Unsafe pointer assignment `assign: *fp = &fp1` not preceded by a safety check, but predicted not vulnerable.']
# Event Trace:
# ['declare int fptag', 'declare int i', 'declare int j', 'declare fpstate fp1', 'declare fpstate* fp', 'assign: *fp = &fp1', 'use fp as fpstate*', 'operator: <operator>.addressOf (&fp1)', 'use fp1 as fpstate', 'assign: fp->fpuc = env->fpuc', 'field_access: fp->fpuc', 'use fp as fpstate*', 'field: fpuc', 'field_access: env->fpuc', 'use env as CPUState*', 'field: fpuc', 'assign: fp->fpus = (env->fpus & ~0x3800) | (env->fpstt & 0x7) << 11', 'field_access: fp->fpus', 'use fp as fpstate*', 'field: fpus', 'condition: (env->fpus & ~0x3800) | (env->fpstt & 0x7) << 11', 'condition: env->fpus & ~0x3800', 'field_access: env->fpus', 'use env as CPUState*', 'field: fpus', 'operator: <operator>.not (~0x3800)', 'literal: 0x3800', 'operator: <operator>.shiftLeft ((env->fpstt & 0x7) << 11)', 'condition: env->fpstt & 0x7', 'field_access: env->fpstt', 'use env as CPUState*', 'field: fpstt', 'literal: 0x7', 'literal: 11', 'assign: fptag = 0', 'use fptag as int', 'literal: 0', 'for: for (i=7;i>=0;i--)', '    call: <operators>.assignmentShiftLeft (fptag <<= 2)', '    use fptag as int', '    literal: 2', '    if: "env->fptags[i]"', '        call: <operators>.assignmentOr (fptag |= 3)', '        use fptag as int', '        literal: 3', '    else', '        else', 'assign: fp->fptag = fptag', 'field_access: fp->fptag', 'use fp as fpstate*', 'field: fptag', 'use fptag as int', 'assign: j = env->fpstt', 'use j as int', 'field_access: env->fpstt', 'use env as CPUState*', 'field: fpstt', 'for: for (i = 0;i < 8;i++)', '    call: memcpy (memcpy(&fp->fpregs1[i * 10], &env->fpregs[j].d, 10))', '    operator: <operator>.addressOf (&fp->fpregs1[i * 10])', '    operator: <operator>.indirectIndexAccess (fp->fpregs1[i * 10])', '    field_access: fp->fpregs1', '    use fp as fpstate*', '    field: fpregs1', '    operator: <operator>.multiplication (i * 10)', '    use i as int', '    literal: 10', '    operator: <operator>.addressOf (&env->fpregs[j].d)', '    operator: <operator>.fieldAccess (env->fpregs[j].d)', '    operator: <operator>.indirectIndexAccess (env->fpregs[j])', '    field_access: env->fpregs', '    use env as CPUState*', '    field: fpregs', '    use j as int', '    field: d', '    literal: 10', '    assign: j = (j + 1) & 7', '    use j as int', '    condition: (j + 1) & 7', '    operator: <operator>.addition (j + 1)', '    use j as int', '    literal: 1', '    literal: 7']
# --------------------------------------------------------------------------------
# Row: 887
# Rule Type(s): ['use_unknown_value', 'use_unknown_value', 'use_unknown_value']
# Conflict Reason:
# ['Use of unknown/untrusted type in `use <unknown> T_RENAME as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `use <unknown> NULL as ANY` but predicted not vulnerable.', 'Use of unknown/untrusted type in `    use <unknown> errno as ANY` but predicted not vulnerable.']
# Event Trace:
# ['declare int retval', 'declare V9fsString oldname', 'declare V9fsString newname', 'call: v9fs_string_init (v9fs_string_init(&oldname))', 'operator: <operator>.addressOf (&oldname)', 'use oldname as V9fsString', 'call: v9fs_string_init (v9fs_string_init(&newname))', 'operator: <operator>.addressOf (&newname)', 'use newname as V9fsString', 'call: v9fs_string_sprintf (v9fs_string_sprintf(&oldname, \\"%s\\", oldpath))', 'operator: <operator>.addressOf (&oldname)', 'use oldname as V9fsString', 'literal: \\"%s\\', 'use oldpath as char*', 'call: v9fs_string_sprintf (v9fs_string_sprintf(&newname, \\"%s\\", newpath))', 'operator: <operator>.addressOf (&newname)', 'use newname as V9fsString', 'literal: \\"%s\\', 'use newpath as char*', 'assign: retval = v9fs_request(ctx->private, T_RENAME, NULL, \\"ss\\", &oldname, &newname)', 'use retval as int', 'call: v9fs_request (v9fs_request(ctx->private, T_RENAME, NULL, \\"ss\\", &oldname, &newname))', 'field_access: ctx->private', 'use ctx as FsContext*', 'field: private', 'use <unknown> T_RENAME as ANY', 'use <unknown> NULL as ANY', 'literal: \\"ss\\', 'operator: <operator>.addressOf (&oldname)', 'use oldname as V9fsString', 'operator: <operator>.addressOf (&newname)', 'use newname as V9fsString', 'call: v9fs_string_free (v9fs_string_free(&oldname))', 'operator: <operator>.addressOf (&oldname)', 'use oldname as V9fsString', 'call: v9fs_string_free (v9fs_string_free(&newname))', 'operator: <operator>.addressOf (&newname)', 'use newname as V9fsString', 'if: "retval < 0"', '    assign: errno = -retval', '    use <unknown> errno as ANY', '    operator: <operator>.minus (-retval)', '    use retval as int', 'return: return retval;', 'use retval as int', 'declare ANY errno', 'declare ANY NULL', 'declare ANY T_RENAME']
# --------------------------------------------------------------------------------

# %%
import pandas as pd
import re
from sklearn.preprocessing import MultiLabelBinarizer

SAFE_MACROS = [
    "NULL", "errno", "stderr", "ELF_MACHINE", "KERNEL_LOAD_ADDR", "MO_64", "MO_32",
    "MEMORY_DEVICE_INFO_KIND_DIMM", "SOCKET_ADDRESS_LEGACY_KIND_INET", "SOCKET_ADDRESS_LEGACY_KIND_UNIX",
    "SOCKET_ADDRESS_LEGACY_KIND_FD", "SOCKET_ADDRESS_LEGACY_KIND_VSOCK", "PIIX4_CPU_HOTPLUG_IO_BASE",
    "GPE_LEN", "GPE_BASE", "INDEX_op_end", "OPC_MAX_SIZE", "ACCESS_CODE"
]
SAFE_UNKNOWN_RE = re.compile(r"use <unknown> (" + "|".join(SAFE_MACROS) + r") as ANY", re.I)

def feature_row(row):
    rule_types = row['rule_type'] if isinstance(row['rule_type'], list) else []
    conflict_reason = str(row['conflict_reason'])
    event_trace = str(row['event_trace'])
    # Basic features
    return {
        "num_rules": len(rule_types),
        "use_unknown_safe": bool(SAFE_UNKNOWN_RE.search(conflict_reason)),
        "pointer_assign_from_address_of": bool(re.search(r"assign: \*\w+ = &", event_trace)),
        "pointer_assign_from_null": bool(re.search(r"assign: \*\w+ = NULL", event_trace)),
        "has_check_nearby": any('if' in e or 'check' in e or 'assert' in e for e in event_trace.split(';')),
        "reason_len": len(conflict_reason.split()),
        "trace_len": len(event_trace.split(';')),
        # One-hot rule types handled below
        "rule_type": rule_types,
    }

# Load your conflicts into a DataFrame, e.g., fp_df
features = fp_df.apply(feature_row, axis=1, result_type='expand')

# One-hot encode rule types
mlb = MultiLabelBinarizer()
rule_types_onehot = mlb.fit_transform(features['rule_type'])
rule_types_df = pd.DataFrame(rule_types_onehot, columns=mlb.classes_)
features = pd.concat([features.drop('rule_type', axis=1), rule_types_df], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\PycharmProjects\CDL\.venv\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rule_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 31
#      18     return {
#      19         "num_rules": len(rule_types),
#      20         "use_unknown_safe": bool(SAFE_UNKNOWN_RE.search(conflict_reason)),
#    (...)
#      27         "rule_type": rule_types,
#      28     }
#      30 # Load your conflicts into a DataFrame, e.g., fp_df
# ---> 31 features = fp_df.apply(feature_row, axis=1, result_type='expand')
#      33 # One-hot encode rule types
#      34 mlb = MultiLabelBinarizer()
#
# File ~\PycharmProjects\CDL\.venv\lib\site-packages\pandas\core\frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~\PycharmProjects\CDL\.venv\lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~\PycharmProjects\CDL\.venv\lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~\PycharmProjects\CDL\.venv\lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[42], line 14, in feature_row(row)
#      13 def feature_row(row):
# ---> 14     rule_types = row['rule_type'] if isinstance(row['rule_type'], list) else []
#      15     conflict_reason = str(row['conflict_reason'])
#      16     event_trace = str(row['event_trace'])
#
# File ~\PycharmProjects\CDL\.venv\lib\site-packages\pandas\core\series.py:1130, in Series.__getitem__(self, key)
#    1127     return self._values[key]
#    1129 elif key_is_scalar:
# -> 1130     return self._get_value(key)
#    1132 # Convert generator to list before going through hashable part
#    1133 # (We will iterate through the generator there to check for slices)
#    1134 if is_iterator(key):
#
# File ~\PycharmProjects\CDL\.venv\lib\site-packages\pandas\core\series.py:1246, in Series._get_value(self, label, takeable)
#    1243     return self._values[label]
#    1245 # Similar to Index.get_value, but we do not fall back to positional
# -> 1246 loc = self.index.get_loc(label)
#    1248 if is_integer(loc):
#    1249     return self._values[loc]
#
# File ~\PycharmProjects\CDL\.venv\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'rule_type'

# %%
print(fp_df.columns)
# Out:
# Index(['func', 'func_cleaned', 'project', 'label', 'graph_path', 'event_trace',
#        'input', 'pred_label', 'pred_prob', 'event_trace_list', 'conflict',
#        'conflict_reason'],
#       dtype='object')

# %%
import ast

def safe_eval(val):
    """Safely eval if string-repr of list, else return as-is."""
    if isinstance(val, list):
        return val
    try:
        return ast.literal_eval(val)
    except Exception:
        return [val]  # fallback

# Randomly sample 10 FPs (assuming conflict == True and pred_label == 0)
sample = fp_df[(fp_df['conflict'] == True) & (fp_df['pred_label'] == 0)].sample(10, random_state=42)

for idx, row in sample.iterrows():
    conflict_reason = safe_eval(row['conflict_reason'])
    event_trace = safe_eval(row['event_trace_list'])

    print(f"\nRow: {idx}")
    print("Conflict Reason(s):")
    for r in conflict_reason:
        print("  -", r)
    print("Event Trace:")
    for e in event_trace:
        print("  -", e)
    print("="*60)
# Out:
# Row: 576
# Conflict Reason(s):
#   - Use of unknown/untrusted type in `        use <unknown> true as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `use <unknown> false as ANY` but predicted not vulnerable.
# Event Trace:
#   - declare uint64_t i
#   - declare int sectors_per_bit
#   - assign: sectors_per_bit = 1 << hbitmap_granularity(bitmap->meta)
#   - use sectors_per_bit as int
#   - operator: <operator>.shiftLeft (1 << hbitmap_granularity(bitmap->meta))
#   - literal: 1
#   - call: hbitmap_granularity (hbitmap_granularity(bitmap->meta))
#   - field_access: bitmap->meta
#   - use bitmap as BdrvDirtyBitmap*
#   - field: meta
#   - for: for (i = sector;i < sector + nb_sectors;i += sectors_per_bit)
#   -     if: "hbitmap_get(bitmap->meta, i)"
#   -         return: return true;
#   -         use <unknown> true as ANY
#   - return: return false;
#   - use <unknown> false as ANY
#   - declare ANY false
#   - declare ANY true
# ============================================================
#
# Row: 312
# Conflict Reason(s):
#   - Unsafe pointer assignment `assign: *reg = cfg_entry->reg` not preceded by a safety check, but predicted not vulnerable.
#   - Unsafe pointer assignment `assign: *val = XEN_PT_MERGE_VALUE(*val, dev_value, throughable_mask)` not preceded by a safety check, but predicted not vulnerable.
# Event Trace:
#   - declare XenPTRegInfo* reg
#   - assign: *reg = cfg_entry->reg
#   - use reg as XenPTRegInfo*
#   - field_access: cfg_entry->reg
#   - use cfg_entry as XenPTReg*
#   - field: reg
#   - declare uint16_t writable_mask
#   - assign: writable_mask = 0
#   - use writable_mask as uint16_t
#   - literal: 0
#   - declare uint16_t throughable_mask
#   - assign: throughable_mask = get_throughable_mask(s, reg, valid_mask)
#   - use throughable_mask as uint16_t
#   - call: get_throughable_mask (get_throughable_mask(s, reg, valid_mask))
#   - use s as XenPCIPassthroughState*
#   - use reg as XenPTRegInfo*
#   - use valid_mask as uint16_t
#   - assign: writable_mask = reg->emu_mask & ~reg->ro_mask & valid_mask
#   - use writable_mask as uint16_t
#   - condition: reg->emu_mask & ~reg->ro_mask & valid_mask
#   - condition: reg->emu_mask & ~reg->ro_mask
#   - field_access: reg->emu_mask
#   - use reg as XenPTRegInfo*
#   - field: emu_mask
#   - operator: <operator>.not (~reg->ro_mask)
#   - field_access: reg->ro_mask
#   - use reg as XenPTRegInfo*
#   - field: ro_mask
#   - use valid_mask as uint16_t
#   - assign: cfg_entry->data = XEN_PT_MERGE_VALUE(*val, cfg_entry->data, writable_mask)
#   - field_access: cfg_entry->data
#   - use cfg_entry as XenPTReg*
#   - field: data
#   - call: XEN_PT_MERGE_VALUE (XEN_PT_MERGE_VALUE(*val, cfg_entry->data, writable_mask))
#   - operator: <operator>.indirection (*val)
#   - use val as uint16_t*
#   - field_access: cfg_entry->data
#   - use cfg_entry as XenPTReg*
#   - field: data
#   - use writable_mask as uint16_t
#   - assign: *val = XEN_PT_MERGE_VALUE(*val, dev_value, throughable_mask)
#   - operator: <operator>.indirection (*val)
#   - use val as uint16_t*
#   - call: XEN_PT_MERGE_VALUE (XEN_PT_MERGE_VALUE(*val, dev_value, throughable_mask))
#   - operator: <operator>.indirection (*val)
#   - use val as uint16_t*
#   - use dev_value as uint16_t
#   - use throughable_mask as uint16_t
#   - return: return 0;
#   - literal: 0
# ============================================================
#
# Row: 70
# Conflict Reason(s):
#   - Unsafe pointer assignment `assign: *cpu_model = args->cpu_model` not preceded by a safety check, but predicted not vulnerable.
#   - Unsafe pointer assignment `assign: *kernel_filename = args->kernel_filename` not preceded by a safety check, but predicted not vulnerable.
#   - Unsafe pointer assignment `assign: *address_space_mem = get_system_memory()` not preceded by a safety check, but predicted not vulnerable.
#   - Unsafe pointer assignment `assign: *ram = g_new(MemoryRegion, 1)` not preceded by a safety check, but predicted not vulnerable.
#   - Use of unknown/untrusted type in `use <unknown> MemoryRegion as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> stderr as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> NULL as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> NULL as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> NULL as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> NULL as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> ELF_MACHINE as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `        use <unknown> NULL as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `        use <unknown> NULL as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `        use <unknown> KERNEL_LOAD_ADDR as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `        use <unknown> KERNEL_LOAD_ADDR as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `        use <unknown> KERNEL_LOAD_ADDR as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `        use <unknown> stderr as ANY` but predicted not vulnerable.
# Event Trace:
#   - declare ram_addr_t ram_size
#   - assign: ram_size = args->ram_size
#   - use ram_size as ram_addr_t
#   - field_access: args->ram_size
#   - use args as QEMUMachineInitArgs*
#   - field: ram_size
#   - declare char* cpu_model
#   - assign: *cpu_model = args->cpu_model
#   - use cpu_model as char*
#   - field_access: args->cpu_model
#   - use args as QEMUMachineInitArgs*
#   - field: cpu_model
#   - declare char* kernel_filename
#   - assign: *kernel_filename = args->kernel_filename
#   - use kernel_filename as char*
#   - field_access: args->kernel_filename
#   - use args as QEMUMachineInitArgs*
#   - field: kernel_filename
#   - declare CPUM68KState* env
#   - declare MemoryRegion* address_space_mem
#   - assign: *address_space_mem = get_system_memory()
#   - use address_space_mem as MemoryRegion*
#   - call: get_system_memory (get_system_memory())
#   - declare MemoryRegion* ram
#   - assign: *ram = g_new(MemoryRegion, 1)
#   - use ram as MemoryRegion*
#   - call: g_new (g_new(MemoryRegion, 1))
#   - use <unknown> MemoryRegion as ANY
#   - literal: 1
#   - declare int kernel_size
#   - declare uint64_t elf_entry
#   - declare target_phys_addr_t entry
#   - if: "!cpu_model"
#   -     assign: cpu_model = \"cfv4e\
#   -     use cpu_model as char*
#   -     literal: \"cfv4e\
#   - assign: env = cpu_init(cpu_model)
#   - use env as CPUM68KState*
#   - call: cpu_init (cpu_init(cpu_model))
#   - use cpu_model as char*
#   - if: "!env"
#   -     call: fprintf (fprintf(stderr, \"Unable to find m68k CPU definition\\n\"))
#   -     use <unknown> stderr as ANY
#   -     literal: \"Unable to find m68k CPU definition\\n\
#   -     call: exit (exit(1))
#   -     literal: 1
#   - assign: env->vbr = 0
#   - field_access: env->vbr
#   - use env as CPUM68KState*
#   - field: vbr
#   - literal: 0
#   - call: memory_region_init_ram (memory_region_init_ram(ram, \"dummy_m68k.ram\", ram_size))
#   - use ram as MemoryRegion*
#   - literal: \"dummy_m68k.ram\
#   - use ram_size as ram_addr_t
#   - call: vmstate_register_ram_global (vmstate_register_ram_global(ram))
#   - use ram as MemoryRegion*
#   - call: memory_region_add_subregion (memory_region_add_subregion(address_space_mem, 0, ram))
#   - use address_space_mem as MemoryRegion*
#   - literal: 0
#   - use ram as MemoryRegion*
#   - if: "kernel_filename"
#   -     assign: kernel_size = load_elf(kernel_filename, NULL, NULL, &elf_entry, NULL, NULL, 1, ELF_MACHINE, 0)
#   -     use kernel_size as int
#   -     call: load_elf (load_elf(kernel_filename, NULL, NULL, &elf_entry, NULL, NULL, 1, ELF_MACHINE, 0))
#   -     use kernel_filename as char*
#   -     use <unknown> NULL as ANY
#   -     use <unknown> NULL as ANY
#   -     operator: <operator>.addressOf (&elf_entry)
#   -     use elf_entry as uint64_t
#   -     use <unknown> NULL as ANY
#   -     use <unknown> NULL as ANY
#   -     literal: 1
#   -     use <unknown> ELF_MACHINE as ANY
#   -     literal: 0
#   -     assign: entry = elf_entry
#   -     use entry as target_phys_addr_t
#   -     use elf_entry as uint64_t
#   -     if: "kernel_size < 0"
#   -         assign: kernel_size = load_uimage(kernel_filename, &entry, NULL, NULL)
#   -         use kernel_size as int
#   -         call: load_uimage (load_uimage(kernel_filename, &entry, NULL, NULL))
#   -         use kernel_filename as char*
#   -         operator: <operator>.addressOf (&entry)
#   -         use entry as target_phys_addr_t
#   -         use <unknown> NULL as ANY
#   -         use <unknown> NULL as ANY
#   -     if: "kernel_size < 0"
#   -         assign: kernel_size = load_image_targphys(kernel_filename, KERNEL_LOAD_ADDR, ram_size - KERNEL_LOAD_ADDR)
#   -         use kernel_size as int
#   -         call: load_image_targphys (load_image_targphys(kernel_filename, KERNEL_LOAD_ADDR, ram_size - KERNEL_LOAD_ADDR))
#   -         use kernel_filename as char*
#   -         use <unknown> KERNEL_LOAD_ADDR as ANY
#   -         operator: <operator>.subtraction (ram_size - KERNEL_LOAD_ADDR)
#   -         use ram_size as ram_addr_t
#   -         use <unknown> KERNEL_LOAD_ADDR as ANY
#   -         assign: entry = KERNEL_LOAD_ADDR
#   -         use entry as target_phys_addr_t
#   -         use <unknown> KERNEL_LOAD_ADDR as ANY
#   -     if: "kernel_size < 0"
#   -         call: fprintf (fprintf(stderr, \"qemu: could not load kernel '%s'\\n\", kernel_filename))
#   -         use <unknown> stderr as ANY
#   -         literal: \"qemu: could not load kernel '%s'\\n\
#   -         use kernel_filename as char*
#   -         call: exit (exit(1))
#   -         literal: 1
#   - else
#   -     else
#   -         assign: entry = 0
#   -         use entry as target_phys_addr_t
#   -         literal: 0
#   - assign: env->pc = entry
#   - field_access: env->pc
#   - use env as CPUM68KState*
#   - field: pc
#   - use entry as target_phys_addr_t
#   - declare ANY stderr
#   - declare ANY KERNEL_LOAD_ADDR
#   - declare ANY NULL
#   - declare ANY ELF_MACHINE
#   - declare ANY MemoryRegion
# ============================================================
#
# Row: 682
# Conflict Reason(s):
#   - Use of unknown/untrusted type in `    use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `        use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `        use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `            use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `            use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `            use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                    use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                    use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                    use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                        use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                    use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                    use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                    use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                        use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                        use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                            use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                            use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                            use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                            use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                                                use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                        use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                        use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `                        use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `use <unknown> eeprom as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `use <unknown> eeprom as ANY` but predicted not vulnerable.
# Event Trace:
#   - if: "eeprom.scl && scl && (eeprom.sda != sda)"
#   -     call: logout (logout(\"%u: scl = %u->%u, sda = %u->%u i2c %s\\n\", eeprom.tick, eeprom.scl, scl, eeprom.sda, sda, sda ? \"stop\" : \"start\"))
#   -     literal: \"%u: scl = %u->%u, sda = %u->%u i2c %s\\n\
#   -     operator: <operator>.fieldAccess (eeprom.tick)
#   -     use <unknown> eeprom as ANY
#   -     field: tick
#   -     operator: <operator>.fieldAccess (eeprom.scl)
#   -     use <unknown> eeprom as ANY
#   -     field: scl
#   -     use scl as int
#   -     operator: <operator>.fieldAccess (eeprom.sda)
#   -     use <unknown> eeprom as ANY
#   -     field: sda
#   -     use sda as int
#   -     condition: sda ? \"stop\" : \"start\
#   -     use sda as int
#   -     literal: \"stop\
#   -     literal: \"start\
#   -     if: "!sda"
#   -         assign: eeprom.tick = 1
#   -         operator: <operator>.fieldAccess (eeprom.tick)
#   -         use <unknown> eeprom as ANY
#   -         field: tick
#   -         literal: 1
#   -         assign: eeprom.command = 0
#   -         operator: <operator>.fieldAccess (eeprom.command)
#   -         use <unknown> eeprom as ANY
#   -         field: command
#   -         literal: 0
#   - else
#   -     else
#   -         if: "eeprom.tick == 0 && !eeprom.ack"
#   -             call: logout (logout(\"%u: scl = %u->%u, sda = %u->%u wait for i2c start\\n\", eeprom.tick, eeprom.scl, scl, eeprom.sda, sda))
#   -             literal: \"%u: scl = %u->%u, sda = %u->%u wait for i2c start\\n\
#   -             operator: <operator>.fieldAccess (eeprom.tick)
#   -             use <unknown> eeprom as ANY
#   -             field: tick
#   -             operator: <operator>.fieldAccess (eeprom.scl)
#   -             use <unknown> eeprom as ANY
#   -             field: scl
#   -             use scl as int
#   -             operator: <operator>.fieldAccess (eeprom.sda)
#   -             use <unknown> eeprom as ANY
#   -             field: sda
#   -             use sda as int
#   -         else
#   -             else
#   -                 if: "!eeprom.scl && scl"
#   -                     call: logout (logout(\"%u: scl = %u->%u, sda = %u->%u trigger bit\\n\", eeprom.tick, eeprom.scl, scl, eeprom.sda, sda))
#   -                     literal: \"%u: scl = %u->%u, sda = %u->%u trigger bit\\n\
#   -                     operator: <operator>.fieldAccess (eeprom.tick)
#   -                     use <unknown> eeprom as ANY
#   -                     field: tick
#   -                     operator: <operator>.fieldAccess (eeprom.scl)
#   -                     use <unknown> eeprom as ANY
#   -                     field: scl
#   -                     use scl as int
#   -                     operator: <operator>.fieldAccess (eeprom.sda)
#   -                     use <unknown> eeprom as ANY
#   -                     field: sda
#   -                     use sda as int
#   -                     if: "eeprom.ack"
#   -                         call: logout (logout(\"\\ti2c ack bit = 0\\n\"))
#   -                         literal: \"\\ti2c ack bit = 0\\n\
#   -                         assign: sda = 0
#   -                         use sda as int
#   -                         literal: 0
#   -                         assign: eeprom.ack = 0
#   -                         operator: <operator>.fieldAccess (eeprom.ack)
#   -                         use <unknown> eeprom as ANY
#   -                         field: ack
#   -                         literal: 0
#   -                     else
#   -                         else
#   -                             if: "eeprom.sda == sda"
#   -                                 declare uint8_t bit
#   -                                 assign: bit = (sda != 0)
#   -                                 use bit as uint8_t
#   -                                 condition: sda != 0
#   -                                 use sda as int
#   -                                 literal: 0
#   -                                 call: logout (logout(\"\\ti2c bit = %d\\n\", bit))
#   -                                 literal: \"\\ti2c bit = %d\\n\
#   -                                 use bit as uint8_t
#   -                                 if: "eeprom.tick < 9"
#   -                                     call: <operators>.assignmentShiftLeft (eeprom.command <<= 1)
#   -                                     operator: <operator>.fieldAccess (eeprom.command)
#   -                                     use <unknown> eeprom as ANY
#   -                                     field: command
#   -                                     literal: 1
#   -                                     operator: <operator>.assignmentPlus (eeprom.command += bit)
#   -                                     operator: <operator>.fieldAccess (eeprom.command)
#   -                                     use <unknown> eeprom as ANY
#   -                                     field: command
#   -                                     use bit as uint8_t
#   -                                     operator: <operator>.postIncrement (eeprom.tick++)
#   -                                     operator: <operator>.fieldAccess (eeprom.tick)
#   -                                     use <unknown> eeprom as ANY
#   -                                     field: tick
#   -                                     if: "eeprom.tick == 9"
#   -                                         call: logout (logout(\"\\tcommand 0x%04x, %s\\n\", eeprom.command, bit ? \"read\" : \"write\"))
#   -                                         literal: \"\\tcommand 0x%04x, %s\\n\
#   -                                         operator: <operator>.fieldAccess (eeprom.command)
#   -                                         use <unknown> eeprom as ANY
#   -                                         field: command
#   -                                         condition: bit ? \"read\" : \"write\
#   -                                         use bit as uint8_t
#   -                                         literal: \"read\
#   -                                         literal: \"write\
#   -                                         assign: eeprom.ack = 1
#   -                                         operator: <operator>.fieldAccess (eeprom.ack)
#   -                                         use <unknown> eeprom as ANY
#   -                                         field: ack
#   -                                         literal: 1
#   -                                 else
#   -                                     else
#   -                                         if: "eeprom.tick < 17"
#   -                                             if: "eeprom.command & 1"
#   -                                                 assign: sda = ((eeprom.data & 0x80) != 0)
#   -                                                 use sda as int
#   -                                                 condition: (eeprom.data & 0x80) != 0
#   -                                                 condition: eeprom.data & 0x80
#   -                                                 operator: <operator>.fieldAccess (eeprom.data)
#   -                                                 use <unknown> eeprom as ANY
#   -                                                 field: data
#   -                                                 literal: 0x80
#   -                                                 literal: 0
#   -                                             call: <operators>.assignmentShiftLeft (eeprom.address <<= 1)
#   -                                             operator: <operator>.fieldAccess (eeprom.address)
#   -                                             use <unknown> eeprom as ANY
#   -                                             field: address
#   -                                             literal: 1
#   -                                             operator: <operator>.assignmentPlus (eeprom.address += bit)
#   -                                             operator: <operator>.fieldAccess (eeprom.address)
#   -                                             use <unknown> eeprom as ANY
#   -                                             field: address
#   -                                             use bit as uint8_t
#   -                                             operator: <operator>.postIncrement (eeprom.tick++)
#   -                                             operator: <operator>.fieldAccess (eeprom.tick)
#   -                                             use <unknown> eeprom as ANY
#   -                                             field: tick
#   -                                             call: <operators>.assignmentShiftLeft (eeprom.data <<= 1)
#   -                                             operator: <operator>.fieldAccess (eeprom.data)
#   -                                             use <unknown> eeprom as ANY
#   -                                             field: data
#   -                                             literal: 1
#   -                                             if: "eeprom.tick == 17"
#   -                                                 assign: eeprom.data = eeprom.contents[eeprom.address]
#   -                                                 operator: <operator>.fieldAccess (eeprom.data)
#   -                                                 use <unknown> eeprom as ANY
#   -                                                 field: data
#   -                                                 operator: <operator>.indirectIndexAccess (eeprom.contents[eeprom.address])
#   -                                                 operator: <operator>.fieldAccess (eeprom.contents)
#   -                                                 use <unknown> eeprom as ANY
#   -                                                 field: contents
#   -                                                 operator: <operator>.fieldAccess (eeprom.address)
#   -                                                 use <unknown> eeprom as ANY
#   -                                                 field: address
#   -                                                 call: logout (logout(\"\\taddress 0x%04x, data 0x%02x\\n\", eeprom.address, eeprom.data))
#   -                                                 literal: \"\\taddress 0x%04x, data 0x%02x\\n\
#   -                                                 operator: <operator>.fieldAccess (eeprom.address)
#   -                                                 use <unknown> eeprom as ANY
#   -                                                 field: address
#   -                                                 operator: <operator>.fieldAccess (eeprom.data)
#   -                                                 use <unknown> eeprom as ANY
#   -                                                 field: data
#   -                                                 assign: eeprom.ack = 1
#   -                                                 operator: <operator>.fieldAccess (eeprom.ack)
#   -                                                 use <unknown> eeprom as ANY
#   -                                                 field: ack
#   -                                                 literal: 1
#   -                                                 assign: eeprom.tick = 0
#   -                                                 operator: <operator>.fieldAccess (eeprom.tick)
#   -                                                 use <unknown> eeprom as ANY
#   -                                                 field: tick
#   -                                                 literal: 0
#   -                                         else
#   -                                             else
#   -                                                 if: "eeprom.tick >= 17"
#   -                                                     assign: sda = 0
#   -                                                     use sda as int
#   -                                                     literal: 0
#   -                             else
#   -                                 else
#   -                                     call: logout (logout(\"\\tsda changed with raising scl\\n\"))
#   -                                     literal: \"\\tsda changed with raising scl\\n\
#   -                 else
#   -                     else
#   -                         call: logout (logout(\"%u: scl = %u->%u, sda = %u->%u\\n\", eeprom.tick, eeprom.scl, scl, eeprom.sda, sda))
#   -                         literal: \"%u: scl = %u->%u, sda = %u->%u\\n\
#   -                         operator: <operator>.fieldAccess (eeprom.tick)
#   -                         use <unknown> eeprom as ANY
#   -                         field: tick
#   -                         operator: <operator>.fieldAccess (eeprom.scl)
#   -                         use <unknown> eeprom as ANY
#   -                         field: scl
#   -                         use scl as int
#   -                         operator: <operator>.fieldAccess (eeprom.sda)
#   -                         use <unknown> eeprom as ANY
#   -                         field: sda
#   -                         use sda as int
#   - assign: eeprom.scl = scl
#   - operator: <operator>.fieldAccess (eeprom.scl)
#   - use <unknown> eeprom as ANY
#   - field: scl
#   - use scl as int
#   - assign: eeprom.sda = sda
#   - operator: <operator>.fieldAccess (eeprom.sda)
#   - use <unknown> eeprom as ANY
#   - field: sda
#   - use sda as int
#   - declare ANY eeprom
# ============================================================
#
# Row: 896
# Conflict Reason(s):
#   - Use of unknown/untrusted type in `use <unknown> VIRTIO_F_NOTIFY_ON_EMPTY as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `use <unknown> VIRTIO_RING_F_INDIRECT_DESC as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `use <unknown> VIRTIO_F_BAD_FEATURE as ANY` but predicted not vulnerable.
# Event Trace:
#   - declare unsigned ret
#   - assign: ret = 0
#   - use ret as unsigned
#   - literal: 0
#   - call: <operators>.assignmentOr (ret |= (1 << VIRTIO_F_NOTIFY_ON_EMPTY))
#   - use ret as unsigned
#   - operator: <operator>.shiftLeft (1 << VIRTIO_F_NOTIFY_ON_EMPTY)
#   - literal: 1
#   - use <unknown> VIRTIO_F_NOTIFY_ON_EMPTY as ANY
#   - call: <operators>.assignmentOr (ret |= (1 << VIRTIO_RING_F_INDIRECT_DESC))
#   - use ret as unsigned
#   - operator: <operator>.shiftLeft (1 << VIRTIO_RING_F_INDIRECT_DESC)
#   - literal: 1
#   - use <unknown> VIRTIO_RING_F_INDIRECT_DESC as ANY
#   - call: <operators>.assignmentOr (ret |= (1 << VIRTIO_F_BAD_FEATURE))
#   - use ret as unsigned
#   - operator: <operator>.shiftLeft (1 << VIRTIO_F_BAD_FEATURE)
#   - literal: 1
#   - use <unknown> VIRTIO_F_BAD_FEATURE as ANY
#   - return: return ret;
#   - use ret as unsigned
#   - declare ANY VIRTIO_F_BAD_FEATURE
#   - declare ANY VIRTIO_RING_F_INDIRECT_DESC
#   - declare ANY VIRTIO_F_NOTIFY_ON_EMPTY
# ============================================================
#
# Row: 912
# Conflict Reason(s):
#   - Use of unknown/untrusted type in `use <unknown> alloc_list as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `use <unknown> alloc_list as ANY` but predicted not vulnerable.
# Event Trace:
#   - declare Aml* var
#   - call: assert (assert(!alloc_list))
#   - condition: !alloc_list
#   - use <unknown> alloc_list as ANY
#   - assign: alloc_list = g_ptr_array_new()
#   - use <unknown> alloc_list as ANY
#   - call: g_ptr_array_new (g_ptr_array_new())
#   - assign: var = aml_alloc()
#   - use var as Aml*
#   - call: aml_alloc (aml_alloc())
#   - return: return var;
#   - use var as Aml*
#   - declare ANY alloc_list
# ============================================================
#
# Row: 308
# Conflict Reason(s):
#   - Unsafe pointer assignment `assign: *red = (ReadEventData *) sccb` not preceded by a safety check, but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> SCLP_RC_INSUFFICIENT_SCCB_LENGTH as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> SCLP_UNCONDITIONAL_READ as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> SCLP_SELECTIVE_READ as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `        use <unknown> SCLP_RC_INVALID_SELECTION_MASK as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> SCLP_RC_INVALID_FUNCTION as ANY` but predicted not vulnerable.
# Event Trace:
#   - declare unsigned int sclp_active_selection_mask
#   - declare unsigned int sclp_cp_receive_mask
#   - declare ReadEventData* red
#   - assign: *red = (ReadEventData *) sccb
#   - use red as ReadEventData*
#   - operator: <operator>.cast ((ReadEventData *) sccb)
#   - use sccb as SCCB*
#   - if: "be16_to_cpu(sccb->h.length) != SCCB_SIZE"
#   -     assign: sccb->h.response_code = cpu_to_be16(SCLP_RC_INSUFFICIENT_SCCB_LENGTH)
#   -     operator: <operator>.fieldAccess (sccb->h.response_code)
#   -     field_access: sccb->h
#   -     use sccb as SCCB*
#   -     field: h
#   -     field: response_code
#   -     call: cpu_to_be16 (cpu_to_be16(SCLP_RC_INSUFFICIENT_SCCB_LENGTH))
#   -     use <unknown> SCLP_RC_INSUFFICIENT_SCCB_LENGTH as ANY
#   -     control: goto out;
#   - assign: sclp_cp_receive_mask = ef->receive_mask
#   - use sclp_cp_receive_mask as unsigned int
#   - field_access: ef->receive_mask
#   - use ef as SCLPEventFacility*
#   - field: receive_mask
#   - switch: switch (sccb->h.function_code) {
# case SCLP_UNCONDITIONAL_READ: sclp_active_selection_mask = sclp_cp_receive_mask; break; case SCLP_SELECTIVE_READ: if (!(sclp_cp_receive_mask & be32_to_cpu(red->mask))) {
# sccb->h.response_code = cpu_to_be16(SCLP_RC_INVALID_SELECTION_MASK); goto out; } sclp_active_selection_mask = be32_to_cpu(red->mask); break; default: sccb->h.response_code = cpu_to_be16(SCLP_RC_INVALID_FUNCTION); goto out; }
#   -     use <unknown> SCLP_UNCONDITIONAL_READ as ANY
#   -     assign: sclp_active_selection_mask = sclp_cp_receive_mask
#   -     use sclp_active_selection_mask as unsigned int
#   -     use sclp_cp_receive_mask as unsigned int
#   -     control: break;
#   -     use <unknown> SCLP_SELECTIVE_READ as ANY
#   -     if: "!(sclp_cp_receive_mask & be32_to_cpu(red->mask))"
#   -         assign: sccb->h.response_code = cpu_to_be16(SCLP_RC_INVALID_SELECTION_MASK)
#   -         operator: <operator>.fieldAccess (sccb->h.response_code)
#   -         field_access: sccb->h
#   -         use sccb as SCCB*
#   -         field: h
#   -         field: response_code
#   -         call: cpu_to_be16 (cpu_to_be16(SCLP_RC_INVALID_SELECTION_MASK))
#   -         use <unknown> SCLP_RC_INVALID_SELECTION_MASK as ANY
#   -         control: goto out;
#   -     assign: sclp_active_selection_mask = be32_to_cpu(red->mask)
#   -     use sclp_active_selection_mask as unsigned int
#   -     call: be32_to_cpu (be32_to_cpu(red->mask))
#   -     field_access: red->mask
#   -     use red as ReadEventData*
#   -     field: mask
#   -     control: break;
#   -     assign: sccb->h.response_code = cpu_to_be16(SCLP_RC_INVALID_FUNCTION)
#   -     operator: <operator>.fieldAccess (sccb->h.response_code)
#   -     field_access: sccb->h
#   -     use sccb as SCCB*
#   -     field: h
#   -     field: response_code
#   -     call: cpu_to_be16 (cpu_to_be16(SCLP_RC_INVALID_FUNCTION))
#   -     use <unknown> SCLP_RC_INVALID_FUNCTION as ANY
#   -     control: goto out;
#   - assign: sccb->h.response_code = cpu_to_be16( handle_sccb_read_events(ef, sccb, sclp_active_selection_mask))
#   - operator: <operator>.fieldAccess (sccb->h.response_code)
#   - field_access: sccb->h
#   - use sccb as SCCB*
#   - field: h
#   - field: response_code
#   - call: cpu_to_be16 (cpu_to_be16( handle_sccb_read_events(ef, sccb, sclp_active_selection_mask)))
#   - call: handle_sccb_read_events (handle_sccb_read_events(ef, sccb, sclp_active_selection_mask))
#   - use ef as SCLPEventFacility*
#   - use sccb as SCCB*
#   - use sclp_active_selection_mask as unsigned int
#   - return: return;
#   - declare ANY SCLP_RC_INVALID_FUNCTION
#   - declare ANY SCLP_RC_INVALID_SELECTION_MASK
#   - declare ANY SCLP_SELECTIVE_READ
#   - declare ANY SCLP_UNCONDITIONAL_READ
#   - declare ANY SCLP_RC_INSUFFICIENT_SCCB_LENGTH
#   - declare ANY SCCB_SIZE
# ============================================================
#
# Row: 660
# Conflict Reason(s):
#   - Use of unknown/untrusted type in `    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_INET as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_UNIX as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_FD as ANY` but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> SOCKET_ADDRESS_LEGACY_KIND_VSOCK as ANY` but predicted not vulnerable.
# Event Trace:
#   - switch: switch (addr->type) {
# case SOCKET_ADDRESS_LEGACY_KIND_INET: return g_strdup_printf(\"%s%s:%s:%s%s\", prefix, is_telnet ? \"telnet\" : \"tcp\", addr->u.inet.data->host, addr->u.inet.data->port, is_listen ? \",server\" : \"\"); break; case SOCKET_ADDRESS_LEGACY_KIND_UNIX: return g_strdup_printf(\"%sunix:%s%s\", prefix, addr->u.q_unix.data->path, is_listen ? \",server\" : \"\"); break; case SOCKET_ADDRESS_LEGACY_KIND_FD: return g_strdup_printf(\"%sfd:%s%s\", prefix, addr->u.fd.data->str, is_listen ? \",server\" : \"\"); break; case SOCKET_ADDRESS_LEGACY_KIND_VSOCK: return g_strdup_printf(\"%svsock:%s:%s\", prefix, addr->u.vsock.data->cid, addr->u.vsock.data->port); default: abort(); }
#   -     use <unknown> SOCKET_ADDRESS_LEGACY_KIND_INET as ANY
#   -     return: return g_strdup_printf(\"%s%s:%s:%s%s\", prefix, is_telnet ? \"telnet\" : \"tcp\", addr->u.inet.data->host, addr->u.inet.data->port, is_listen ? \",server\" : \"\");
#   -     call: g_strdup_printf (g_strdup_printf(\"%s%s:%s:%s%s\", prefix, is_telnet ? \"telnet\" : \"tcp\", addr->u.inet.data->host, addr->u.inet.data->port, is_listen ? \",server\" : \"\"))
#   -     literal: \"%s%s:%s:%s%s\
#   -     use prefix as char*
#   -     condition: is_telnet ? \"telnet\" : \"tcp\
#   -     use is_telnet as bool
#   -     literal: \"telnet\
#   -     literal: \"tcp\
#   -     field_access: addr->u.inet.data->host
#   -     operator: <operator>.fieldAccess (addr->u.inet.data)
#   -     operator: <operator>.fieldAccess (addr->u.inet)
#   -     field_access: addr->u
#   -     use addr as SocketAddressLegacy*
#   -     field: u
#   -     field: inet
#   -     field: data
#   -     field: host
#   -     field_access: addr->u.inet.data->port
#   -     operator: <operator>.fieldAccess (addr->u.inet.data)
#   -     operator: <operator>.fieldAccess (addr->u.inet)
#   -     field_access: addr->u
#   -     use addr as SocketAddressLegacy*
#   -     field: u
#   -     field: inet
#   -     field: data
#   -     field: port
#   -     condition: is_listen ? \",server\" : \"\
#   -     use is_listen as bool
#   -     literal: \",server\
#   -     literal: \"\
#   -     control: break;
#   -     use <unknown> SOCKET_ADDRESS_LEGACY_KIND_UNIX as ANY
#   -     return: return g_strdup_printf(\"%sunix:%s%s\", prefix, addr->u.q_unix.data->path, is_listen ? \",server\" : \"\");
#   -     call: g_strdup_printf (g_strdup_printf(\"%sunix:%s%s\", prefix, addr->u.q_unix.data->path, is_listen ? \",server\" : \"\"))
#   -     literal: \"%sunix:%s%s\
#   -     use prefix as char*
#   -     field_access: addr->u.q_unix.data->path
#   -     operator: <operator>.fieldAccess (addr->u.q_unix.data)
#   -     operator: <operator>.fieldAccess (addr->u.q_unix)
#   -     field_access: addr->u
#   -     use addr as SocketAddressLegacy*
#   -     field: u
#   -     field: q_unix
#   -     field: data
#   -     field: path
#   -     condition: is_listen ? \",server\" : \"\
#   -     use is_listen as bool
#   -     literal: \",server\
#   -     literal: \"\
#   -     control: break;
#   -     use <unknown> SOCKET_ADDRESS_LEGACY_KIND_FD as ANY
#   -     return: return g_strdup_printf(\"%sfd:%s%s\", prefix, addr->u.fd.data->str, is_listen ? \",server\" : \"\");
#   -     call: g_strdup_printf (g_strdup_printf(\"%sfd:%s%s\", prefix, addr->u.fd.data->str, is_listen ? \",server\" : \"\"))
#   -     literal: \"%sfd:%s%s\
#   -     use prefix as char*
#   -     field_access: addr->u.fd.data->str
#   -     operator: <operator>.fieldAccess (addr->u.fd.data)
#   -     operator: <operator>.fieldAccess (addr->u.fd)
#   -     field_access: addr->u
#   -     use addr as SocketAddressLegacy*
#   -     field: u
#   -     field: fd
#   -     field: data
#   -     field: str
#   -     condition: is_listen ? \",server\" : \"\
#   -     use is_listen as bool
#   -     literal: \",server\
#   -     literal: \"\
#   -     control: break;
#   -     use <unknown> SOCKET_ADDRESS_LEGACY_KIND_VSOCK as ANY
#   -     return: return g_strdup_printf(\"%svsock:%s:%s\", prefix, addr->u.vsock.data->cid, addr->u.vsock.data->port);
#   -     call: g_strdup_printf (g_strdup_printf(\"%svsock:%s:%s\", prefix, addr->u.vsock.data->cid, addr->u.vsock.data->port))
#   -     literal: \"%svsock:%s:%s\
#   -     use prefix as char*
#   -     field_access: addr->u.vsock.data->cid
#   -     operator: <operator>.fieldAccess (addr->u.vsock.data)
#   -     operator: <operator>.fieldAccess (addr->u.vsock)
#   -     field_access: addr->u
#   -     use addr as SocketAddressLegacy*
#   -     field: u
#   -     field: vsock
#   -     field: data
#   -     field: cid
#   -     field_access: addr->u.vsock.data->port
#   -     operator: <operator>.fieldAccess (addr->u.vsock.data)
#   -     operator: <operator>.fieldAccess (addr->u.vsock)
#   -     field_access: addr->u
#   -     use addr as SocketAddressLegacy*
#   -     field: u
#   -     field: vsock
#   -     field: data
#   -     field: port
#   -     call: abort (abort())
#   - declare ANY SOCKET_ADDRESS_LEGACY_KIND_VSOCK
#   - declare ANY SOCKET_ADDRESS_LEGACY_KIND_FD
#   - declare ANY SOCKET_ADDRESS_LEGACY_KIND_UNIX
#   - declare ANY SOCKET_ADDRESS_LEGACY_KIND_INET
# ============================================================
#
# Row: 174
# Conflict Reason(s):
#   - Unsafe pointer assignment `assign: *filename = qdict_get_str(qdict, \"device\")` not preceded by a safety check, but predicted not vulnerable.
#   - Use of unknown/untrusted type in `    use <unknown> QERR_DEVICE_NOT_FOUND as ANY` but predicted not vulnerable.
# Event Trace:
#   - declare BlockDriverState* bs
#   - declare int force
#   - assign: force = qdict_get_int(qdict, \"force\")
#   - use force as int
#   - call: qdict_get_int (qdict_get_int(qdict, \"force\"))
#   - use qdict as QDict*
#   - literal: \"force\
#   - declare char* filename
#   - assign: *filename = qdict_get_str(qdict, \"device\")
#   - use filename as char*
#   - call: qdict_get_str (qdict_get_str(qdict, \"device\"))
#   - use qdict as QDict*
#   - literal: \"device\
#   - assign: bs = bdrv_find(filename)
#   - use bs as BlockDriverState*
#   - call: bdrv_find (bdrv_find(filename))
#   - use filename as char*
#   - if: "!bs"
#   -     call: qerror_report (qerror_report(QERR_DEVICE_NOT_FOUND, filename))
#   -     use <unknown> QERR_DEVICE_NOT_FOUND as ANY
#   -     use filename as char*
#   -     return: return -1;
#   -     operator: <operator>.minus (-1)
#   -     literal: 1
#   - return: return eject_device(mon, bs, force);
#   - call: eject_device (eject_device(mon, bs, force))
#   - use mon as Monitor*
#   - use bs as BlockDriverState*
#   - use force as int
#   - declare ANY QERR_DEVICE_NOT_FOUND
# ============================================================
#
# Row: 192
# Conflict Reason(s):
#   - Unsafe pointer assignment `assign: *info_list = NULL` not preceded by a safety check, but predicted not vulnerable.
#   - Use of unknown/untrusted type in `use <unknown> NULL as ANY` but predicted not vulnerable.
#   - Unsafe pointer assignment `assign: **prev = &info_list` not preceded by a safety check, but predicted not vulnerable.
#   - Unsafe pointer assignment `    assign: *value = info->value` not preceded by a safety check, but predicted not vulnerable.
#   - Use of unknown/untrusted type in `            use <unknown> MEMORY_DEVICE_INFO_KIND_DIMM as ANY` but predicted not vulnerable.
# Event Trace:
#   - declare MemoryDeviceInfoList* info_list
#   - assign: *info_list = NULL
#   - use info_list as MemoryDeviceInfoList*
#   - use <unknown> NULL as ANY
#   - declare MemoryDeviceInfoList** prev
#   - assign: **prev = &info_list
#   - use prev as MemoryDeviceInfoList**
#   - operator: <operator>.addressOf (&info_list)
#   - use info_list as MemoryDeviceInfoList*
#   - declare MemoryDeviceInfoList* info
#   - call: qmp_pc_dimm_device_list (qmp_pc_dimm_device_list(qdev_get_machine(), &prev))
#   - call: qdev_get_machine (qdev_get_machine())
#   - operator: <operator>.addressOf (&prev)
#   - use prev as MemoryDeviceInfoList**
#   - for: for (info = info_list;info;info = info->next)
#   -     declare MemoryDeviceInfo* value
#   -     assign: *value = info->value
#   -     use value as MemoryDeviceInfo*
#   -     field_access: info->value
#   -     use info as MemoryDeviceInfoList*
#   -     field: value
#   -     if: "value"
#   -         switch: switch (value->type) {
# case MEMORY_DEVICE_INFO_KIND_DIMM: node_mem[value->u.dimm->node] += value->u.dimm->size; break; default: break; }
#   -             use <unknown> MEMORY_DEVICE_INFO_KIND_DIMM as ANY
#   -             operator: <operator>.assignmentPlus (node_mem[value->u.dimm->node] += value->u.dimm->size)
#   -             operator: <operator>.indirectIndexAccess (node_mem[value->u.dimm->node])
#   -             use node_mem as uint64_t[]
#   -             field_access: value->u.dimm->node
#   -             operator: <operator>.fieldAccess (value->u.dimm)
#   -             field_access: value->u
#   -             use value as MemoryDeviceInfo*
#   -             field: u
#   -             field: dimm
#   -             field: node
#   -             field_access: value->u.dimm->size
#   -             operator: <operator>.fieldAccess (value->u.dimm)
#   -             field_access: value->u
#   -             use value as MemoryDeviceInfo*
#   -             field: u
#   -             field: dimm
#   -             field: size
#   -             control: break;
#   -             control: break;
#   - call: qapi_free_MemoryDeviceInfoList (qapi_free_MemoryDeviceInfoList(info_list))
#   - use info_list as MemoryDeviceInfoList*
#   - declare ANY MEMORY_DEVICE_INFO_KIND_DIMM
#   - declare ANY NULL
# ============================================================

# %%
from collections import Counter
import re

unknown_type_pattern = re.compile(r"use <unknown> ([\w\->*]+) as ANY")
unsafe_pointer_pattern = re.compile(r"Unsafe pointer assignment")

unknown_types = []
pointer_fp = 0
total_fp = 0

for idx, row in fp_df.iterrows():
    reasons = row['conflict_reason']
    # If it's a string repr, use ast.literal_eval; if list, use directly
    if isinstance(reasons, str) and reasons.startswith("["):
        import ast
        reasons = ast.literal_eval(reasons)
    elif isinstance(reasons, str):
        reasons = [reasons]
    for r in reasons:
        total_fp += 1
        # Count pointer assignment overflags
        if unsafe_pointer_pattern.search(r):
            pointer_fp += 1
        # Extract unknown/untrusted types
        m = unknown_type_pattern.search(r)
        if m:
            unknown_types.append(m.group(1))

print("Total False Positives (conflicts):", total_fp)
print("Overflagged Pointer Assignments:", pointer_fp)
print("Unknown/Untrusted Types (top 10):")
for t, count in Counter(unknown_types).most_common(10):
    print(f"  {t:30s} : {count} times")
# Out:
# Total False Positives (conflicts): 8674
# Overflagged Pointer Assignments: 995
# Unknown/Untrusted Types (top 10):
#   NULL                           : 694 times
#   stderr                         : 135 times
#   true                           : 133 times
#   false                          : 110 times
#   error_abort                    : 90 times
#   cpu_env                        : 83 times
#   EINVAL                         : 75 times
#   cpu_gpr                        : 66 times
#   errno                          : 60 times
#   env                            : 58 times
